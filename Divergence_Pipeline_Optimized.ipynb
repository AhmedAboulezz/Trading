# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAboulezz/Trading/blob/main/Divergence_Pipeline_Optimized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install pandas numpy matplotlib plotly scipy ta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.signal import argrelextrema
import ta
from datetime import datetime
import warnings
from numba import njit
warnings.filterwarnings('ignore')

#------------------------------------------------------------------------------
# CONFIGURATION PARAMETERS
#------------------------------------------------------------------------------

class Config:
    # Pivot settings
    prd = 5  # Pivot Period
    source = "Close"  # Source for Pivot Points: "Close" or "High/Low"

    # Divergence settings
    searchdiv = "Regular"  # "Regular", "Hidden", or "Regular/Hidden"
    showlimit = 1  # Minimum Number of Divergence (any)
    maxpp = 10  # Maximum Pivot Points to Check
    maxbars = 100  # Maximum Bars to Check
    dontconfirm = False  # Don't Wait for Confirmation

    # Quality filter
    minPosDivForEntry = 2  # Min # of Positive Divergence for Valid Long
    minNegDivForExit = 1   # Min # of Negative Divergence for Exit

    # Entry delay and drawdown
    delayBars = 0  # Delay For Entry (Bars)
    useDrawdown = False  # Use % Drawdown Before Entry
    drawdownPerc = 1.0  # Drawdown %

    # Indicator selection (all enabled by default)
    calcmacd = True
    calcmacda = True
    calcrsi = True
    calcstoc = True
    calccci = True
    calcmom = True
    calcobv = False
    calcvwmacd = True
    calccmf = True
    calcmfi = True

    # Backtest settings
    initial_capital = 10000
    position_size = 1.0  # Use 100% of capital per trade

config = Config()

#------------------------------------------------------------------------------
# DATA LOADING
#------------------------------------------------------------------------------

def load_data_from_csv(filepath):
    """Load OHLC data from CSV file"""
    print(f"Loading data from {filepath}...")

    # Read CSV
    df = pd.read_csv(filepath)

    # Normalize column names to lowercase
    df.columns = [col.lower().strip() for col in df.columns]

    # Parse time column
    df['time'] = pd.to_datetime(df['time'])
    df.set_index('time', inplace=True)

    # Ensure we have required columns
    required_cols = ['open', 'high', 'low', 'close']
    for col in required_cols:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")

    # Add volume if not present (needed for some indicators)
    if 'volume' not in df.columns:
        df['volume'] = 1000000  # Default volume
        print("Warning: No volume column found, using default values")

    print(f"Loaded {len(df)} bars from {df.index[0]} to {df.index[-1]}")
    return df

#------------------------------------------------------------------------------
# TECHNICAL INDICATORS
#------------------------------------------------------------------------------


def calculate_indicators(df):
    df = df.copy()

    close = df["close"].astype(float)
    high  = df["high"].astype(float)
    low   = df["low"].astype(float)
    vol   = df["volume"].astype(float)  # أو "volume" حسب اسم العمود عندك

    # ------------------------------------------------------------------
    # RSI, MACD, VW-MACD, CMF, ... خليهـم زي ما أنت عاملهم لو متطابقين
    # ------------------------------------------------------------------
    import ta

    # RSI(14) - مطابق لـ ta.rsi(close, 14)
    df["rsi"] = ta.momentum.RSIIndicator(close=close, window=14).rsi()

    # MACD(12,26,9)
    macd_ind = ta.trend.MACD(close=close, window_slow=26,
                             window_fast=12, window_sign=9)
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # Momentum(10)
    df["momentum"] = close - close.shift(10)

    # VW-MACD = VWMA(12) - VWMA(26) (نفس Pine)
    vwma_fast = (close * vol).rolling(12).sum() / vol.rolling(12).sum()
    vwma_slow = (close * vol).rolling(26).sum() / vol.rolling(26).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # CMF(21) زي Pine
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high=high, low=low, close=close, volume=vol, window=21
    ).chaikin_money_flow()

    # ==============================================================
    # ✅ 1) Stochastic(14,3) مطابق لـ Stochastic(14,3) في Pine
    # ==============================================================
    lowest_low_14  = low.rolling(window=14, min_periods=14).min()
    highest_high_14 = high.rolling(window=14, min_periods=14).max()

    stoch_k = 100.0 * (close - lowest_low_14) / (highest_high_14 - lowest_low_14)
    df["stoch"] = stoch_k.rolling(window=3, min_periods=3).mean()

    # ==============================================================
    # ✅ 2) CCI(10) باستخدام الـ close (نفس Pine في csv)
    # ==============================================================
    n_cci = 10
    sma_close = close.rolling(n_cci, min_periods=n_cci).mean()

    # mean absolute deviation من الـ sma على الـ close
    mad_close = close.rolling(n_cci, min_periods=n_cci).apply(
        lambda x: np.mean(np.abs(x - x.mean())),
        raw=True
    )

    df["cci"] = (close - sma_close) / (0.015 * mad_close)

    # ==============================================================
    # ✅ 3) MFI(14) باستخدام الـ close كـ price
    # ==============================================================
    n_mfi = 14
    price = close

    raw_mf = price * vol
    pos_mf = [0.0]
    neg_mf = [0.0]

    for i in range(1, len(df)):
        if price.iloc[i] > price.iloc[i - 1]:
            pos_mf.append(raw_mf.iloc[i])
            neg_mf.append(0.0)
        elif price.iloc[i] < price.iloc[i - 1]:
            pos_mf.append(0.0)
            neg_mf.append(raw_mf.iloc[i])
        else:
            pos_mf.append(0.0)
            neg_mf.append(0.0)

    pos_mf = pd.Series(pos_mf, index=df.index)
    neg_mf = pd.Series(neg_mf, index=df.index)

    pos_roll = pos_mf.rolling(n_mfi, min_periods=n_mfi).sum()
    neg_roll = neg_mf.rolling(n_mfi, min_periods=n_mfi).sum()

    mfi = 100.0 * (pos_roll / (pos_roll + neg_roll))
    df["mfi"] = mfi

    # 9) OBV (هنسيبه زي ما انت عامل)
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i-1]:
            obv_values.append(obv_values[-1] + vol.iloc[i])
        elif close.iloc[i] < close.iloc[i-1]:
            obv_values.append(obv_values[-1] - vol.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df['obv'] = obv_values

    df = df.fillna(method='bfill').fillna(method='ffill')

    # ==============================================================
    # OBV زي ما تحب (وانت أصلاً قلت سيبه)
    # ==============================================================
    # ممكن تخليه زي Pine لو حابب لاحقًا، بس مش ضروري دلوقتي

    return df


#------------------------------------------------------------------------------
# PIVOT POINT DETECTION
#------------------------------------------------------------------------------

def find_pivots(df, period):
    """Find pivot highs and pivot lows"""
    print(f"Finding pivot points with period {period}...")

    if config.source == "Close":
        high_series = df['close']
        low_series = df['close']
    else:
        high_series = df['high']
        low_series = df['low']

    # Initialize pivot columns
    df['pivot_high'] = np.nan
    df['pivot_high_bar'] = np.nan
    df['pivot_low'] = np.nan
    df['pivot_low_bar'] = np.nan

    for i in range(period, len(df) - period):
        # Check pivot high
        is_pivot_high = True
        for j in range(1, period + 1):
            if high_series.iloc[i] <= high_series.iloc[i - j] or \
               high_series.iloc[i] <= high_series.iloc[i + j]:
                is_pivot_high = False
                break

        if is_pivot_high:
            df.iloc[i, df.columns.get_loc('pivot_high')] = high_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_high_bar')] = i

        # Check pivot low
        is_pivot_low = True
        for j in range(1, period + 1):
            if low_series.iloc[i] >= low_series.iloc[i - j] or \
               low_series.iloc[i] >= low_series.iloc[i + j]:
                is_pivot_low = False
                break

        if is_pivot_low:
            df.iloc[i, df.columns.get_loc('pivot_low')] = low_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_low_bar')] = i

    num_highs = df['pivot_high'].notna().sum()
    num_lows = df['pivot_low'].notna().sum()
    print(f"Found {num_highs} pivot highs and {num_lows} pivot lows")

    return df

#------------------------------------------------------------------------------
# DIVERGENCE DETECTION
#------------------------------------------------------------------------------

def detect_divergence(df, indicator_name, bar_idx, pivot_positions, pivot_values,
                     is_bullish, is_regular):
    """
    Detect divergence at a specific bar
    Returns: length of divergence if found, else 0
    """

    if bar_idx < config.prd:
        return 0

    startpoint = 0 if config.dontconfirm else 1

    if config.source == "Close":
        price_series = df['close'].values
    else:
        price_series = df['low'].values if is_bullish else df['high'].values

    indicator_series = df[indicator_name].values

    # Check confirmation condition
    if not config.dontconfirm:
        if is_bullish:
            if not (indicator_series[bar_idx] > indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] > df['close'].values[bar_idx - 1]):
                return 0
        else:
            if not (indicator_series[bar_idx] < indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] < df['close'].values[bar_idx - 1]):
                return 0

    # Check each pivot
    for pivot_idx in range(min(config.maxpp, len(pivot_positions))):
        if pivot_idx >= len(pivot_positions) or np.isnan(pivot_positions[pivot_idx]):
            break

        pivot_bar = int(pivot_positions[pivot_idx])
        length = bar_idx - pivot_bar

        if length > config.maxbars:
            break

        if length > 5:
            # Check divergence conditions
            if is_bullish and is_regular:
                # Positive Regular: indicator makes higher low, price makes lower low
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])
            elif is_bullish and not is_regular:
                # Positive Hidden: indicator makes lower low, price makes higher low
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            elif not is_bullish and is_regular:
                # Negative Regular: indicator makes lower high, price makes higher high
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            else:
                # Negative Hidden: indicator makes higher high, price makes lower high
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])

            if div_condition:
                # Check if line is valid (no crossings)
                slope1 = (indicator_series[bar_idx - startpoint] - indicator_series[pivot_bar]) / length
                slope2 = (df['close'].values[bar_idx - startpoint] - df['close'].values[pivot_bar]) / length

                virtual_line1 = indicator_series[bar_idx - startpoint]
                virtual_line2 = df['close'].values[bar_idx - startpoint]

                valid = True
                for y in range(1 + startpoint, length):
                    virtual_line1 -= slope1
                    virtual_line2 -= slope2

                    check_idx = bar_idx - y
                    if is_bullish:
                        if indicator_series[check_idx] < virtual_line1 or \
                           df['close'].values[check_idx] < virtual_line2:
                            valid = False
                            break
                    else:
                        if indicator_series[check_idx] > virtual_line1 or \
                           df['close'].values[check_idx] > virtual_line2:
                            valid = False
                            break

                if valid:
                    return length

    return 0

from collections import deque
import numpy as np
#------------------------------------------------------------------------------
# NUMBA CORES (لا تغيّر اللوجيك، بس تسرّع التنفيذ)
#------------------------------------------------------------------------------

@njit
def _detect_divergence_core(
    indicator_series,
    close_series,
    low_series,
    high_series,
    price_source_code,   # 0 = Close, 1 = High/Low
    bar_idx,
    pivot_positions,
    pivot_values,
    is_bullish,
    is_regular,
    prd,
    dontconfirm,
    maxpp,
    maxbars
):
    # نفس لوجيك detect_divergence تقريباً لكن على arrays جوّه Numba

    if bar_idx < prd:
        return 0

    startpoint = 0 if dontconfirm else 1

    # اختيار price_series
    if price_source_code == 0:
        price_series = close_series
    else:
        if is_bullish:
            price_series = low_series
        else:
            price_series = high_series

    # شرط الـ confirmation
    if not dontconfirm:
        if is_bullish:
            if not (
                indicator_series[bar_idx] > indicator_series[bar_idx - 1]
                or close_series[bar_idx] > close_series[bar_idx - 1]
            ):
                return 0
        else:
            if not (
                indicator_series[bar_idx] < indicator_series[bar_idx - 1]
                or close_series[bar_idx] < close_series[bar_idx - 1]
            ):
                return 0

    n_pivots = len(pivot_positions)

    for pivot_idx in range(min(maxpp, n_pivots)):
        pivot_bar = int(pivot_positions[pivot_idx])
        length = bar_idx - pivot_bar

        if length > maxbars:
            break

        if length > 5:
            # نفس شروط الديفرجنس بالظبط
            if is_bullish and is_regular:
                # Positive Regular
                div_condition = (
                    indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] < pivot_values[pivot_idx]
                )
            elif is_bullish and not is_regular:
                # Positive Hidden
                div_condition = (
                    indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] > pivot_values[pivot_idx]
                )
            elif (not is_bullish) and is_regular:
                # Negative Regular
                div_condition = (
                    indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] > pivot_values[pivot_idx]
                )
            else:
                # Negative Hidden
                div_condition = (
                    indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] < pivot_values[pivot_idx]
                )

            if div_condition:
                # خطين افتراضيين ونفس check-crossing
                slope1 = (indicator_series[bar_idx - startpoint] - indicator_series[pivot_bar]) / length
                slope2 = (close_series[bar_idx - startpoint] - close_series[pivot_bar]) / length

                virtual_line1 = indicator_series[bar_idx - startpoint]
                virtual_line2 = close_series[bar_idx - startpoint]

                valid = True
                for y in range(1 + startpoint, length):
                    virtual_line1 -= slope1
                    virtual_line2 -= slope2

                    check_idx = bar_idx - y
                    if is_bullish:
                        if (
                            indicator_series[check_idx] < virtual_line1
                            or close_series[check_idx] < virtual_line2
                        ):
                            valid = False
                            break
                    else:
                        if (
                            indicator_series[check_idx] > virtual_line1
                            or close_series[check_idx] > virtual_line2
                        ):
                            valid = False
                            break

                if valid:
                    return length

    return 0


@njit
def scan_divergences_for_indicator_core(
    indicator_series,
    close_series,
    low_series,
    high_series,
    pivot_high_series,
    pivot_low_series,
    prd,
    searchdiv_code,      # 0 = Regular, 1 = Hidden, 2 = Regular/Hidden
    maxpp,
    maxbars,
    dontconfirm,
    price_source_code    # 0 = Close, 1 = High/Low
):
    n = len(close_series)

    # هنرجّع 4 arrays: لكل نوع ديفرجنس
    pos_reg = np.zeros(n, dtype=np.int16)
    neg_reg = np.zeros(n, dtype=np.int16)
    pos_hid = np.zeros(n, dtype=np.int16)
    neg_hid = np.zeros(n, dtype=np.int16)

    use_reg = (searchdiv_code == 0 or searchdiv_code == 2)
    use_hid = (searchdiv_code == 1 or searchdiv_code == 2)

    for bar_idx in range(prd + 10, n):
        val = indicator_series[bar_idx]
        if np.isnan(val):
            continue

        # نبني pivots حوالين الشمعة دي (بالظبط زي اللوب الأصلي لكن جوّه Numba)
        # low pivots (للـ bullish)
        pivot_low_pos = np.empty(maxpp, dtype=np.float64)
        pivot_low_val = np.empty(maxpp, dtype=np.float64)
        low_count = 0

        stop = max(0, bar_idx - maxbars)
        for j in range(bar_idx - 1, stop, -1):  # نفس range القديم
            v = pivot_low_series[j]
            if not np.isnan(v):
                pivot_low_pos[low_count] = j
                pivot_low_val[low_count] = v
                low_count += 1
                if low_count >= maxpp:
                    break

        # high pivots (للـ bearish)
        pivot_high_pos = np.empty(maxpp, dtype=np.float64)
        pivot_high_val = np.empty(maxpp, dtype=np.float64)
        high_count = 0

        for j in range(bar_idx - 1, stop, -1):
            v = pivot_high_series[j]
            if not np.isnan(v):
                pivot_high_pos[high_count] = j
                pivot_high_val[high_count] = v
                high_count += 1
                if high_count >= maxpp:
                    break

        # === نفس النداءات اللي كنت بتعملها في scan_all_divergences القديم ===

        # Positive Regular (bullish, regular)
        if use_reg and low_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_low_pos[:low_count],
                pivot_low_val[:low_count],
                True,
                True,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                pos_reg[bar_idx] = div_len

        # Negative Regular (bearish, regular)
        if use_reg and high_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_high_pos[:high_count],
                pivot_high_val[:high_count],
                False,
                True,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                neg_reg[bar_idx] = div_len

        # Positive Hidden (bullish, hidden)
        if use_hid and low_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_low_pos[:low_count],
                pivot_low_val[:low_count],
                True,
                False,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                pos_hid[bar_idx] = div_len

        # Negative Hidden (bearish, hidden)
        if use_hid and high_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_high_pos[:high_count],
                pivot_high_val[:high_count],
                False,
                False,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                neg_hid[bar_idx] = div_len

    return pos_reg, neg_reg, pos_hid, neg_hid


def scan_all_divergences(df):
    """Scan for all divergences across all indicators (Numba-accelerated core)"""
    print("Scanning for divergences...")

    div_cols = []
    indicators_to_check = []

    if config.calcmacd:
        indicators_to_check.append('macd')
    if config.calcmacda:
        indicators_to_check.append('macd_hist')
    if config.calcrsi:
        indicators_to_check.append('rsi')
    if config.calcstoc:
        indicators_to_check.append('stoch')
    if config.calccci:
        indicators_to_check.append('cci')
    if config.calcmom:
        indicators_to_check.append('momentum')
    if config.calcobv:
        indicators_to_check.append('obv')
    if config.calcvwmacd:
        indicators_to_check.append('vwmacd')
    if config.calccmf:
        indicators_to_check.append('cmf')
    if config.calcmfi:
        indicators_to_check.append('mfi')

    # جهّز الأعمدة (نفس الأسامي القديمة بالظبط)
    for ind in indicators_to_check:
        for div_type in ['pos_reg', 'neg_reg', 'pos_hid', 'neg_hid']:
            col_name = f'{ind}_{div_type}'
            df[col_name] = 0
            div_cols.append(col_name)

    if not indicators_to_check:
        df['total_divergences'] = 0
        df['pos_div_count'] = 0
        df['neg_div_count'] = 0
        print("No indicators selected for divergence scanning")
        return df

    # Arrays مشتركة
    close_arr = df['close'].astype(float).values
    low_arr   = df['low'].astype(float).values
    high_arr  = df['high'].astype(float).values
    pivot_high_arr = df['pivot_high'].astype(float).values
    pivot_low_arr  = df['pivot_low'].astype(float).values

    # Encode config.searchdiv => رقم
    if config.searchdiv == "Regular":
        searchdiv_code = 0
    elif config.searchdiv == "Hidden":
        searchdiv_code = 1
    else:  # "Regular/Hidden"
        searchdiv_code = 2

    # Encode source => رقم
    price_source_code = 0 if config.source == "Close" else 1

    # ننده الـ core لكل indicator لوحده
    for ind in indicators_to_check:
        ind_arr = df[ind].astype(float).values

        pos_reg_arr, neg_reg_arr, pos_hid_arr, neg_hid_arr = scan_divergences_for_indicator_core(
            ind_arr,
            close_arr,
            low_arr,
            high_arr,
            pivot_high_arr,
            pivot_low_arr,
            config.prd,
            searchdiv_code,
            config.maxpp,
            config.maxbars,
            config.dontconfirm,
            price_source_code
        )

        df[f'{ind}_pos_reg'] = pos_reg_arr
        df[f'{ind}_neg_reg'] = neg_reg_arr
        df[f'{ind}_pos_hid'] = pos_hid_arr
        df[f'{ind}_neg_hid'] = neg_hid_arr

    # نفس البوست-بروسسينج القديم بالظبط 👇

    # Count total divergences
    df['total_divergences'] = 0
    for col in div_cols:
        df['total_divergences'] += (df[col] > 0).astype(int)

    # Filter by minimum divergences
    df.loc[df['total_divergences'] < config.showlimit, div_cols] = 0

    # Count positive and negative divergences
    df['pos_div_count'] = 0
    df['neg_div_count'] = 0

    for col in div_cols:
        if 'pos_' in col:
            df['pos_div_count'] += (df[col] > 0).astype(int)
        else:
            df['neg_div_count'] += (df[col] > 0).astype(int)

    total_divs = (df['total_divergences'] > 0).sum()
    print(f"Found {total_divs} bars with divergences")

    return df



#------------------------------------------------------------------------------
# TRADING STRATEGY
#------------------------------------------------------------------------------

def run_strategy(df):
    """Execute trading strategy based on divergences (optimized loop over NumPy arrays)"""
    print("Running strategy...")

    n = len(df)

    # نشتغل على NumPy arrays بدل iloc/loc جوه اللوب
    close_arr = df['close'].values
    open_arr  = df['open'].values
    pos_div   = df['pos_div_count'].values
    neg_div   = df['neg_div_count'].values

    # نجهز الـ outputs كـ arrays
    signal_arr      = np.zeros(n, dtype=np.int8)
    position_arr    = np.zeros(n, dtype=np.int8)
    entry_price_arr = np.full(n, np.nan, dtype=float)
    exit_price_arr  = np.full(n, np.nan, dtype=float)

    # نفس المتغيرات اللي فوق بس على scalars بسيطة
    buy_signal_bar   = -1
    buy_signal_price = 0.0
    sell_signal_bar  = -1
    in_position      = False

    min_pos_div = config.minPosDivForEntry
    min_neg_div = config.minNegDivForExit
    delay_bars  = max(1, config.delayBars)
    use_dd      = config.useDrawdown
    dd_perc     = config.drawdownPerc

    for i in range(n):
        # -------------------------
        # 1) Entry signal detection
        # -------------------------
        if (not in_position) and (pos_div[i] >= min_pos_div):
            buy_signal_bar   = i
            buy_signal_price = close_arr[i]

        # Process entry after delay
        if (buy_signal_bar != -1) and (not in_position):
            bars_since_signal = i - buy_signal_bar

            if bars_since_signal >= delay_bars:
                enter_trade = True

                if use_dd and i > 0:  # نفس الشرط القديم فعلياً (لأن delay_bars >= 1)
                    cur_drawdown = (buy_signal_price - close_arr[i-1]) / buy_signal_price * 100.0
                    if cur_drawdown < dd_perc:
                        enter_trade = False

                if enter_trade:
                    signal_arr[i]      = 1
                    entry_price_arr[i] = open_arr[i]  # Next bar's open
                    in_position        = True
                    buy_signal_bar     = -1
                    buy_signal_price   = 0.0

        # -------------------------
        # 2) Maintain position flag
        # -------------------------
        if in_position:
            position_arr[i] = 1

        # -------------------------
        # 3) Exit signal detection
        # -------------------------
        if in_position and (neg_div[i] >= min_neg_div):
            sell_signal_bar = i  # Mark the signal bar

        # Process exit at NEXT bar's open
        if (sell_signal_bar != -1) and in_position:
            bars_since_exit_signal = i - sell_signal_bar
            if bars_since_exit_signal >= 1:
                signal_arr[i]    = -1
                exit_price_arr[i] = open_arr[i]  # Next bar's open
                in_position       = False
                sell_signal_bar   = -1

    # نرجّع النتائج للـ DataFrame بنفس الأعمدة القديمة
    df['signal']      = signal_arr
    df['position']    = position_arr
    df['entry_price'] = entry_price_arr
    df['exit_price']  = exit_price_arr

    return df


#------------------------------------------------------------------------------
# VISUALIZATION
#------------------------------------------------------------------------------

def plot_candlestick_with_signals(df):
    """Create interactive candlestick chart with entry/exit signals"""
    print("Creating candlestick chart...")

    # Create figure with subplots
    fig = make_subplots(
        rows=2, cols=1,
        shared_xaxes=True,
        vertical_spacing=0.03,
        subplot_titles=('Price with Entry/Exit Signals', 'Divergence Counts'),
        row_heights=[0.7, 0.3]
    )

    # Add candlestick
    fig.add_trace(
        go.Candlestick(
            x=df.index,
            open=df['open'],
            high=df['high'],
            low=df['low'],
            close=df['close'],
            name='Price',
            increasing_line_color='green',
            decreasing_line_color='red'
        ),
        row=1, col=1
    )

    # Add entry signals (buy)
    entries = df[df['signal'] == 1]
    if len(entries) > 0:
        fig.add_trace(
            go.Scatter(
                x=entries.index,
                y=entries['entry_price'],
                mode='markers',
                name='BUY',
                marker=dict(
                    symbol='triangle-up',
                    size=15,
                    color='lime',
                    line=dict(color='darkgreen', width=2)
                )
            ),
            row=1, col=1
        )

    # Add exit signals (sell)
    exits = df[df['signal'] == -1]
    if len(exits) > 0:
        fig.add_trace(
            go.Scatter(
                x=exits.index,
                y=exits['exit_price'],
                mode='markers',
                name='SELL',
                marker=dict(
                    symbol='triangle-down',
                    size=15,
                    color='red',
                    line=dict(color='darkred', width=2)
                )
            ),
            row=1, col=1
        )

    # Add positive divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['pos_div_count'],
            mode='lines',
            name='Positive Divergences',
            line=dict(color='green', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add negative divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['neg_div_count'],
            mode='lines',
            name='Negative Divergences',
            line=dict(color='red', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add threshold lines
    fig.add_hline(
        y=config.minPosDivForEntry,
        line_dash="dash",
        line_color="green",
        annotation_text=f"Entry Threshold ({config.minPosDivForEntry})",
        row=2, col=1
    )

    fig.add_hline(
        y=config.minNegDivForExit,
        line_dash="dash",
        line_color="red",
        annotation_text=f"Exit Threshold ({config.minNegDivForExit})",
        row=2, col=1
    )

    # Update layout
    fig.update_layout(
        title='Divergence-Based Trading Strategy',
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis2_title='Time',
        yaxis2_title='Divergence Count',
        height=900,
        showlegend=True,
        xaxis_rangeslider_visible=False
    )

    fig.show()
    print("Chart displayed successfully")

#------------------------------------------------------------------------------
# PERFORMANCE METRICS
#------------------------------------------------------------------------------

def calculate_performance(df):
    """Calculate and display performance metrics"""
    print("\n" + "="*60)
    print("PERFORMANCE METRICS")
    print("="*60)

    entries = df[df['signal'] == 1].copy()
    exits = df[df['signal'] == -1].copy()

    if len(entries) == 0:
        print("No trades were executed")
        return

    # Match entries with exits
    trades = []
    for i, entry_row in entries.iterrows():
        entry_idx = df.index.get_loc(i)
        entry_price = entry_row['entry_price']

        # Find next exit
        exit_found = False
        for j, exit_row in exits.iterrows():
            exit_idx = df.index.get_loc(j)
            if exit_idx > entry_idx:
                exit_price = exit_row['exit_price']
                pnl_pct = (exit_price - entry_price) / entry_price * 100
                trades.append({
                    'entry_time': i,
                    'exit_time': j,
                    'entry_price': entry_price,
                    'exit_price': exit_price,
                    'pnl_pct': pnl_pct,
                    'bars_held': exit_idx - entry_idx,
                    'entry_idx': entry_idx  # Store index for indicator lookup
                })
                exit_found = True
                break

        if not exit_found:
            # Still in trade
            trades.append({
                'entry_time': i,
                'exit_time': None,
                'entry_price': entry_price,
                'exit_price': df['close'].iloc[-1],
                'pnl_pct': (df['close'].iloc[-1] - entry_price) / entry_price * 100,
                'bars_held': len(df) - entry_idx - 1,
                'entry_idx': entry_idx
            })

    trades_df = pd.DataFrame(trades)

    # Calculate metrics
    total_trades = len(trades_df)
    winning_trades = len(trades_df[trades_df['pnl_pct'] > 0])
    losing_trades = len(trades_df[trades_df['pnl_pct'] < 0])
    win_rate = (winning_trades / total_trades * 100) if total_trades > 0 else 0
    avg_win = trades_df[trades_df['pnl_pct'] > 0]['pnl_pct'].mean() if winning_trades > 0 else 0
    avg_loss = trades_df[trades_df['pnl_pct'] < 0]['pnl_pct'].mean() if losing_trades > 0 else 0
    avg_pnl = trades_df['pnl_pct'].mean()
    total_return = trades_df['pnl_pct'].sum()
    avg_bars_held = trades_df['bars_held'].mean()

    # Display metrics
    print(f"Total Trades:       {total_trades}")
    print(f"Winning Trades:     {winning_trades}")
    print(f"Losing Trades:      {losing_trades}")
    print(f"Win Rate:           {win_rate:.2f}%")
    print(f"Average Win:        {avg_win:.2f}%")
    print(f"Average Loss:       {avg_loss:.2f}%")
    print(f"Average P&L:        {avg_pnl:.2f}%")
    print(f"Total Return:       {total_return:.2f}%")
    print(f"Avg Bars Held:      {avg_bars_held:.1f}")

    print("\n" + "="*60)

    # Display trade list with indicator values
    print("\nDETAILED TRADE ANALYSIS WITH INDICATORS:")
    print("="*60)

    for idx, trade in trades_df.iterrows():
        status = "CLOSED" if trade['exit_time'] is not None else "OPEN"
        entry_idx = trade['entry_idx']

        print(f"\n{'='*60}")
        print(f"Trade #{idx+1} [{status}]")
        print(f"{'='*60}")

        # Price information
        print(f"\n📊 PRICE INFORMATION:")
        print(f"  Entry Time:      {trade['entry_time']}")
        print(f"  Entry Price:     ${trade['entry_price']:.2f}")
        print(f"  Open:            ${df['open'].iloc[entry_idx]:.2f}")
        print(f"  High:            ${df['high'].iloc[entry_idx]:.2f}")
        print(f"  Low:             ${df['low'].iloc[entry_idx]:.2f}")
        print(f"  Close:           ${df['close'].iloc[entry_idx]:.2f}")

        if trade['exit_time'] is not None:
            print(f"  Exit Time:       {trade['exit_time']}")
            print(f"  Exit Price:      ${trade['exit_price']:.2f}")
        else:
            print(f"  Current Price:   ${trade['exit_price']:.2f}")

        print(f"  P&L:             {trade['pnl_pct']:+.2f}%")
        print(f"  Duration:        {int(trade['bars_held'])} bars")

        # Divergence counts
        print(f"\n🔍 DIVERGENCE SIGNALS:")
        print(f"  Positive Divs:   {int(df['pos_div_count'].iloc[entry_idx])}")
        print(f"  Negative Divs:   {int(df['neg_div_count'].iloc[entry_idx])}")
        print(f"  Total Divs:      {int(df['total_divergences'].iloc[entry_idx])}")

        # Technical indicators
        print(f"\n📈 TECHNICAL INDICATORS AT ENTRY:")

        # Momentum indicators
        if config.calcrsi:
            print(f"  RSI (14):        {df['rsi'].iloc[entry_idx]:.2f}")

        if config.calcstoc:
            print(f"  Stochastic:      {df['stoch'].iloc[entry_idx]:.2f}")

        if config.calcmom:
            print(f"  Momentum (10):   {df['momentum'].iloc[entry_idx]:.2f}")

        if config.calccci:
            print(f"  CCI (10):        {df['cci'].iloc[entry_idx]:.2f}")

        # Trend indicators
        if config.calcmacd:
            print(f"  MACD:            {df['macd'].iloc[entry_idx]:.4f}")
            print(f"  MACD Signal:     {df['macd_signal'].iloc[entry_idx]:.4f}")

        if config.calcmacda:
            print(f"  MACD Histogram:  {df['macd_hist'].iloc[entry_idx]:.4f}")

        # Volume indicators
        if config.calcobv:
            print(f"  OBV:             {df['obv'].iloc[entry_idx]:,.0f}")

        if config.calcvwmacd:
            print(f"  VWMACD:          {df['vwmacd'].iloc[entry_idx]:.4f}")

        if config.calccmf:
            print(f"  CMF (21):        {df['cmf'].iloc[entry_idx]:.4f}")

        if config.calcmfi:
            print(f"  MFI (14):        {df['mfi'].iloc[entry_idx]:.2f}")

        # Individual divergences detected
        print(f"\n🎯 SPECIFIC DIVERGENCES DETECTED:")
        divergence_found = False

        # Check each indicator's divergences
        indicators_list = []
        if config.calcmacd:
            indicators_list.append(('MACD', 'macd'))
        if config.calcmacda:
            indicators_list.append(('MACD Hist', 'macd_hist'))
        if config.calcrsi:
            indicators_list.append(('RSI', 'rsi'))
        if config.calcstoc:
            indicators_list.append(('Stochastic', 'stoch'))
        if config.calccci:
            indicators_list.append(('CCI', 'cci'))
        if config.calcmom:
            indicators_list.append(('Momentum', 'momentum'))
        if config.calcobv:
            indicators_list.append(('OBV', 'obv'))
        if config.calcvwmacd:
            indicators_list.append(('VWMACD', 'vwmacd'))
        if config.calccmf:
            indicators_list.append(('CMF', 'cmf'))
        if config.calcmfi:
            indicators_list.append(('MFI', 'mfi'))

        for ind_name, ind_col in indicators_list:
            divs = []
            if f'{ind_col}_pos_reg' in df.columns and df[f'{ind_col}_pos_reg'].iloc[entry_idx] > 0:
                divs.append(f"Pos Regular ({int(df[f'{ind_col}_pos_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_reg' in df.columns and df[f'{ind_col}_neg_reg'].iloc[entry_idx] > 0:
                divs.append(f"Neg Regular ({int(df[f'{ind_col}_neg_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_pos_hid' in df.columns and df[f'{ind_col}_pos_hid'].iloc[entry_idx] > 0:
                divs.append(f"Pos Hidden ({int(df[f'{ind_col}_pos_hid'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_hid' in df.columns and df[f'{ind_col}_neg_hid'].iloc[entry_idx] > 0:
                divs.append(f"Neg Hidden ({int(df[f'{ind_col}_neg_hid'].iloc[entry_idx])} bars)")
                divergence_found = True

            if divs:
                print(f"  {ind_name:15s}: {', '.join(divs)}")

        if not divergence_found:
            print(f"  No specific divergences recorded (signal from previous bar)")

    print("\n" + "="*60)
def print_bar_debug(df, idx=-1):
    """
    اطبع كل القيم لشمعة واحدة:
    - السعر
    - المؤشرات
    - البيفوتات
    - عدد الديفرجنس
    idx = -1 يعني آخر شمعة
    """
    row = df.iloc[idx]

    print("\n" + "="*80)
    print(f"DEBUG SNAPSHOT @ index {idx} | time = {row.name}")
    print("="*80)

    # السعر
    print("\n📊 PRICE:")
    print(f"  Open   : {row['open']:.4f}")
    print(f"  High   : {row['high']:.4f}")
    print(f"  Low    : {row['low']:.4f}")
    print(f"  Close  : {row['close']:.4f}")
    print(f"  Volume : {row['volume']}")

    # المؤشرات
    print("\n📈 INDICATORS:")
    print(f"  RSI(14)        : {row['rsi']:.4f}")
    print(f"  MACD(12,26,9)  : {row['macd']:.4f}")
    print(f"  MACD Signal    : {row['macd_signal']:.4f}")
    print(f"  MACD Hist      : {row['macd_hist']:.4f}")
    print(f"  Momentum(10)   : {row['momentum']:.4f}")
    print(f"  Stoch(14,3)    : {row['stoch']:.4f}")
    print(f"  CCI(10)        : {row['cci']:.4f}")
    print(f"  VW-MACD        : {row['vwmacd']:.4f}")
    print(f"  CMF(21)        : {row['cmf']:.4f}")
    print(f"  MFI(14)        : {row['mfi']:.4f}")
    print(f"  OBV            : {row['obv']:.4f}")

    # البيفوتات والديفرجنس
    print("\n📌 PIVOTS & DIVERGENCES:")
    print(f"  pivot_high       : {row.get('pivot_high', np.nan)}")
    print(f"  pivot_low        : {row.get('pivot_low', np.nan)}")
    print(f"  pos_div_count    : {row.get('pos_div_count', np.nan)}")
    print(f"  neg_div_count    : {row.get('neg_div_count', np.nan)}")
    print(f"  total_divergences: {row.get('total_divergences', np.nan)}")
    print("="*80)


def print_last_n_bars_debug(df, n=5):
    """
    اطبع snapshot لآخر n شمعات
    عشان تقارن بالـ TradingView بسهولة
    """
    start = max(0, len(df) - n)
    for i in range(start, len(df)):
        print_bar_debug(df, i)

#------------------------------------------------------------------------------
# MAIN EXECUTION
#------------------------------------------------------------------------------

def main(csv_filepath):
    """Main execution function"""

    print("="*60)
    print("DIVERGENCE-BASED TRADING STRATEGY")
    print("="*60)
    print(f"\nConfiguration:")
    print(f"  Pivot Period: {config.prd}")
    print(f"  Divergence Type: {config.searchdiv}")
    print(f"  Min Positive Divergences for Entry: {config.minPosDivForEntry}")
    print(f"  Min Negative Divergences for Exit: {config.minNegDivForExit}")
    print(f"  Entry Delay: {config.delayBars} bars")
    print("\n" + "="*60 + "\n")

    # Load data
    df = load_data_from_csv(csv_filepath)

    # Calculate indicators
    df = calculate_indicators(df)

    # Find pivot points
    df = find_pivots(df, config.prd)

    # Scan for divergences
    df = scan_all_divergences(df)

    # Run strategy
    df = run_strategy(df)

    # Calculate performance
    calculate_performance(df)

    # Plot results
    #plot_candlestick_with_signals(df)

    return df

# ============================================================================
# RUN THE STRATEGY
# ============================================================================

# Upload your CSV file to Colab first, then specify the path
# Example: df_result = main('/content/your_data.csv')

# For Google Colab, you can upload a file like this:
# from google.colab import files
# uploaded = files.upload()

# Get the uploaded filename
csv_filename = 'XAU.csv'

# Run the strategy
df_result = main(csv_filename)
print_last_n_bars_debug(df_result, n=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# ============================================================
# Trade #26 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-05 09:00:00-05:00
#   Entry Price:     $2899.89
#   Open:            $2899.89
#   High:            $2906.48
#   Low:             $2899.15
#   Close:           $2902.13
#   Exit Time:       2025-03-05 11:00:00-05:00
#   Exit Price:      $2917.02
#   P&L:             +0.59%
#   Duration:        8 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        32.66
#   Stochastic:      20.82
#   Momentum (10):   -13.08
#   CCI (10):        -93.97
#   MACD:            -2.9496
#   MACD Signal:     -1.1361
#   MACD Histogram:  -1.8135
#   VWMACD:          -4.3297
#   CMF (21):        -0.1078
#   MFI (14):        47.10
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #27 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-05 20:15:00-05:00
#   Entry Price:     $2918.42
#   Open:            $2918.42
#   High:            $2918.95
#   Low:             $2918.01
#   Close:           $2918.84
#   Exit Time:       2025-03-06 08:30:00-05:00
#   Exit Price:      $2904.58
#   P&L:             -0.47%
#   Duration:        49 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.61
#   Stochastic:      28.96
#   Momentum (10):   -0.41
#   CCI (10):        80.15
#   MACD:            0.0296
#   MACD Signal:     0.2196
#   MACD Histogram:  -0.1900
#   VWMACD:          -0.1150
#   CMF (21):        0.2176
#   MFI (14):        54.15
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #28 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-07 13:00:00-05:00
#   Entry Price:     $2908.20
#   Open:            $2908.20
#   High:            $2908.64
#   Low:             $2905.35
#   Close:           $2905.95
#   Exit Time:       2025-03-10 03:15:00-04:00
#   Exit Price:      $2912.93
#   P&L:             +0.16%
#   Duration:        52 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.10
#   Stochastic:      8.68
#   Momentum (10):   -8.34
#   CCI (10):        -109.05
#   MACD:            -2.7101
#   MACD Signal:     -1.2948
#   MACD Histogram:  -1.4153
#   VWMACD:          -3.4031
#   CMF (21):        0.0195
#   MFI (14):        51.05
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #29 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-10 05:15:00-04:00
#   Entry Price:     $2908.47
#   Open:            $2908.47
#   High:            $2913.13
#   Low:             $2907.33
#   Close:           $2912.43
#   Exit Time:       2025-03-11 03:15:00-04:00
#   Exit Price:      $2899.68
#   P&L:             -0.30%
#   Duration:        84 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        54.56
#   Stochastic:      49.84
#   Momentum (10):   -1.76
#   CCI (10):        65.27
#   MACD:            -1.4811
#   MACD Signal:     -1.2294
#   MACD Histogram:  -0.2516
#   VWMACD:          -1.0019
#   CMF (21):        -0.0106
#   MFI (14):        41.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #30 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-12 03:45:00-04:00
#   Entry Price:     $2912.62
#   Open:            $2912.62
#   High:            $2915.54
#   Low:             $2912.31
#   Close:           $2914.36
#   Exit Time:       2025-03-12 05:15:00-04:00
#   Exit Price:      $2919.47
#   P&L:             +0.24%
#   Duration:        6 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        49.65
#   Stochastic:      31.55
#   Momentum (10):   1.30
#   CCI (10):        10.06
#   MACD:            -0.7576
#   MACD Signal:     -0.5333
#   MACD Histogram:  -0.2242
#   VWMACD:          -0.9065
#   CMF (21):        -0.0713
#   MFI (14):        40.32
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #31 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-12 09:45:00-04:00
#   Entry Price:     $2912.01
#   Open:            $2912.01
#   High:            $2917.50
#   Low:             $2911.60
#   Close:           $2915.61
#   Exit Time:       2025-03-12 11:30:00-04:00
#   Exit Price:      $2923.80
#   P&L:             +0.40%
#   Duration:        7 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.24
#   Stochastic:      40.45
#   Momentum (10):   2.49
#   CCI (10):        26.21
#   MACD:            -0.3058
#   MACD Signal:     -0.1801
#   MACD Histogram:  -0.1258
#   VWMACD:          -0.6029
#   CMF (21):        -0.0235
#   MFI (14):        53.88
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #32 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-13 23:15:00-04:00
#   Entry Price:     $2985.62
#   Open:            $2985.62
#   High:            $2988.24
#   Low:             $2984.97
#   Close:           $2987.30
#   Exit Time:       2025-03-14 00:15:00-04:00
#   Exit Price:      $2992.55
#   P&L:             +0.23%
#   Duration:        4 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        56.00
#   Stochastic:      47.10
#   Momentum (10):   0.65
#   CCI (10):        27.12
#   MACD:            1.6117
#   MACD Signal:     2.3161
#   MACD Histogram:  -0.7044
#   VWMACD:          0.3117
#   CMF (21):        0.1406
#   MFI (14):        60.30
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #33 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-14 01:45:00-04:00
#   Entry Price:     $2984.54
#   Open:            $2984.54
#   High:            $2986.74
#   Low:             $2981.93
#   Close:           $2986.38
#   Exit Time:       2025-03-14 06:00:00-04:00
#   Exit Price:      $2998.67
#   P&L:             +0.47%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.91
#   Stochastic:      25.17
#   Momentum (10):   -0.92
#   CCI (10):        -31.99
#   MACD:            0.5259
#   MACD Signal:     1.2914
#   MACD Histogram:  -0.7655
#   VWMACD:          0.3090
#   CMF (21):        0.1798
#   MFI (14):        57.25
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #34 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-19 05:15:00-04:00
#   Entry Price:     $3025.71
#   Open:            $3025.71
#   High:            $3028.47
#   Low:             $3025.48
#   Close:           $3027.96
#   Exit Time:       2025-03-19 14:30:00-04:00
#   Exit Price:      $3037.53
#   P&L:             +0.39%
#   Duration:        37 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.07
#   Stochastic:      13.23
#   Momentum (10):   -14.26
#   CCI (10):        -64.99
#   MACD:            -1.9388
#   MACD Signal:     -0.2755
#   MACD Histogram:  -1.6633
#   VWMACD:          -1.6045
#   CMF (21):        -0.0876
#   MFI (14):        38.34
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #35 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-20 03:30:00-04:00
#   Entry Price:     $3046.72
#   Open:            $3046.72
#   High:            $3047.70
#   Low:             $3044.58
#   Close:           $3045.02
#   Exit Time:       2025-03-20 12:30:00-04:00
#   Exit Price:      $3038.51
#   P&L:             -0.27%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.08
#   Stochastic:      12.50
#   Momentum (10):   -6.87
#   CCI (10):        -131.60
#   MACD:            -0.5245
#   MACD Signal:     0.1557
#   MACD Histogram:  -0.6802
#   VWMACD:          -1.1829
#   CMF (21):        0.0769
#   MFI (14):        49.41
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #36 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-23 23:15:00-04:00
#   Entry Price:     $3017.03
#   Open:            $3017.03
#   High:            $3019.68
#   Low:             $3016.72
#   Close:           $3017.76
#   Exit Time:       2025-03-24 05:30:00-04:00
#   Exit Price:      $3029.31
#   P&L:             +0.41%
#   Duration:        25 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        43.46
#   Stochastic:      27.69
#   Momentum (10):   -0.57
#   CCI (10):        -67.45
#   MACD:            -0.8659
#   MACD Signal:     -0.1060
#   MACD Histogram:  -0.7599
#   VWMACD:          -0.8413
#   CMF (21):        -0.1035
#   MFI (14):        45.91
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #37 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-24 23:15:00-04:00
#   Entry Price:     $3012.46
#   Open:            $3012.46
#   High:            $3014.76
#   Low:             $3012.15
#   Close:           $3014.28
#   Exit Time:       2025-03-25 00:00:00-04:00
#   Exit Price:      $3015.08
#   P&L:             +0.09%
#   Duration:        3 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        57.36
#   Stochastic:      61.74
#   Momentum (10):   0.16
#   CCI (10):        125.12
#   MACD:            0.2471
#   MACD Signal:     0.0609
#   MACD Histogram:  0.1862
#   VWMACD:          0.3570
#   CMF (21):        0.0245
#   MFI (14):        41.99
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #38 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-25 21:00:00-04:00
#   Entry Price:     $3018.06
#   Open:            $3018.06
#   High:            $3018.81
#   Low:             $3016.24
#   Close:           $3018.63
#   Exit Time:       2025-03-25 22:15:00-04:00
#   Exit Price:      $3025.09
#   P&L:             +0.23%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.21
#   Stochastic:      16.12
#   Momentum (10):   -2.20
#   CCI (10):        -88.40
#   MACD:            -0.6038
#   MACD Signal:     -0.3878
#   MACD Histogram:  -0.2159
#   VWMACD:          -0.3018
#   CMF (21):        0.1202
#   MFI (14):        60.42
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #39 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-26 00:15:00-04:00
#   Entry Price:     $3016.83
#   Open:            $3016.83
#   High:            $3017.60
#   Low:             $3015.35
#   Close:           $3015.55
#   Exit Time:       2025-03-26 03:30:00-04:00
#   Exit Price:      $3026.27
#   P&L:             +0.31%
#   Duration:        13 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.65
#   Stochastic:      7.28
#   Momentum (10):   -9.30
#   CCI (10):        -105.68
#   MACD:            -0.8996
#   MACD Signal:     -0.1666
#   MACD Histogram:  -0.7330
#   VWMACD:          0.8339
#   CMF (21):        0.0070
#   MFI (14):        53.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #40 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-26 10:15:00-04:00
#   Entry Price:     $3017.98
#   Open:            $3017.98
#   High:            $3018.43
#   Low:             $3014.87
#   Close:           $3015.34
#   Exit Time:       2025-03-26 19:45:00-04:00
#   Exit Price:      $3020.35
#   P&L:             +0.08%
#   Duration:        34 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.18
#   Stochastic:      10.16
#   Momentum (10):   -12.11
#   CCI (10):        -127.29
#   MACD:            -1.1416
#   MACD Signal:     0.1539
#   MACD Histogram:  -1.2955
#   VWMACD:          0.0714
#   CMF (21):        -0.0127
#   MFI (14):        30.85
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #41 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-28 11:15:00-04:00
#   Entry Price:     $3074.76
#   Open:            $3074.76
#   High:            $3081.20
#   Low:             $3074.59
#   Close:           $3079.80
#   Exit Time:       2025-03-28 12:15:00-04:00
#   Exit Price:      $3083.74
#   P&L:             +0.29%
#   Duration:        4 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        54.97
#   Stochastic:      37.69
#   Momentum (10):   2.44
#   CCI (10):        78.10
#   MACD:            0.3795
#   MACD Signal:     0.5686
#   MACD Histogram:  -0.1891
#   VWMACD:          0.5029
#   CMF (21):        0.1115
#   MFI (14):        36.82
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #42 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-01 09:45:00-04:00
#   Entry Price:     $3132.08
#   Open:            $3132.08
#   High:            $3134.40
#   Low:             $3130.76
#   Close:           $3133.33
#   Exit Time:       2025-04-01 20:45:00-04:00
#   Exit Price:      $3120.62
#   P&L:             -0.37%
#   Duration:        40 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.57
#   Stochastic:      36.17
#   Momentum (10):   2.59
#   CCI (10):        50.90
#   MACD:            -0.4623
#   MACD Signal:     -0.5481
#   MACD Histogram:  0.0858
#   VWMACD:          0.2544
#   CMF (21):        0.1216
#   MFI (14):        64.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #43 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-02 14:45:00-04:00
#   Entry Price:     $3122.69
#   Open:            $3122.69
#   High:            $3123.47
#   Low:             $3120.99
#   Close:           $3121.88
#   Exit Time:       2025-04-02 16:45:00-04:00
#   Exit Price:      $3130.62
#   P&L:             +0.25%
#   Duration:        8 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.58
#   Stochastic:      16.73
#   Momentum (10):   -10.65
#   CCI (10):        -61.77
#   MACD:            -0.6336
#   MACD Signal:     0.2759
#   MACD Histogram:  -0.9095
#   VWMACD:          0.9784
#   CMF (21):        0.0437
#   MFI (14):        35.04
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #44 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-03 13:45:00-04:00
#   Entry Price:     $3106.52
#   Open:            $3106.52
#   High:            $3109.81
#   Low:             $3106.00
#   Close:           $3109.47
#   Exit Time:       2025-04-03 18:00:00-04:00
#   Exit Price:      $3115.05
#   P&L:             +0.27%
#   Duration:        13 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        52.11
#   Stochastic:      25.48
#   Momentum (10):   3.22
#   CCI (10):        45.33
#   MACD:            0.2943
#   MACD Signal:     -0.2203
#   MACD Histogram:  0.5146
#   VWMACD:          10.6825
#   CMF (21):        0.1688
#   MFI (14):        32.48
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #45 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-04 05:00:00-04:00
#   Entry Price:     $3084.05
#   Open:            $3084.05
#   High:            $3092.38
#   Low:             $3083.74
#   Close:           $3090.86
#   Exit Time:       2025-04-04 07:00:00-04:00
#   Exit Price:      $3110.19
#   P&L:             +0.85%
#   Duration:        8 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.58
#   Stochastic:      24.49
#   Momentum (10):   -10.33
#   CCI (10):        -12.69
#   MACD:            -4.7992
#   MACD Signal:     -3.5430
#   MACD Histogram:  -1.2563
#   VWMACD:          -2.9831
#   CMF (21):        -0.0661
#   MFI (14):        29.37
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #46 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-04 09:15:00-04:00
#   Entry Price:     $3082.22
#   Open:            $3082.22
#   High:            $3087.33
#   Low:             $3075.51
#   Close:           $3075.72
#   Exit Time:       2025-04-07 07:30:00-04:00
#   Exit Price:      $3040.25
#   P&L:             -1.36%
#   Duration:        84 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.14
#   Stochastic:      10.47
#   Momentum (10):   -34.47
#   CCI (10):        -89.14
#   MACD:            -4.4205
#   MACD Signal:     -0.8240
#   MACD Histogram:  -3.5964
#   VWMACD:          3.1052
#   CMF (21):        0.0223
#   MFI (14):        48.27
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #47 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-08 20:00:00-04:00
#   Entry Price:     $2978.32
#   Open:            $2978.32
#   High:            $2984.75
#   Low:             $2974.60
#   Close:           $2977.73
#   Exit Time:       2025-04-09 01:15:00-04:00
#   Exit Price:      $3015.63
#   P&L:             +1.25%
#   Duration:        21 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.57
#   Stochastic:      32.12
#   Momentum (10):   -2.93
#   CCI (10):        -78.24
#   MACD:            -3.8497
#   MACD Signal:     -4.1391
#   MACD Histogram:  0.2894
#   VWMACD:          -2.5186
#   CMF (21):        -0.0809
#   MFI (14):        46.28
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #48 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-11 07:15:00-04:00
#   Entry Price:     $3221.18
#   Open:            $3221.18
#   High:            $3223.83
#   Low:             $3216.85
#   Close:           $3220.57
#   Exit Time:       2025-04-11 10:00:00-04:00
#   Exit Price:      $3223.44
#   P&L:             +0.07%
#   Duration:        11 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        54.10
#   Stochastic:      38.92
#   Momentum (10):   4.83
#   CCI (10):        -12.73
#   MACD:            4.0984
#   MACD Signal:     4.5628
#   MACD Histogram:  -0.4644
#   VWMACD:          9.1999
#   CMF (21):        0.1530
#   MFI (14):        56.04
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #49 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-14 07:00:00-04:00
#   Entry Price:     $3215.26
#   Open:            $3215.26
#   High:            $3223.01
#   Low:             $3213.88
#   Close:           $3223.01
#   Exit Time:       2025-04-14 19:00:00-04:00
#   Exit Price:      $3212.19
#   P&L:             -0.10%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        49.24
#   Stochastic:      35.33
#   Momentum (10):   1.01
#   CCI (10):        29.67
#   MACD:            -3.4837
#   MACD Signal:     -2.6587
#   MACD Histogram:  -0.8250
#   VWMACD:          -4.5734
#   CMF (21):        -0.1010
#   MFI (14):        38.72
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #50 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-15 07:15:00-04:00
#   Entry Price:     $3221.74
#   Open:            $3221.74
#   High:            $3222.76
#   Low:             $3219.50
#   Close:           $3220.17
#   Exit Time:       2025-04-15 15:30:00-04:00
#   Exit Price:      $3226.70
#   P&L:             +0.15%
#   Duration:        33 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        43.01
#   Stochastic:      18.03
#   Momentum (10):   -7.36
#   CCI (10):        -105.09
#   MACD:            -0.4956
#   MACD Signal:     0.4381
#   MACD Histogram:  -0.9337
#   VWMACD:          -0.6208
#   CMF (21):        0.0384
#   MFI (14):        36.52
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #51 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-17 03:45:00-04:00
#   Entry Price:     $3323.21
#   Open:            $3323.21
#   High:            $3324.31
#   Low:             $3320.21
#   Close:           $3323.36
#   Exit Time:       2025-04-17 07:00:00-04:00
#   Exit Price:      $3327.58
#   P&L:             +0.13%
#   Duration:        13 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.60
#   Stochastic:      22.35
#   Momentum (10):   -13.46
#   CCI (10):        -50.47
#   MACD:            -4.7502
#   MACD Signal:     -3.3028
#   MACD Histogram:  -1.4473
#   VWMACD:          -5.1958
#   CMF (21):        0.0346
#   MFI (14):        37.67
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #52 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-17 09:45:00-04:00
#   Entry Price:     $3329.49
#   Open:            $3329.49
#   High:            $3329.69
#   Low:             $3311.78
#   Close:           $3315.02
#   Exit Time:       2025-04-17 16:00:00-04:00
#   Exit Price:      $3320.63
#   P&L:             -0.27%
#   Duration:        25 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.35
#   Stochastic:      20.84
#   Momentum (10):   -11.81
#   CCI (10):        -188.88
#   MACD:            -1.3711
#   MACD Signal:     -1.0384
#   MACD Histogram:  -0.3327
#   VWMACD:          0.8634
#   CMF (21):        -0.1456
#   MFI (14):        36.99
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #53 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-22 05:15:00-04:00
#   Entry Price:     $3454.50
#   Open:            $3454.50
#   High:            $3458.80
#   Low:             $3453.84
#   Close:           $3456.43
#   Exit Time:       2025-04-23 07:45:00-04:00
#   Exit Price:      $3334.36
#   P&L:             -3.48%
#   Duration:        102 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.37
#   Stochastic:      15.00
#   Momentum (10):   -23.22
#   CCI (10):        -39.23
#   MACD:            -2.5245
#   MACD Signal:     1.9880
#   MACD Histogram:  -4.5125
#   VWMACD:          -9.8914
#   CMF (21):        -0.1003
#   MFI (14):        36.20
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #54 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-24 09:30:00-04:00
#   Entry Price:     $3330.57
#   Open:            $3330.57
#   High:            $3333.39
#   Low:             $3315.91
#   Close:           $3316.44
#   Exit Time:       2025-04-24 16:00:00-04:00
#   Exit Price:      $3342.11
#   P&L:             +0.35%
#   Duration:        26 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.08
#   Stochastic:      16.27
#   Momentum (10):   -17.70
#   CCI (10):        -224.73
#   MACD:            -0.6658
#   MACD Signal:     1.0939
#   MACD Histogram:  -1.7597
#   VWMACD:          -1.2293
#   CMF (21):        -0.3573
#   MFI (14):        26.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #55 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-25 06:15:00-04:00
#   Entry Price:     $3297.83
#   Open:            $3297.83
#   High:            $3304.89
#   Low:             $3295.55
#   Close:           $3304.84
#   Exit Time:       2025-04-28 11:00:00-04:00
#   Exit Price:      $3328.46
#   P&L:             +0.93%
#   Duration:        110 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        46.10
#   Stochastic:      28.48
#   Momentum (10):   -2.47
#   CCI (10):        89.70
#   MACD:            -7.1055
#   MACD Signal:     -8.4007
#   MACD Histogram:  1.2952
#   VWMACD:          -3.4630
#   CMF (21):        -0.0049
#   MFI (14):        52.56
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #56 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-29 01:30:00-04:00
#   Entry Price:     $3309.26
#   Open:            $3309.26
#   High:            $3316.53
#   Low:             $3307.60
#   Close:           $3315.73
#   Exit Time:       2025-04-29 20:30:00-04:00
#   Exit Price:      $3319.14
#   P&L:             +0.30%
#   Duration:        72 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.35
#   Stochastic:      19.49
#   Momentum (10):   2.14
#   CCI (10):        73.46
#   MACD:            -5.8846
#   MACD Signal:     -5.3735
#   MACD Histogram:  -0.5110
#   VWMACD:          -9.6870
#   CMF (21):        -0.0819
#   MFI (14):        38.29
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #57 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-29 21:15:00-04:00
#   Entry Price:     $3315.82
#   Open:            $3315.82
#   High:            $3322.74
#   Low:             $3313.92
#   Close:           $3318.73
#   Exit Time:       2025-05-01 15:00:00-04:00
#   Exit Price:      $3223.85
#   P&L:             -2.77%
#   Duration:        163 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.51
#   Stochastic:      36.25
#   Momentum (10):   -0.20
#   CCI (10):        56.56
#   MACD:            -0.4215
#   MACD Signal:     -0.2024
#   MACD Histogram:  -0.2190
#   VWMACD:          -1.3177
#   CMF (21):        -0.0136
#   MFI (14):        57.49
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #58 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-06 21:00:00-04:00
#   Entry Price:     $3379.05
#   Open:            $3379.05
#   High:            $3384.90
#   Low:             $3367.79
#   Close:           $3380.07
#   Exit Time:       2025-05-07 10:15:00-04:00
#   Exit Price:      $3385.82
#   P&L:             +0.20%
#   Duration:        53 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.25
#   Stochastic:      17.57
#   Momentum (10):   -11.25
#   CCI (10):        -51.78
#   MACD:            -7.1366
#   MACD Signal:     -3.6746
#   MACD Histogram:  -3.4620
#   VWMACD:          -11.2208
#   CMF (21):        -0.0073
#   MFI (14):        48.29
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #59 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-07 12:45:00-04:00
#   Entry Price:     $3384.65
#   Open:            $3384.65
#   High:            $3389.71
#   Low:             $3384.65
#   Close:           $3386.88
#   Exit Time:       2025-05-07 14:30:00-04:00
#   Exit Price:      $3387.16
#   P&L:             +0.07%
#   Duration:        7 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.24
#   Stochastic:      40.57
#   Momentum (10):   3.98
#   CCI (10):        113.23
#   MACD:            -0.6168
#   MACD Signal:     -0.4096
#   MACD Histogram:  -0.2072
#   VWMACD:          -2.9234
#   CMF (21):        0.0516
#   MFI (14):        60.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #60 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-07 15:00:00-04:00
#   Entry Price:     $3384.41
#   Open:            $3384.41
#   High:            $3386.73
#   Low:             $3371.83
#   Close:           $3372.71
#   Exit Time:       2025-05-07 22:15:00-04:00
#   Exit Price:      $3409.59
#   P&L:             +0.74%
#   Duration:        25 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.79
#   Stochastic:      16.18
#   Momentum (10):   -11.94
#   CCI (10):        -235.24
#   MACD:            -1.3549
#   MACD Signal:     -0.5009
#   MACD Histogram:  -0.8540
#   VWMACD:          -1.9574
#   CMF (21):        -0.1727
#   MFI (14):        42.71
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #61 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-08 12:30:00-04:00
#   Entry Price:     $3311.48
#   Open:            $3311.48
#   High:            $3314.24
#   Low:             $3306.76
#   Close:           $3308.64
#   Exit Time:       2025-05-09 01:30:00-04:00
#   Exit Price:      $3321.51
#   P&L:             +0.30%
#   Duration:        48 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        26.25
#   Stochastic:      6.64
#   Momentum (10):   -51.33
#   CCI (10):        -106.99
#   MACD:            -8.8574
#   MACD Signal:     -3.4231
#   MACD Histogram:  -5.4343
#   VWMACD:          -5.8254
#   CMF (21):        -0.0852
#   MFI (14):        34.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #62 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-09 10:30:00-04:00
#   Entry Price:     $3338.09
#   Open:            $3338.09
#   High:            $3341.08
#   Low:             $3333.62
#   Close:           $3337.63
#   Exit Time:       2025-05-09 11:30:00-04:00
#   Exit Price:      $3339.58
#   P&L:             +0.04%
#   Duration:        4 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        57.31
#   Stochastic:      59.26
#   Momentum (10):   3.11
#   CCI (10):        79.90
#   MACD:            2.8877
#   MACD Signal:     3.0481
#   MACD Histogram:  -0.1605
#   VWMACD:          1.9689
#   CMF (21):        0.0750
#   MFI (14):        32.42
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #63 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-11 21:30:00-04:00
#   Entry Price:     $3264.67
#   Open:            $3264.67
#   High:            $3274.79
#   Low:             $3263.36
#   Close:           $3273.85
#   Exit Time:       2025-05-12 20:00:00-04:00
#   Exit Price:      $3236.83
#   P&L:             -0.85%
#   Duration:        86 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.59
#   Stochastic:      20.15
#   Momentum (10):   -2.29
#   CCI (10):        -35.66
#   MACD:            -14.8736
#   MACD Signal:     -14.1172
#   MACD Histogram:  -0.7564
#   VWMACD:          -16.0902
#   CMF (21):        0.0149
#   MFI (14):        48.86
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #64 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-14 14:30:00-04:00
#   Entry Price:     $3177.31
#   Open:            $3177.31
#   High:            $3178.79
#   Low:             $3174.95
#   Close:           $3174.96
#   Exit Time:       2025-05-15 15:00:00-04:00
#   Exit Price:      $3223.18
#   P&L:             +1.44%
#   Duration:        94 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.27
#   Stochastic:      13.27
#   Momentum (10):   -5.09
#   CCI (10):        -117.94
#   MACD:            -7.8705
#   MACD Signal:     -8.7176
#   MACD Histogram:  0.8470
#   VWMACD:          -4.7497
#   CMF (21):        -0.1396
#   MFI (14):        39.55
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #65 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-16 03:45:00-04:00
#   Entry Price:     $3214.94
#   Open:            $3214.94
#   High:            $3214.95
#   Low:             $3206.91
#   Close:           $3207.44
#   Exit Time:       2025-05-16 13:15:00-04:00
#   Exit Price:      $3186.58
#   P&L:             -0.88%
#   Duration:        38 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.82
#   Stochastic:      21.08
#   Momentum (10):   -6.89
#   CCI (10):        -138.43
#   MACD:            -3.0869
#   MACD Signal:     -2.5985
#   MACD Histogram:  -0.4884
#   VWMACD:          -0.0096
#   CMF (21):        -0.1061
#   MFI (14):        38.24
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #66 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-19 19:30:00-04:00
#   Entry Price:     $3222.37
#   Open:            $3222.37
#   High:            $3222.70
#   Low:             $3218.97
#   Close:           $3222.50
#   Exit Time:       2025-05-20 04:00:00-04:00
#   Exit Price:      $3222.76
#   P&L:             +0.01%
#   Duration:        34 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.58
#   Stochastic:      10.58
#   Momentum (10):   -9.51
#   CCI (10):        -98.42
#   MACD:            -2.4845
#   MACD Signal:     -1.5882
#   MACD Histogram:  -0.8963
#   VWMACD:          -2.2650
#   CMF (21):        -0.0079
#   MFI (14):        45.55
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #67 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-22 10:15:00-04:00
#   Entry Price:     $3290.05
#   Open:            $3290.05
#   High:            $3298.60
#   Low:             $3287.21
#   Close:           $3297.44
#   Exit Time:       2025-05-23 01:45:00-04:00
#   Exit Price:      $3317.70
#   P&L:             +0.84%
#   Duration:        58 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        43.09
#   Stochastic:      31.52
#   Momentum (10):   -16.64
#   CCI (10):        -57.79
#   MACD:            -5.2007
#   MACD Signal:     -4.9452
#   MACD Histogram:  -0.2555
#   VWMACD:          -1.0426
#   CMF (21):        0.0909
#   MFI (14):        54.46
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #68 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-26 02:45:00-04:00
#   Entry Price:     $3342.66
#   Open:            $3342.66
#   High:            $3342.97
#   Low:             $3337.08
#   Close:           $3337.32
#   Exit Time:       2025-05-26 19:00:00-04:00
#   Exit Price:      $3347.35
#   P&L:             +0.14%
#   Duration:        61 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.34
#   Stochastic:      14.00
#   Momentum (10):   -10.62
#   CCI (10):        -163.88
#   MACD:            -1.6422
#   MACD Signal:     -0.7964
#   MACD Histogram:  -0.8458
#   VWMACD:          0.3310
#   CMF (21):        -0.1395
#   MFI (14):        39.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #69 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-27 06:00:00-04:00
#   Entry Price:     $3296.27
#   Open:            $3296.27
#   High:            $3299.48
#   Low:             $3295.95
#   Close:           $3296.86
#   Exit Time:       2025-05-27 14:00:00-04:00
#   Exit Price:      $3301.15
#   P&L:             +0.15%
#   Duration:        32 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.23
#   Stochastic:      14.07
#   Momentum (10):   -13.05
#   CCI (10):        -63.27
#   MACD:            -9.4151
#   MACD Signal:     -9.2045
#   MACD Histogram:  -0.2106
#   VWMACD:          -9.1681
#   CMF (21):        -0.2589
#   MFI (14):        46.12
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #70 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-28 11:45:00-04:00
#   Entry Price:     $3295.33
#   Open:            $3295.33
#   High:            $3296.60
#   Low:             $3293.94
#   Close:           $3295.92
#   Exit Time:       2025-05-29 03:45:00-04:00
#   Exit Price:      $3279.62
#   P&L:             -0.48%
#   Duration:        60 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.12
#   Stochastic:      9.69
#   Momentum (10):   -9.63
#   CCI (10):        -91.06
#   MACD:            -4.1201
#   MACD Signal:     -2.7677
#   MACD Histogram:  -1.3523
#   VWMACD:          -3.9182
#   CMF (21):        -0.1273
#   MFI (14):        32.65
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #71 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-29 21:15:00-04:00
#   Entry Price:     $3316.08
#   Open:            $3316.08
#   High:            $3322.58
#   Low:             $3314.62
#   Close:           $3316.46
#   Exit Time:       2025-05-30 08:30:00-04:00
#   Exit Price:      $3301.27
#   P&L:             -0.45%
#   Duration:        45 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        52.75
#   Stochastic:      46.67
#   Momentum (10):   2.03
#   CCI (10):        118.83
#   MACD:            -0.3341
#   MACD Signal:     -0.0975
#   MACD Histogram:  -0.2366
#   VWMACD:          -2.0438
#   CMF (21):        0.0043
#   MFI (14):        49.14
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #72 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-30 10:15:00-04:00
#   Entry Price:     $3282.04
#   Open:            $3282.04
#   High:            $3287.35
#   Low:             $3279.51
#   Close:           $3283.51
#   Exit Time:       2025-05-30 16:15:00-04:00
#   Exit Price:      $3292.93
#   P&L:             +0.33%
#   Duration:        24 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.85
#   Stochastic:      21.68
#   Momentum (10):   -10.41
#   CCI (10):        -78.39
#   MACD:            -3.2042
#   MACD Signal:     -1.3747
#   MACD Histogram:  -1.8295
#   VWMACD:          -0.7124
#   CMF (21):        -0.0634
#   MFI (14):        43.62
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #73 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-03 00:00:00-04:00
#   Entry Price:     $3361.20
#   Open:            $3361.20
#   High:            $3365.02
#   Low:             $3361.18
#   Close:           $3363.30
#   Exit Time:       2025-06-03 15:30:00-04:00
#   Exit Price:      $3353.00
#   P&L:             -0.24%
#   Duration:        62 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.11
#   Stochastic:      11.19
#   Momentum (10):   -9.76
#   CCI (10):        -72.11
#   MACD:            -4.0611
#   MACD Signal:     -2.5585
#   MACD Histogram:  -1.5025
#   VWMACD:          -4.0372
#   CMF (21):        -0.1121
#   MFI (14):        37.33
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #74 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-04 07:15:00-04:00
#   Entry Price:     $3350.38
#   Open:            $3350.38
#   High:            $3351.52
#   Low:             $3343.68
#   Close:           $3346.69
#   Exit Time:       2025-06-04 11:00:00-04:00
#   Exit Price:      $3377.32
#   P&L:             +0.80%
#   Duration:        15 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.94
#   Stochastic:      17.33
#   Momentum (10):   -16.09
#   CCI (10):        -133.10
#   MACD:            -1.6745
#   MACD Signal:     -0.2894
#   MACD Histogram:  -1.3851
#   VWMACD:          0.6231
#   CMF (21):        -0.0597
#   MFI (14):        34.61
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #75 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-05 00:15:00-04:00
#   Entry Price:     $3369.60
#   Open:            $3369.60
#   High:            $3370.20
#   Low:             $3363.79
#   Close:           $3367.40
#   Exit Time:       2025-06-05 05:45:00-04:00
#   Exit Price:      $3385.24
#   P&L:             +0.46%
#   Duration:        22 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.90
#   Stochastic:      12.27
#   Momentum (10):   -6.32
#   CCI (10):        -163.19
#   MACD:            -1.2168
#   MACD Signal:     -0.4185
#   MACD Histogram:  -0.7982
#   VWMACD:          -2.7688
#   CMF (21):        0.0294
#   MFI (14):        19.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #76 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-06 05:45:00-04:00
#   Entry Price:     $3357.09
#   Open:            $3357.09
#   High:            $3357.40
#   Low:             $3352.60
#   Close:           $3356.63
#   Exit Time:       2025-06-09 11:45:00-04:00
# ...
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.04
#   Stochastic:      20.51
#   Momentum (10):   -17.28
#   CCI (10):        -46.65
#   MACD:            -8.3170
#   MACD Signal:     -7.6495
#   MACD Histogram:  -0.6675
#   VWMACD:          -0.8069
#   CMF (21):        -0.0170
#   MFI (14):        66.14
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #149 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-31 12:30:00-04:00
#   Entry Price:     $3985.75
#   Open:            $3985.75
#   High:            $3990.29
#   Low:             $3981.67
#   Close:           $3984.42
#   Exit Time:       2025-11-03 03:15:00-05:00
#   Exit Price:      $4021.47
#   P&L:             +0.90%
#   Duration:        54 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.96
#   Stochastic:      14.38
#   Momentum (10):   -35.21
#   CCI (10):        -104.53
#   MACD:            -5.4837
#   MACD Signal:     -1.0559
#   MACD Histogram:  -4.4278
#   VWMACD:          -5.0028
#   CMF (21):        -0.0927
#   MFI (14):        49.08
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #150 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-03 21:30:00-05:00
#   Entry Price:     $3983.95
#   Open:            $3983.95
#   High:            $3985.20
#   Low:             $3977.05
#   Close:           $3983.22
#   Exit Time:       2025-11-04 22:30:00-05:00
#   Exit Price:      $3953.05
#   P&L:             -0.78%
#   Duration:        96 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.55
#   Stochastic:      22.33
#   Momentum (10):   -11.31
#   CCI (10):        -41.89
#   MACD:            -5.8431
#   MACD Signal:     -5.1821
#   MACD Histogram:  -0.6610
#   VWMACD:          -6.7228
#   CMF (21):        0.0463
#   MFI (14):        43.96
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #151 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-06 08:15:00-05:00
#   Entry Price:     $4011.77
#   Open:            $4011.77
#   High:            $4016.01
#   Low:             $4010.18
#   Close:           $4013.07
#   Exit Time:       2025-11-06 20:30:00-05:00
#   Exit Price:      $3997.37
#   P&L:             -0.36%
#   Duration:        45 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        58.60
#   Stochastic:      43.46
#   Momentum (10):   4.82
#   CCI (10):        37.34
#   MACD:            3.5721
#   MACD Signal:     4.5518
#   MACD Histogram:  -0.9797
#   VWMACD:          1.5655
#   CMF (21):        0.1169
#   MFI (14):        55.43
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #152 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-11 09:45:00-05:00
#   Entry Price:     $4132.78
#   Open:            $4132.78
#   High:            $4134.62
#   Low:             $4119.77
#   Close:           $4124.80
#   Exit Time:       2025-11-12 07:45:00-05:00
#   Exit Price:      $4134.24
#   P&L:             +0.04%
#   Duration:        84 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.98
#   Stochastic:      23.14
#   Momentum (10):   -14.10
#   CCI (10):        -158.24
#   MACD:            -1.2591
#   MACD Signal:     0.4674
#   MACD Histogram:  -1.7265
#   VWMACD:          -2.1279
#   CMF (21):        -0.0105
#   MFI (14):        57.06
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #153 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-12 19:00:00-05:00
#   Entry Price:     $4191.12
#   Open:            $4191.12
#   High:            $4192.21
#   Low:             $4185.89
#   Close:           $4187.90
#   Exit Time:       2025-11-12 20:15:00-05:00
#   Exit Price:      $4190.89
#   P&L:             -0.01%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.62
#   Stochastic:      15.75
#   Momentum (10):   -7.64
#   CCI (10):        -146.35
#   MACD:            4.1705
#   MACD Signal:     7.1184
#   MACD Histogram:  -2.9480
#   VWMACD:          -4.1702
#   CMF (21):        -0.1061
#   MFI (14):        61.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #154 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-13 14:00:00-05:00
#   Entry Price:     $4157.61
#   Open:            $4157.61
#   High:            $4157.82
#   Low:             $4145.81
#   Close:           $4153.75
#   Exit Time:       2025-11-13 21:30:00-05:00
#   Exit Price:      $4199.47
#   P&L:             +1.01%
#   Duration:        26 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        27.66
#   Stochastic:      16.06
#   Momentum (10):   -43.80
#   CCI (10):        -117.99
#   MACD:            -13.5220
#   MACD Signal:     -8.7328
#   MACD Histogram:  -4.7892
#   VWMACD:          -14.2314
#   CMF (21):        -0.0175
#   MFI (14):        46.98
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #155 [OPEN]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-14 06:45:00-05:00
#   Entry Price:     $4153.42
#   Open:            $4153.42
#   High:            $4153.44
#   Low:             $4130.73
#   Close:           $4132.92
#   Current Price:   $4069.39
#   P&L:             -2.02%
#   Duration:        70 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        25.72
#   Stochastic:      15.11
#   Momentum (10):   -37.17
#   CCI (10):        -177.84
#   MACD:            -9.8349
#   MACD Signal:     -6.9501
#   MACD Histogram:  -2.8849
#   VWMACD:          -10.7635
#   CMF (21):        -0.1484
#   MFI (14):        29.39
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20716 | time = 2025-11-16 23:15:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4083.7300
#   High   : 4084.4400
#   Low    : 4080.9600
#   Close  : 4083.1300
#   Volume : 3640.0
#
# 📈 INDICATORS:
#   RSI(14)        : 44.6204
#   MACD(12,26,9)  : -2.9518
#   MACD Signal    : -2.5632
#   MACD Hist      : -0.3885
#   Momentum(10)   : -8.1000
#   Stoch(14,3)    : 42.8852
#   CCI(10)        : -22.7926
#   VW-MACD        : -2.8123
#   CMF(21)        : 0.0659
#   MFI(14)        : 55.9721
#   OBV            : 3076612.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20717 | time = 2025-11-16 23:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4083.1300
#   High   : 4085.2100
#   Low    : 4081.1800
#   Close  : 4083.1600
#   Volume : 4046.0
#
# 📈 INDICATORS:
#   RSI(14)        : 44.6556
#   MACD(12,26,9)  : -2.8821
#   MACD Signal    : -2.6270
#   MACD Hist      : -0.2551
#   Momentum(10)   : -5.6600
#   Stoch(14,3)    : 43.3086
#   CCI(10)        : -13.2663
#   VW-MACD        : -4.3266
#   CMF(21)        : 0.0388
#   MFI(14)        : 51.6333
#   OBV            : 3080658.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20718 | time = 2025-11-16 23:45:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4083.1600
#   High   : 4083.5300
#   Low    : 4076.6000
#   Close  : 4078.4600
#   Volume : 5223.0
#
# 📈 INDICATORS:
#   RSI(14)        : 40.3343
#   MACD(12,26,9)  : -3.1695
#   MACD Signal    : -2.7355
#   MACD Hist      : -0.4340
#   Momentum(10)   : -13.3100
#   Stoch(14,3)    : 37.8666
#   CCI(10)        : -133.0039
#   VW-MACD        : -5.3076
#   CMF(21)        : 0.0281
#   MFI(14)        : 44.2869
#   OBV            : 3075435.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20719 | time = 2025-11-17 00:00:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4078.4600
#   High   : 4078.6300
#   Low    : 4071.7000
#   Close  : 4072.1700
#   Volume : 6317.0
#
# 📈 INDICATORS:
#   RSI(14)        : 35.3976
#   MACD(12,26,9)  : -3.8604
#   MACD Signal    : -2.9605
#   MACD Hist      : -0.8999
#   Momentum(10)   : -16.0700
#   Stoch(14,3)    : 26.7416
#   CCI(10)        : -225.7835
#   VW-MACD        : -6.2916
#   CMF(21)        : 0.0151
#   MFI(14)        : 36.4296
#   OBV            : 3069118.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20720 | time = 2025-11-17 00:15:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4072.1700
#   High   : 4072.6700
#   Low    : 4058.0800
#   Close  : 4064.2600
#   Volume : 14289.0
#
# 📈 INDICATORS:
#   RSI(14)        : 30.3644
#   MACD(12,26,9)  : -4.9887
#   MACD Signal    : -3.3661
#   MACD Hist      : -1.6225
#   Momentum(10)   : -17.2600
#   Stoch(14,3)    : 18.2746
#   CCI(10)        : -222.1770
#   VW-MACD        : -8.2062
#   CMF(21)        : 0.0395
#   MFI(14)        : 36.1079
#   OBV            : 3054829.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 1.0
#   neg_div_count    : 0.0
#   total_divergences: 1.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20721 | time = 2025-11-17 00:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4064.2600
#   High   : 4064.9400
#   Low    : 4049.4800
#   Close  : 4057.2600
#   Volume : 17530.0
#
# 📈 INDICATORS:
#   RSI(14)        : 26.7407
#   MACD(12,26,9)  : -6.3742
#   MACD Signal    : -3.9677
#   MACD Hist      : -2.4065
#   Momentum(10)   : -22.2700
#   Stoch(14,3)    : 14.7423
#   CCI(10)        : -177.5570
#   VW-MACD        : -10.0235
#   CMF(21)        : 0.0379
#   MFI(14)        : 34.8006
#   OBV            : 3037299.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20722 | time = 2025-11-17 00:45:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4057.2600
#   High   : 4060.1800
#   Low    : 4053.4500
#   Close  : 4058.3500
#   Volume : 9107.0
#
# 📈 INDICATORS:
#   RSI(14)        : 28.1780
#   MACD(12,26,9)  : -7.3001
#   MACD Signal    : -4.6342
#   MACD Hist      : -2.6659
#   Momentum(10)   : -21.7700
#   Stoch(14,3)    : 18.3341
#   CCI(10)        : -116.8421
#   VW-MACD        : -10.5380
#   CMF(21)        : 0.0418
#   MFI(14)        : 35.1264
#   OBV            : 3046406.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 1.0
#   neg_div_count    : 0.0
#   total_divergences: 1.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20723 | time = 2025-11-17 01:00:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4058.3500
#   High   : 4066.4700
#   Low    : 4054.6200
#   Close  : 4058.5300
#   Volume : 13531.0
#
# 📈 INDICATORS:
#   RSI(14)        : 28.4278
#   MACD(12,26,9)  : -7.9280
#   MACD Signal    : -5.2930
#   MACD Hist      : -2.6351
#   Momentum(10)   : -24.1900
#   Stoch(14,3)    : 20.0625
#   CCI(10)        : -90.4033
#   VW-MACD        : -11.5287
#   CMF(21)        : 0.0525
#   MFI(14)        : 44.2495
#   OBV            : 3059937.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20724 | time = 2025-11-17 01:15:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4058.5300
#   High   : 4064.7400
#   Low    : 4056.2200
#   Close  : 4063.0300
#   Volume : 7690.0
#
# 📈 INDICATORS:
#   RSI(14)        : 34.5543
#   MACD(12,26,9)  : -7.9707
#   MACD Signal    : -5.8285
#   MACD Hist      : -2.1421
#   Momentum(10)   : -19.7200
#   Stoch(14,3)    : 25.9356
#   CCI(10)        : -48.2295
#   VW-MACD        : -12.4245
#   CMF(21)        : 0.0209
#   MFI(14)        : 52.5158
#   OBV            : 3067627.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20725 | time = 2025-11-17 01:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 4063.0300
#   High   : 4071.8600
#   Low    : 4062.4900
#   Close  : 4069.3900
#   Volume : 8818.0
#
# 📈 INDICATORS:
#   RSI(14)        : 42.0982
#   MACD(12,26,9)  : -7.4059
#   MACD Signal    : -6.1440
#   MACD Hist      : -1.2619
#   Momentum(10)   : -14.3400
#   Stoch(14,3)    : 36.4964
#   CCI(10)        : 4.8382
#   VW-MACD        : -12.8854
#   CMF(21)        : -0.0144
#   MFI(14)        : 62.3018
#   OBV            : 3076445.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================

# %%
#===============================================================================
# CELL 2: Auto "window + indicators + pivots" search (with drawdown stats)
#===============================================================================

# !pip install scikit-learn

from sklearn.model_selection import ParameterGrid

#-------------------------------------------
# 0) Load CSV ONCE and prepare pivot cache
#-------------------------------------------

# نفس csv_filename اللي فوق في الـ main
# لو حابب تغيره، غيّره مرة واحدة هنا وهنا في main
base_df = load_data_from_csv(csv_filename)

# هنسجّل فيها pivots لكل pivot_prd (3,5, ...)
pivot_cache = {}

#-------------------------------------------
# 1) Parametric indicator calculator
#-------------------------------------------

def calculate_indicators_with_params(df, params):
    """
    نسخة من calculate_indicators لكن بالـ windows جاية من params
    ما بنلمسش Config ولا الاستراتيجية نفسها، بس بنغير إعدادات المؤشرات.
    """
    df = df.copy()

    # نقرأ الـ windows من params مع قيم default
    rsi_window      = params.get("rsi_window",      14)
    macd_fast       = params.get("macd_fast",       12)
    macd_slow       = params.get("macd_slow",       26)
    macd_signal     = params.get("macd_signal",      9)
    mom_window      = params.get("mom_window",      10)
    stoch_window    = params.get("stoch_window",    14)
    stoch_smooth    = params.get("stoch_smooth",     3)
    vwma_fast_win   = params.get("vwma_fast",       12)
    vwma_slow_win   = params.get("vwma_slow",       26)
    cmf_window      = params.get("cmf_window",      21)
    cci_window      = params.get("cci_window",      10)
    mfi_window      = params.get("mfi_window",      14)

    close  = df["close"]
    high   = df["high"]
    low    = df["low"]
    volume = df["volume"]

    # ----- RSI -----
    df["rsi"] = ta.momentum.RSIIndicator(
        close, window=rsi_window
    ).rsi()

    # ----- MACD -----
    macd_ind = ta.trend.MACD(
        close,
        window_slow=macd_slow,
        window_fast=macd_fast,
        window_sign=macd_signal,
    )
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # ----- Momentum -----
    df["momentum"] = close - close.shift(mom_window)

    # ----- Stochastic -----
    lowest_low   = low.rolling(window=stoch_window).min()
    highest_high = high.rolling(window=stoch_window).max()
    stoch_k = 100 * (close - lowest_low) / (highest_high - lowest_low)
    df["stoch"] = stoch_k.rolling(window=stoch_smooth).mean()

    # ----- VW-MACD (VWMA fast - VWMA slow) -----
    vwma_fast = (close * volume).rolling(vwma_fast_win).sum() / volume.rolling(vwma_fast_win).sum()
    vwma_slow = (close * volume).rolling(vwma_slow_win).sum() / volume.rolling(vwma_slow_win).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # ----- CMF -----
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high, low, close, volume, window=cmf_window
    ).chaikin_money_flow()

    # ----- CCI -----
    df["cci"] = ta.trend.CCIIndicator(
        high, low, close,
        window=cci_window, constant=0.015, fillna=False
    ).cci()

    # ----- MFI -----
    df["mfi"] = ta.volume.MFIIndicator(
        high, low, close, volume,
        window=mfi_window, fillna=False
    ).money_flow_index()

    # ----- OBV (نفس الكود القديم) -----
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i - 1]:
            obv_values.append(obv_values[-1] + volume.iloc[i])
        elif close.iloc[i] < close.iloc[i - 1]:
            obv_values.append(obv_values[-1] - volume.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df["obv"] = obv_values

    # Fill NaNs
    df = df.fillna(method="bfill").fillna(method="ffill")

    return df

#-------------------------------------------
# 2) Fast performance evaluator (بدون طباعة) + drawdown per trade
#-------------------------------------------

def quick_performance(df):
    """
    - يحسب P&L لكل صفقة
    - يحسب max drawdown% لكل صفقة (أكبر نزول عن سعر الدخول)
    - يرجّع ملخّص: total_trades, win_rate, avg_pnl, total_return,
                    max_dd, avg_dd, median_dd
    """
    entries = df[df["signal"] == 1].copy()
    exits   = df[df["signal"] == -1].copy()

    if len(entries) == 0:
        return {
            "total_trades": 0,
            "win_rate": 0.0,
            "avg_pnl": 0.0,
            "total_return": 0.0,
            "max_dd": 0.0,
            "avg_dd": 0.0,
            "median_dd": 0.0,
        }

    pnl_list = []
    dd_list  = []

    for i, entry_row in entries.iterrows():
        entry_idx   = df.index.get_loc(i)
        entry_price = entry_row["entry_price"]

        # نلاقي أول exit بعد entry
        exit_idx = None
        exit_price = None
        for j, exit_row in exits.iterrows():
            candidate_idx = df.index.get_loc(j)
            if candidate_idx > entry_idx:
                exit_idx   = candidate_idx
                exit_price = exit_row["exit_price"]
                break

        # لو مفيش exit -> نخرج عند آخر شمعة
        if exit_idx is None:
            exit_idx   = len(df) - 1
            exit_price = df["close"].iloc[-1]

        # --- P&L للصفقة ---
        pnl_pct = (exit_price - entry_price) / entry_price * 100.0
        pnl_list.append(pnl_pct)

        # --- Drawdown للصفقة ---
        trade_slice = df.iloc[entry_idx:exit_idx + 1]
        dd_series = (trade_slice["low"] - entry_price) / entry_price * 100.0
        worst_dd = dd_series.min()   # سالب غالباً
        dd_mag   = abs(worst_dd)     # نخليه موجب
        dd_list.append(dd_mag)

    trades = np.array(pnl_list)
    dds    = np.array(dd_list)

    total_trades = len(trades)
    wins   = (trades > 0).sum()
    win_rate = (wins / total_trades * 100.0) if total_trades > 0 else 0.0
    avg_pnl = trades.mean() if total_trades > 0 else 0.0
    total_return = trades.sum()

    max_dd     = dds.max()      if len(dds) > 0 else 0.0
    avg_dd     = dds.mean()     if len(dds) > 0 else 0.0
    median_dd  = np.median(dds) if len(dds) > 0 else 0.0

    return {
        "total_trades": int(total_trades),
        "win_rate": float(win_rate),
        "avg_pnl": float(avg_pnl),
        "total_return": float(total_return),
        "max_dd": float(max_dd),
        "avg_dd": float(avg_dd),
        "median_dd": float(median_dd),
    }

#-------------------------------------------
# 3) Pipeline for one parameter set (مع pivot cache)
#-------------------------------------------

def run_pipeline_with_params(df_base, params):
    """
    - يستخدم df_base (loaded once)
    - يحسب المؤشرات بالـ windows الجديدة
    - يظبط Config:
        * pivot period (prd)
        * أي indicators عايز تطفيها/تشغّلها
    - يركّب pivots من pivot_cache حسب pivot_prd
    - يطلع divergences + strategy + quick metrics
    """
    # نخزن الـ state الأصلي عشان نرجّعه بعدين
    orig_state = {
        "prd":       config.prd,
        "calcmacd":  config.calcmacd,
        "calcmacda": config.calcmacda,
        "calcrsi":   config.calcrsi,
        "calcstoc":  config.calcstoc,
        "calccci":   config.calccci,
        "calcmom":   config.calcmom,
        "calcobv":   config.calcobv,
        "calcvwmacd":config.calcvwmacd,
        "calccmf":   config.calccmf,
        "calcmfi":   config.calcmfi,
    }

    try:
        # 1) نغيّر الـ pivot period لو موجود في params
        pivot_prd = params.get("pivot_prd", config.prd)
        config.prd = int(pivot_prd)

        # 2) نطبّق ON/OFF للمؤشرات لو params فيها flags
        indicator_flags = {
            "use_macd":      "calcmacd",
            "use_macd_hist": "calcmacda",
            "use_rsi":       "calcrsi",
            "use_stoch":     "calcstoc",
            "use_mom":       "calcmom",
            "use_cci":       "calccci",
            "use_obv":       "calcobv",
            "use_vwmacd":    "calcvwmacd",
            "use_cmf":       "calccmf",
            "use_mfi":       "calcmfi",
        }
        for param_key, cfg_attr in indicator_flags.items():
            if param_key in params:
                setattr(config, cfg_attr, bool(params[param_key]))

        # 3) Indicators على نسخة من الـ base df
        df = calculate_indicators_with_params(df_base, params)

        # 4) Pivots من الـ cache (أو نحسب ونخزّن أول مرة)
        prd = config.prd
        if prd not in pivot_cache:
            tmp = base_df.copy()
            tmp = find_pivots(tmp, prd)
            pivot_cache[prd] = {
                "pivot_high"     : tmp["pivot_high"].to_numpy(),
                "pivot_low"      : tmp["pivot_low"].to_numpy(),
                "pivot_high_bar" : tmp["pivot_high_bar"].to_numpy(),
                "pivot_low_bar"  : tmp["pivot_low_bar"].to_numpy(),
            }

        piv = pivot_cache[prd]
        df["pivot_high"]     = piv["pivot_high"]
        df["pivot_low"]      = piv["pivot_low"]
        df["pivot_high_bar"] = piv["pivot_high_bar"]
        df["pivot_low_bar"]  = piv["pivot_low_bar"]

        # 5) Divergences + strategy
        df = scan_all_divergences(df)
        df = run_strategy(df)
        metrics = quick_performance(df)
    finally:
        # نرجّع Config زي ما كانت عشان التجربة اللي بعدها
        config.prd       = orig_state["prd"]
        config.calcmacd  = orig_state["calcmacd"]
        config.calcmacda = orig_state["calcmacda"]
        config.calcrsi   = orig_state["calcrsi"]
        config.calcstoc  = orig_state["calcstoc"]
        config.calccci   = orig_state["calccci"]
        config.calcmom   = orig_state["calcmom"]
        config.calcobv   = orig_state["calcobv"]
        config.calcvwmacd= orig_state["calcvwmacd"]
        config.calccmf   = orig_state["calccmf"]
        config.calcmfi   = orig_state["calcmfi"]

    return metrics, df

#-------------------------------------------
# 4) Grid search على windows + indicators + pivot period
#-------------------------------------------

param_grid = {
    # ---- indicator windows ----
    "rsi_window"   : [7, 10, 14, 21],
    "stoch_window" : [9, 14],
    "stoch_smooth" : [3],
    "mom_window"   : [5, 10],
    "cci_window"   : [10],
    "mfi_window"   : [10, 20],
    "vwma_fast"    : [8, 12],
    "vwma_slow"    : [26],
    "cmf_window"   : [14, 21],

    # ---- pivot period ----
    "pivot_prd"    : [3, 5],

    # ---- indicator ON/OFF ----
    "use_vwmacd"   : [True, False],
    "use_cmf"      : [True, False],
    "use_mfi"      : [True, False],
}

grid = list(ParameterGrid(param_grid))
print(f"🔍 Number of combinations to test: {len(grid)}")

results = []

for idx, params in enumerate(grid, start=1):
    metrics, _ = run_pipeline_with_params(base_df, params)
    row = {**params, **metrics}
    results.append(row)

    print(f"\n[{idx}/{len(grid)}]")
    print(f"  params : {params}")
    print(
        "  metrics: "
        f"trades={metrics['total_trades']}, "
        f"win_rate={metrics['win_rate']:.2f}%, "
        f"avg_pnl={metrics['avg_pnl']:.2f}%, "
        f"total_return={metrics['total_return']:.2f}%, "
        f"max_dd={metrics['max_dd']:.2f}%, "
        f"avg_dd={metrics['avg_dd']:.2f}%, "
        f"median_dd={metrics['median_dd']:.2f}%"
    )

    # 💾 checkpoint كل 100 combo عشان الأمان
    if idx % 100 == 0 or idx == len(grid):
        tmp_df = pd.DataFrame(results)
        tmp_df.to_csv("divergence_param_grid_results_partial.csv", index=False)
        print("  💾 checkpoint saved: divergence_param_grid_results_partial.csv")

results_df = pd.DataFrame(results)

# نرتب حسب:
#   1) أعلى Total Return
#   2) أعلى Win Rate
#   3) أقل Max Drawdown
results_df = results_df.sort_values(
    by=["total_return", "win_rate", "max_dd"],
    ascending=[False, False, True]
).reset_index(drop=True)

print("\n===============================================")
print("🏆 TOP 10 PARAMETER SETS (by total_return, win_rate, low max_dd)")
print("===============================================")
print(results_df.head(10))

#-------------------------------------------
# 5) Export full grid-search results to CSV
#-------------------------------------------

csv_output_path = "divergence_param_grid_results.csv"
results_df.to_csv(csv_output_path, index=False)
print(f"\n📁 Full grid-search results saved to: {csv_output_path}")

best_params = results_df.iloc[0][list(param_grid.keys())].to_dict()
print("\n🔥 BEST PARAMS FOUND:")
for k, v in best_params.items():
    print(f"  {k}: {v}")

# شغّل الاستراتيجية تاني على أحسن params وشوف الشارت:
best_metrics, best_df = run_pipeline_with_params(base_df, best_params)
print("\nBest metrics on full sample:")
print(best_metrics)

# لو حابب تشوف الشارت:
# plot_candlestick_with_signals(best_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [1346/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=230, win_rate=66.09%, avg_pnl=0.05%, total_return=10.60%, max_dd=5.32%, avg_dd=0.51%, median_dd=0.27%
# Scanning for divergences...
# Found 2269 bars with divergences
# Running strategy...
#
# [1347/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=200, win_rate=65.00%, avg_pnl=0.04%, total_return=8.39%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.29%
# Scanning for divergences...
# Found 2269 bars with divergences
# Running strategy...
#
# [1348/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=200, win_rate=65.00%, avg_pnl=0.04%, total_return=8.39%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.29%
# Scanning for divergences...
# Found 2252 bars with divergences
# Running strategy...
#
# [1349/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=210, win_rate=64.76%, avg_pnl=0.05%, total_return=9.90%, max_dd=5.32%, avg_dd=0.52%, median_dd=0.27%
# Scanning for divergences...
# Found 2310 bars with divergences
# Running strategy...
#
# [1350/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=222, win_rate=67.57%, avg_pnl=0.08%, total_return=16.69%, max_dd=5.32%, avg_dd=0.49%, median_dd=0.26%
# Scanning for divergences...
# Found 2175 bars with divergences
# Running strategy...
#
# [1351/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=187, win_rate=66.31%, avg_pnl=0.07%, total_return=13.61%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.28%
# Scanning for divergences...
# Found 2175 bars with divergences
# Running strategy...
#
# [1352/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=187, win_rate=66.31%, avg_pnl=0.07%, total_return=13.61%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.28%
# Scanning for divergences...
# Found 2150 bars with divergences
# Running strategy...
#
# [1353/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=196, win_rate=65.31%, avg_pnl=0.04%, total_return=7.53%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.27%
# Scanning for divergences...
# Found 2213 bars with divergences
# Running strategy...
#
# [1354/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=212, win_rate=67.45%, avg_pnl=0.06%, total_return=13.08%, max_dd=5.32%, avg_dd=0.52%, median_dd=0.26%
# Scanning for divergences...
# Found 2063 bars with divergences
# Running strategy...
#
# [1355/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=178, win_rate=66.29%, avg_pnl=0.07%, total_return=11.71%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.28%
# Scanning for divergences...
# Found 2063 bars with divergences
# Running strategy...
#
# [1356/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=178, win_rate=66.29%, avg_pnl=0.07%, total_return=11.71%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.28%
# Scanning for divergences...
# Found 2049 bars with divergences
# Running strategy...
#
# [1357/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=182, win_rate=65.38%, avg_pnl=0.05%, total_return=8.58%, max_dd=5.32%, avg_dd=0.55%, median_dd=0.27%
# Scanning for divergences...
# Found 2117 bars with divergences
# Running strategy...
#
# [1358/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=199, win_rate=68.34%, avg_pnl=0.08%, total_return=15.02%, max_dd=5.32%, avg_dd=0.50%, median_dd=0.26%
# Scanning for divergences...
# Found 1960 bars with divergences
# Running strategy...
#
# [1359/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=160, win_rate=67.50%, avg_pnl=0.09%, total_return=14.05%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.28%
# Scanning for divergences...
# Found 1960 bars with divergences
# Running strategy...
#
# [1360/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=160, win_rate=67.50%, avg_pnl=0.09%, total_return=14.05%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.28%
# Scanning for divergences...
# Found 2328 bars with divergences
# Running strategy...
#
# [1361/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=215, win_rate=65.58%, avg_pnl=0.03%, total_return=5.71%, max_dd=5.32%, avg_dd=0.54%, median_dd=0.28%
# Scanning for divergences...
# Found 2383 bars with divergences
# Running strategy...
#
# [1362/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=229, win_rate=66.81%, avg_pnl=0.04%, total_return=8.97%, max_dd=5.32%, avg_dd=0.51%, median_dd=0.27%
# Scanning for divergences...
# Found 2255 bars with divergences
# Running strategy...
#
# [1363/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=198, win_rate=66.16%, avg_pnl=0.03%, total_return=6.85%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.31%
# Scanning for divergences...
# Found 2255 bars with divergences
# Running strategy...
#
# [1364/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=198, win_rate=66.16%, avg_pnl=0.03%, total_return=6.85%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.31%
# Scanning for divergences...
# Found 2235 bars with divergences
# Running strategy...
#
# [1365/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=206, win_rate=65.53%, avg_pnl=0.03%, total_return=7.18%, max_dd=5.32%, avg_dd=0.54%, median_dd=0.28%
# Scanning for divergences...
# Found 2294 bars with divergences
# Running strategy...
#
# [1366/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=218, win_rate=66.97%, avg_pnl=0.06%, total_return=13.04%, max_dd=5.32%, avg_dd=0.50%, median_dd=0.27%
# Scanning for divergences...
# Found 2161 bars with divergences
# Running strategy...
#
# [1367/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=66.49%, avg_pnl=0.05%, total_return=9.81%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
# Scanning for divergences...
# Found 2161 bars with divergences
# Running strategy...
#
# [1368/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=66.49%, avg_pnl=0.05%, total_return=9.81%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
# Scanning for divergences...
# Found 2133 bars with divergences
# Running strategy...
#
# [1369/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=192, win_rate=67.19%, avg_pnl=0.03%, total_return=6.19%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.28%
# Scanning for divergences...
# Found 2196 bars with divergences
# Running strategy...
#
# [1370/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=209, win_rate=67.94%, avg_pnl=0.05%, total_return=9.84%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.27%
# Scanning for divergences...
# Found 2049 bars with divergences
# Running strategy...
#
# [1371/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=176, win_rate=68.75%, avg_pnl=0.06%, total_return=10.47%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.31%
# Scanning for divergences...
# Found 2049 bars with divergences
# Running strategy...
#
# [1372/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=176, win_rate=68.75%, avg_pnl=0.06%, total_return=10.47%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.31%
# Scanning for divergences...
# Found 2033 bars with divergences
# Running strategy...
#
# [1373/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=176, win_rate=65.91%, avg_pnl=0.03%, total_return=5.66%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.31%
# Scanning for divergences...
# Found 2101 bars with divergences
# Running strategy...
#
# [1374/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=194, win_rate=68.04%, avg_pnl=0.07%, total_return=13.31%, max_dd=5.32%, avg_dd=0.52%, median_dd=0.27%
# Scanning for divergences...
# Found 1946 bars with divergences
# Running strategy...
#
# [1375/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=68.79%, avg_pnl=0.07%, total_return=11.74%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.32%
# Scanning for divergences...
# Found 1946 bars with divergences
# Running strategy...
#
# [1376/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=68.79%, avg_pnl=0.07%, total_return=11.74%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.32%
# Scanning for divergences...
# Found 2338 bars with divergences
# Running strategy...
#
# [1377/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=217, win_rate=64.52%, avg_pnl=0.04%, total_return=7.64%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.28%
# Scanning for divergences...
# Found 2395 bars with divergences
# Running strategy...
#
# [1378/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=229, win_rate=65.94%, avg_pnl=0.05%, total_return=10.59%, max_dd=5.32%, avg_dd=0.51%, median_dd=0.27%
# Scanning for divergences...
# Found 2264 bars with divergences
# Running strategy...
#
# [1379/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=198, win_rate=65.66%, avg_pnl=0.04%, total_return=8.81%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.30%
# Scanning for divergences...
# Found 2264 bars with divergences
# Running strategy...
#
# [1380/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=198, win_rate=65.66%, avg_pnl=0.04%, total_return=8.81%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.30%
# Scanning for divergences...
# Found 2244 bars with divergences
# Running strategy...
#
# [1381/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=208, win_rate=64.90%, avg_pnl=0.05%, total_return=10.52%, max_dd=5.32%, avg_dd=0.52%, median_dd=0.27%
# Scanning for divergences...
# Found 2304 bars with divergences
# Running strategy...
#
# [1382/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=221, win_rate=66.97%, avg_pnl=0.07%, total_return=14.81%, max_dd=5.32%, avg_dd=0.50%, median_dd=0.27%
# Scanning for divergences...
# Found 2169 bars with divergences
# Running strategy...
#
# [1383/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=66.49%, avg_pnl=0.07%, total_return=12.16%, max_dd=5.32%, avg_dd=0.54%, median_dd=0.29%
# Scanning for divergences...
# Found 2169 bars with divergences
# Running strategy...
#
# [1384/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=66.49%, avg_pnl=0.07%, total_return=12.16%, max_dd=5.32%, avg_dd=0.54%, median_dd=0.29%
# Scanning for divergences...
# Found 2139 bars with divergences
# Running strategy...
#
# [1385/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=193, win_rate=65.28%, avg_pnl=0.04%, total_return=7.78%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.27%
# Scanning for divergences...
# Found 2204 bars with divergences
# Running strategy...
#
# [1386/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=210, win_rate=67.62%, avg_pnl=0.06%, total_return=12.66%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.27%
# Scanning for divergences...
# Found 2053 bars with divergences
# Running strategy...
#
# [1387/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=175, win_rate=66.86%, avg_pnl=0.07%, total_return=11.73%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.29%
# Scanning for divergences...
# Found 2053 bars with divergences
# Running strategy...
#
# [1388/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=175, win_rate=66.86%, avg_pnl=0.07%, total_return=11.73%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.29%
# Scanning for divergences...
# Found 2037 bars with divergences
# Running strategy...
#
# [1389/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=179, win_rate=65.36%, avg_pnl=0.05%, total_return=8.16%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.28%
# Scanning for divergences...
# Found 2106 bars with divergences
# Running strategy...
#
# [1390/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=197, win_rate=68.02%, avg_pnl=0.06%, total_return=12.75%, max_dd=5.32%, avg_dd=0.51%, median_dd=0.27%
# Scanning for divergences...
# Found 1948 bars with divergences
# Running strategy...
#
# [1391/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=66.88%, avg_pnl=0.07%, total_return=11.55%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.29%
# Scanning for divergences...
# Found 1948 bars with divergences
# Running strategy...
#
# [1392/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=66.88%, avg_pnl=0.07%, total_return=11.55%, max_dd=5.32%, avg_dd=0.58%, median_dd=0.29%
# Scanning for divergences...
# Found 2320 bars with divergences
# Running strategy...
#
# [1393/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=214, win_rate=65.89%, avg_pnl=0.03%, total_return=6.72%, max_dd=5.32%, avg_dd=0.54%, median_dd=0.28%
# Scanning for divergences...
# Found 2377 bars with divergences
# Running strategy...
#
# [1394/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=228, win_rate=66.67%, avg_pnl=0.04%, total_return=9.18%, max_dd=5.32%, avg_dd=0.52%, median_dd=0.27%
# Scanning for divergences...
# Found 2249 bars with divergences
# Running strategy...
#
# [1395/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=196, win_rate=66.84%, avg_pnl=0.04%, total_return=7.72%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
# Scanning for divergences...
# Found 2249 bars with divergences
# Running strategy...
#
# [1396/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=196, win_rate=66.84%, avg_pnl=0.04%, total_return=7.72%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
# Scanning for divergences...
# Found 2225 bars with divergences
# Running strategy...
#
# [1397/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=205, win_rate=65.85%, avg_pnl=0.04%, total_return=8.17%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.28%
# Scanning for divergences...
# Found 2286 bars with divergences
# Running strategy...
#
# [1398/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=217, win_rate=66.36%, avg_pnl=0.05%, total_return=11.39%, max_dd=5.32%, avg_dd=0.51%, median_dd=0.27%
# Scanning for divergences...
# Found 2153 bars with divergences
# Running strategy...
#
# [1399/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=183, win_rate=66.67%, avg_pnl=0.05%, total_return=8.82%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
# Scanning for divergences...
# Found 2153 bars with divergences
# Running strategy...
#
# [1400/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=183, win_rate=66.67%, avg_pnl=0.05%, total_return=8.82%, max_dd=5.32%, avg_dd=0.56%, median_dd=0.31%
#   💾 checkpoint saved: divergence_param_grid_results_partial.csv
# Scanning for divergences...
# Found 2121 bars with divergences
# Running strategy...
#
# [1401/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=191, win_rate=67.02%, avg_pnl=0.04%, total_return=6.87%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.27%
# Scanning for divergences...
# Found 2186 bars with divergences
# Running strategy...
#
# [1402/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=208, win_rate=68.27%, avg_pnl=0.05%, total_return=9.71%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.27%
# Scanning for divergences...
# Found 2038 bars with divergences
# Running strategy...
#
# [1403/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=173, win_rate=68.79%, avg_pnl=0.06%, total_return=10.90%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.31%
# Scanning for divergences...
# Found 2038 bars with divergences
# Running strategy...
#
# [1404/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=173, win_rate=68.79%, avg_pnl=0.06%, total_return=10.90%, max_dd=5.32%, avg_dd=0.59%, median_dd=0.31%
# Scanning for divergences...
# Found 2019 bars with divergences
# Running strategy...
#
# [1405/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=175, win_rate=65.71%, avg_pnl=0.03%, total_return=5.67%, max_dd=5.32%, avg_dd=0.57%, median_dd=0.31%
# Scanning for divergences...
# Found 2088 bars with divergences
# Running strategy...
#
# [1406/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=193, win_rate=67.88%, avg_pnl=0.06%, total_return=11.32%, max_dd=5.32%, avg_dd=0.53%, median_dd=0.27%
# Scanning for divergences...
# Found 1932 bars with divergences
# Running strategy...
#
# [1407/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=154, win_rate=67.53%, avg_pnl=0.06%, total_return=9.66%, max_dd=5.32%, avg_dd=0.60%, median_dd=0.32%
# Scanning for divergences...
# Found 1932 bars with divergences
# Running strategy...
#
# [1408/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=154, win_rate=67.53%, avg_pnl=0.06%, total_return=9.66%, max_dd=5.32%, avg_dd=0.60%, median_dd=0.32%
# Scanning for divergences...
# Found 1721 bars with divergences
# Running strategy...
#
# [1409/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=148, win_rate=72.97%, avg_pnl=0.08%, total_return=11.62%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.32%
# Scanning for divergences...
# Found 1748 bars with divergences
# Running strategy...
#
# [1410/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=154, win_rate=70.78%, avg_pnl=0.06%, total_return=9.57%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.35%
# Scanning for divergences...
# Found 1684 bars with divergences
# Running strategy...
#
# [1411/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=143, win_rate=72.03%, avg_pnl=0.08%, total_return=11.02%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.32%
# Scanning for divergences...
# Found 1684 bars with divergences
# Running strategy...
#
# [1412/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=143, win_rate=72.03%, avg_pnl=0.08%, total_return=11.02%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.32%
# Scanning for divergences...
# Found 1661 bars with divergences
# Running strategy...
#
# [1413/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=140, win_rate=73.57%, avg_pnl=0.11%, total_return=15.46%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.35%
# Scanning for divergences...
# Found 1689 bars with divergences
# Running strategy...
#
# [1414/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=146, win_rate=71.23%, avg_pnl=0.10%, total_return=13.99%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.41%
# Scanning for divergences...
# Found 1623 bars with divergences
# Running strategy...
#
# [1415/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=135, win_rate=72.59%, avg_pnl=0.11%, total_return=14.65%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.34%
# Scanning for divergences...
# Found 1623 bars with divergences
# Running strategy...
#
# [1416/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=135, win_rate=72.59%, avg_pnl=0.11%, total_return=14.65%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.34%
# Scanning for divergences...
# Found 1588 bars with divergences
# Running strategy...
#
# [1417/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=74.10%, avg_pnl=0.12%, total_return=16.54%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.32%
# Scanning for divergences...
# Found 1619 bars with divergences
# Running strategy...
#
# [1418/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=144, win_rate=72.92%, avg_pnl=0.12%, total_return=16.87%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.32%
# Scanning for divergences...
# Found 1545 bars with divergences
# Running strategy...
#
# [1419/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=136, win_rate=75.00%, avg_pnl=0.14%, total_return=19.00%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.31%
# Scanning for divergences...
# Found 1545 bars with divergences
# Running strategy...
#
# [1420/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=136, win_rate=75.00%, avg_pnl=0.14%, total_return=19.00%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.31%
# Scanning for divergences...
# Found 1520 bars with divergences
# Running strategy...
#
# [1421/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=128, win_rate=73.44%, avg_pnl=0.13%, total_return=16.76%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.33%
# Scanning for divergences...
# Found 1553 bars with divergences
# Running strategy...
#
# [1422/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=132, win_rate=71.97%, avg_pnl=0.13%, total_return=17.57%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.34%
# Scanning for divergences...
# Found 1476 bars with divergences
# Running strategy...
#
# [1423/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=124, win_rate=74.19%, avg_pnl=0.15%, total_return=18.85%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.32%
# Scanning for divergences...
# Found 1476 bars with divergences
# Running strategy...
#
# [1424/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=124, win_rate=74.19%, avg_pnl=0.15%, total_return=18.85%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.32%
# Scanning for divergences...
# Found 1710 bars with divergences
# Running strategy...
#
# [1425/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=148, win_rate=72.97%, avg_pnl=0.07%, total_return=10.27%, max_dd=5.32%, avg_dd=0.68%, median_dd=0.34%
# Scanning for divergences...
# Found 1737 bars with divergences
# Running strategy...
#
# [1426/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=154, win_rate=70.78%, avg_pnl=0.07%, total_return=10.51%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.38%
# Scanning for divergences...
# Found 1675 bars with divergences
# Running strategy...
#
# [1427/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=141, win_rate=72.34%, avg_pnl=0.07%, total_return=9.91%, max_dd=5.32%, avg_dd=0.69%, median_dd=0.34%
# Scanning for divergences...
# Found 1675 bars with divergences
# Running strategy...
#
# [1428/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=141, win_rate=72.34%, avg_pnl=0.07%, total_return=9.91%, max_dd=5.32%, avg_dd=0.69%, median_dd=0.34%
# Scanning for divergences...
# Found 1654 bars with divergences
# Running strategy...
#
# [1429/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=141, win_rate=73.76%, avg_pnl=0.10%, total_return=14.21%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.38%
# Scanning for divergences...
# Found 1682 bars with divergences
# Running strategy...
#
# [1430/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=148, win_rate=70.95%, avg_pnl=0.08%, total_return=12.45%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.41%
# Scanning for divergences...
# Found 1618 bars with divergences
# Running strategy...
#
# [1431/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=73.13%, avg_pnl=0.10%, total_return=13.65%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.36%
# Scanning for divergences...
# Found 1618 bars with divergences
# Running strategy...
#
# [1432/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=73.13%, avg_pnl=0.10%, total_return=13.65%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.36%
# Scanning for divergences...
# Found 1576 bars with divergences
# Running strategy...
#
# [1433/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=140, win_rate=75.00%, avg_pnl=0.13%, total_return=17.66%, max_dd=4.41%, avg_dd=0.65%, median_dd=0.33%
# Scanning for divergences...
# Found 1607 bars with divergences
# Running strategy...
#
# [1434/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=145, win_rate=73.79%, avg_pnl=0.14%, total_return=20.08%, max_dd=4.41%, avg_dd=0.63%, median_dd=0.34%
# Scanning for divergences...
# Found 1535 bars with divergences
# Running strategy...
#
# [1435/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=135, win_rate=75.56%, avg_pnl=0.15%, total_return=20.24%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.32%
# Scanning for divergences...
# Found 1535 bars with divergences
# Running strategy...
#
# [1436/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=135, win_rate=75.56%, avg_pnl=0.15%, total_return=20.24%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.32%
# Scanning for divergences...
# Found 1512 bars with divergences
# Running strategy...
#
# [1437/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=130, win_rate=74.62%, avg_pnl=0.14%, total_return=18.54%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.35%
# Scanning for divergences...
# Found 1545 bars with divergences
# Running strategy...
#
# [1438/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=135, win_rate=72.59%, avg_pnl=0.14%, total_return=19.03%, max_dd=4.41%, avg_dd=0.63%, median_dd=0.38%
# Scanning for divergences...
# Found 1469 bars with divergences
# Running strategy...
#
# [1439/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=124, win_rate=75.00%, avg_pnl=0.17%, total_return=20.86%, max_dd=4.41%, avg_dd=0.63%, median_dd=0.34%
# Scanning for divergences...
# Found 1469 bars with divergences
# Running strategy...
#
# [1440/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=124, win_rate=75.00%, avg_pnl=0.17%, total_return=20.86%, max_dd=4.41%, avg_dd=0.63%, median_dd=0.34%
# Scanning for divergences...
# Found 1714 bars with divergences
# Running strategy...
#
# [1441/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=145, win_rate=73.10%, avg_pnl=0.08%, total_return=11.41%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.33%
# Scanning for divergences...
# Found 1742 bars with divergences
# Running strategy...
#
# [1442/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=70.86%, avg_pnl=0.06%, total_return=9.66%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.35%
# Scanning for divergences...
# Found 1683 bars with divergences
# Running strategy...
#
# [1443/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=140, win_rate=72.14%, avg_pnl=0.08%, total_return=10.61%, max_dd=5.32%, avg_dd=0.68%, median_dd=0.33%
# Scanning for divergences...
# Found 1683 bars with divergences
# Running strategy...
#
# [1444/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=140, win_rate=72.14%, avg_pnl=0.08%, total_return=10.61%, max_dd=5.32%, avg_dd=0.68%, median_dd=0.33%
# Scanning for divergences...
# Found 1654 bars with divergences
# Running strategy...
#
# [1445/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=72.66%, avg_pnl=0.10%, total_return=14.45%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.38%
# Scanning for divergences...
# Found 1683 bars with divergences
# Running strategy...
#
# [1446/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=145, win_rate=71.03%, avg_pnl=0.10%, total_return=14.45%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.41%
# Scanning for divergences...
# Found 1622 bars with divergences
# Running strategy...
#
# [1447/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=133, win_rate=72.18%, avg_pnl=0.11%, total_return=14.17%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.34%
# Scanning for divergences...
# Found 1622 bars with divergences
# Running strategy...
#
# [1448/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=133, win_rate=72.18%, avg_pnl=0.11%, total_return=14.17%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.34%
# Scanning for divergences...
# Found 1583 bars with divergences
# Running strategy...
#
# [1449/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=137, win_rate=74.45%, avg_pnl=0.12%, total_return=16.95%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.32%
# Scanning for divergences...
# Found 1615 bars with divergences
# Running strategy...
#
# [1450/2048]
# ...
# Found 1666 bars with divergences
# Running strategy...
#
# [2022/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=70.50%, avg_pnl=0.08%, total_return=11.68%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.41%
# Scanning for divergences...
# Found 1603 bars with divergences
# Running strategy...
#
# [2023/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=128, win_rate=71.09%, avg_pnl=0.10%, total_return=12.26%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.36%
# Scanning for divergences...
# Found 1603 bars with divergences
# Running strategy...
#
# [2024/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=128, win_rate=71.09%, avg_pnl=0.10%, total_return=12.26%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.36%
# Scanning for divergences...
# Found 1592 bars with divergences
# Running strategy...
#
# [2025/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=137, win_rate=75.18%, avg_pnl=0.16%, total_return=21.60%, max_dd=5.32%, avg_dd=0.63%, median_dd=0.34%
# Scanning for divergences...
# Found 1612 bars with divergences
# Running strategy...
#
# [2026/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=144, win_rate=72.92%, avg_pnl=0.14%, total_return=20.30%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.35%
# Scanning for divergences...
# Found 1558 bars with divergences
# Running strategy...
#
# [2027/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=133, win_rate=75.19%, avg_pnl=0.17%, total_return=23.05%, max_dd=5.32%, avg_dd=0.62%, median_dd=0.32%
# Scanning for divergences...
# Found 1558 bars with divergences
# Running strategy...
#
# [2028/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=133, win_rate=75.19%, avg_pnl=0.17%, total_return=23.05%, max_dd=5.32%, avg_dd=0.62%, median_dd=0.32%
# Scanning for divergences...
# Found 1496 bars with divergences
# Running strategy...
#
# [2029/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=121, win_rate=71.90%, avg_pnl=0.11%, total_return=13.01%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.34%
# Scanning for divergences...
# Found 1529 bars with divergences
# Running strategy...
#
# [2030/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=126, win_rate=71.43%, avg_pnl=0.12%, total_return=14.90%, max_dd=5.32%, avg_dd=0.64%, median_dd=0.36%
# Scanning for divergences...
# Found 1455 bars with divergences
# Running strategy...
#
# [2031/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=116, win_rate=72.41%, avg_pnl=0.13%, total_return=15.63%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.32%
# Scanning for divergences...
# Found 1455 bars with divergences
# Running strategy...
#
# [2032/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=116, win_rate=72.41%, avg_pnl=0.13%, total_return=15.63%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.32%
# Scanning for divergences...
# Found 1701 bars with divergences
# Running strategy...
#
# [2033/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=147, win_rate=72.11%, avg_pnl=0.11%, total_return=15.91%, max_dd=5.32%, avg_dd=0.65%, median_dd=0.40%
# Scanning for divergences...
# Found 1719 bars with divergences
# Running strategy...
#
# [2034/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=155, win_rate=70.97%, avg_pnl=0.08%, total_return=12.13%, max_dd=5.32%, avg_dd=0.66%, median_dd=0.40%
# Scanning for divergences...
# Found 1674 bars with divergences
# Running strategy...
#
# [2035/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=141, win_rate=70.92%, avg_pnl=0.10%, total_return=14.55%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.44%
# Scanning for divergences...
# Found 1674 bars with divergences
# Running strategy...
#
# [2036/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=141, win_rate=70.92%, avg_pnl=0.10%, total_return=14.55%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.44%
# Scanning for divergences...
# Found 1622 bars with divergences
# Running strategy...
#
# [2037/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=133, win_rate=72.18%, avg_pnl=0.08%, total_return=10.95%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.38%
# Scanning for divergences...
# Found 1653 bars with divergences
# Running strategy...
#
# [2038/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=70.50%, avg_pnl=0.06%, total_return=8.24%, max_dd=5.32%, avg_dd=0.67%, median_dd=0.44%
# Scanning for divergences...
# Found 1590 bars with divergences
# Running strategy...
#
# [2039/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=127, win_rate=70.87%, avg_pnl=0.08%, total_return=9.87%, max_dd=5.32%, avg_dd=0.69%, median_dd=0.40%
# Scanning for divergences...
# Found 1590 bars with divergences
# Running strategy...
#
# [2040/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=127, win_rate=70.87%, avg_pnl=0.08%, total_return=9.87%, max_dd=5.32%, avg_dd=0.69%, median_dd=0.40%
# Scanning for divergences...
# Found 1576 bars with divergences
# Running strategy...
#
# [2041/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=138, win_rate=75.36%, avg_pnl=0.16%, total_return=22.71%, max_dd=4.41%, avg_dd=0.62%, median_dd=0.39%
# Scanning for divergences...
# Found 1596 bars with divergences
# Running strategy...
#
# [2042/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=145, win_rate=73.10%, avg_pnl=0.14%, total_return=19.70%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.40%
# Scanning for divergences...
# Found 1542 bars with divergences
# Running strategy...
#
# [2043/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=74.63%, avg_pnl=0.18%, total_return=23.60%, max_dd=4.41%, avg_dd=0.62%, median_dd=0.36%
# Scanning for divergences...
# Found 1542 bars with divergences
# Running strategy...
#
# [2044/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=74.63%, avg_pnl=0.18%, total_return=23.60%, max_dd=4.41%, avg_dd=0.62%, median_dd=0.36%
# Scanning for divergences...
# Found 1481 bars with divergences
# Running strategy...
#
# [2045/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=121, win_rate=72.73%, avg_pnl=0.13%, total_return=15.17%, max_dd=4.41%, avg_dd=0.65%, median_dd=0.38%
# Scanning for divergences...
# Found 1515 bars with divergences
# Running strategy...
#
# [2046/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=127, win_rate=72.44%, avg_pnl=0.12%, total_return=15.38%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.40%
# Scanning for divergences...
# Found 1440 bars with divergences
# Running strategy...
#
# [2047/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=116, win_rate=73.28%, avg_pnl=0.15%, total_return=17.29%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.35%
# Scanning for divergences...
# Found 1440 bars with divergences
# Running strategy...
#
# [2048/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=116, win_rate=73.28%, avg_pnl=0.15%, total_return=17.29%, max_dd=4.41%, avg_dd=0.64%, median_dd=0.35%
#   💾 checkpoint saved: divergence_param_grid_results_partial.csv
#
# ===============================================
# 🏆 TOP 10 PARAMETER SETS (by total_return, win_rate, low max_dd)
# ===============================================
#    cci_window  cmf_window  mfi_window  mom_window  pivot_prd  rsi_window  \
# 0          10          14          20          10          5           7
# 1          10          14          20          10          5           7
# 2          10          21          20          10          5           7
# 3          10          21          20          10          5           7
# 4          10          14          20           5          5          10
# 5          10          14          20           5          5          10
# 6          10          14          20          10          5          10
# 7          10          14          20          10          5          10
# 8          10          21          20          10          5          10
# 9          10          21          20          10          5          10
#
#    stoch_smooth  stoch_window  use_cmf  use_mfi  use_vwmacd  vwma_fast  \
# 0             3            14    False     True       False          8
# 1             3            14    False     True       False         12
# 2             3            14    False     True       False          8
# 3             3            14    False     True       False         12
# 4             3             9     True     True       False          8
# 5             3             9     True     True       False         12
# 6             3            14    False     True       False          8
# 7             3            14    False     True       False         12
# 8             3            14    False     True       False          8
# 9             3            14    False     True       False         12
#
#    vwma_slow  total_trades   win_rate   avg_pnl  total_return    max_dd  \
# 0         26           138  76.811594  0.181772     25.084489  4.410684
# 1         26           138  76.811594  0.181772     25.084489  4.410684
# 2         26           138  76.811594  0.181772     25.084489  4.410684
# 3         26           138  76.811594  0.181772     25.084489  4.410684
# 4         26           154  74.025974  0.160575     24.728552  5.323577
# 5         26           154  74.025974  0.160575     24.728552  5.323577
# 6         26           137  75.912409  0.179885     24.644181  4.410684
# 7         26           137  75.912409  0.179885     24.644181  4.410684
# 8         26           137  75.912409  0.179885     24.644181  4.410684
# 9         26           137  75.912409  0.179885     24.644181  4.410684
#
#      avg_dd  median_dd
# 0  0.618308   0.348116
# 1  0.618308   0.348116
# 2  0.618308   0.348116
# 3  0.618308   0.348116
# 4  0.614967   0.330169
# 5  0.614967   0.330169
# 6  0.627830   0.352052
# 7  0.627830   0.352052
# 8  0.627830   0.352052
# 9  0.627830   0.352052
#
# 📁 Full grid-search results saved to: divergence_param_grid_results.csv
#
# 🔥 BEST PARAMS FOUND:
#   rsi_window: 7
#   stoch_window: 14
#   stoch_smooth: 3
#   mom_window: 10
#   cci_window: 10
#   mfi_window: 20
#   vwma_fast: 8
#   vwma_slow: 26
#   cmf_window: 14
#   pivot_prd: 5
#   use_vwmacd: False
#   use_cmf: False
#   use_mfi: True
# Scanning for divergences...
# Found 1563 bars with divergences
# Running strategy...
#
# Best metrics on full sample:
# {'total_trades': 138, 'win_rate': 76.81159420289855, 'avg_pnl': 0.18177166026986402, 'total_return': 25.084489117241233, 'max_dd': 4.410684154122724, 'avg_dd': 0.6183080532152724, 'median_dd': 0.3481160932926851}

# %%
#===============================================================================
# CELL 4: AI-LIKE NOTEWORTHY INSIGHTS
#   - Detect patterns in best vs rest
#   - Cluster strategy styles (aggressive / balanced / defensive)
#===============================================================================

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

def ai_noteworthy_insights(results_df, param_grid, min_trades=30, top_quantile=0.8):
    df = results_df.copy()

    #-------------------------------
    # 0) فلترة مبدئية
    #-------------------------------
    df = df[df["total_trades"] >= min_trades].copy()
    if df.empty:
        print(f"[AI] No parameter sets with >= {min_trades} trades. Nothing to analyse.")
        return None

    param_cols = list(param_grid.keys())

    # لو عندك edge_score من الـ dashboard cell، استخدمه
    if "edge_score" not in df.columns:
        # لو مش موجود، نبنيه بسرعة
        df["edge_score"] = (
            df["total_return"]
            - df["max_dd"] * 1.5
            + (df["win_rate"] - 50) * 0.7
        )

    #-------------------------------
    # 1) تقسيم Elite vs Rest
    #-------------------------------
    q = df["edge_score"].quantile(top_quantile)
    elite = df[df["edge_score"] >= q].copy()
    rest  = df[df["edge_score"] <  q].copy()

    print("\n=================================================")
    print("🧠 AI Noteworthy Insights - Global Overview")
    print("=================================================")
    print(f"Total parameter sets (filtered) : {len(df)}")
    print(f"Elite cutoff (edge_score q{int(top_quantile*100)}): {q:.2f}")
    print(f"Elite count                     : {len(elite)}")
    print(f"Rest count                      : {len(rest)}")

    #-------------------------------
    # 2) Noteworthy patterns per parameter
    #-------------------------------
    print("\n-------------------------------------------------")
    print("📌 PARAMETER PATTERNS (Elite vs Rest)")
    print("-------------------------------------------------")

    insights_param = []

    for col in param_cols:
        col_type = df[col].dtype

        if col_type == bool:
            # نسبة استخدام True في النخبة مقابل الباقي
            elite_true = elite[col].mean()
            rest_true  = rest[col].mean()
            diff = elite_true - rest_true

            if abs(diff) > 0.15:  # 15% فرق يعتبر noteworthy
                direction = "more" if diff > 0 else "less"
                insights_param.append(
                    f"- Elite setups use **{col} = True** {direction} often "
                    f"(elite: {elite_true*100:.1f}%, rest: {rest_true*100:.1f}%)"
                )

        else:
            # أرقام (windows / pivot_prd / ...)
            elite_mean = elite[col].mean()
            rest_mean  = rest[col].mean()
            col_min, col_max = df[col].min(), df[col].max()
            value_range = col_max - col_min if col_max != col_min else 1.0

            diff = elite_mean - rest_mean
            rel = diff / value_range  # normalized diff

            if abs(rel) > 0.15:  # 15% من الرينج
                if diff < 0:
                    insight = (
                        f"- Elite prefer **lower {col}** "
                        f"(elite≈{elite_mean:.2f}, rest≈{rest_mean:.2f}, range[{col_min}, {col_max}])"
                    )
                else:
                    insight = (
                        f"- Elite prefer **higher {col}** "
                        f"(elite≈{elite_mean:.2f}, rest≈{rest_mean:.2f}, range[{col_min}, {col_max}])"
                    )
                insights_param.append(insight)

    if insights_param:
        for line in insights_param:
            print(line)
    else:
        print("- No very strong parameter shifts detected (elite vs rest).")

    #-------------------------------
    # 3) Performance profile differences
    #-------------------------------
    perf_cols = ["total_return", "win_rate", "max_dd", "avg_pnl", "median_dd"]

    print("\n-------------------------------------------------")
    print("📊 PERFORMANCE PROFILE (Elite vs Rest)")
    print("-------------------------------------------------")

    def summarize_group(name, g):
        print(f"\n{name}:")
        print(f"  total_return (sum%) : {g['total_return'].mean():+.2f}%")
        print(f"  win_rate            : {g['win_rate'].mean():.2f}%")
        print(f"  max_dd              : {g['max_dd'].mean():.2f}%")
        print(f"  median_dd           : {g['median_dd'].mean():.2f}%")
        print(f"  avg_pnl per trade   : {g['avg_pnl'].mean():+.2f}%")
        print(f"  avg trades          : {g['total_trades'].mean():.1f}")

    summarize_group("Elite", elite)
    summarize_group("Rest", rest)

    #-------------------------------
    # 4) Clustering strategy styles
    #-------------------------------
    print("\n-------------------------------------------------")
    print("🎨 STRATEGY STYLE CLUSTERS")
    print("-------------------------------------------------")

    cluster_features = df[["total_return", "win_rate", "max_dd", "median_dd"]].copy()

    scaler = StandardScaler()
    X = scaler.fit_transform(cluster_features)

    # 3 ستايلات مبدئيًا
    kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
    df["cluster"] = kmeans.fit_predict(X)

    cluster_summary = []
    for c in sorted(df["cluster"].unique()):
        g = df[df["cluster"] == c]
        avg_ret = g["total_return"].mean()
        avg_dd  = g["max_dd"].mean()
        avg_wr  = g["win_rate"].mean()

        # نحاول نسمي الستايل بناءً على pattern
        if avg_ret > 0 and avg_dd > 1.2 * df["max_dd"].mean():
            style = "Aggressive (High return, High DD)"
        elif avg_ret > 0 and avg_dd < df["max_dd"].mean():
            style = "Balanced/Defensive (Decent return, Lower DD)"
        else:
            style = "Low-edge / noisy"

        cluster_summary.append(
            (c, style, avg_ret, avg_dd, avg_wr, len(g))
        )

    # اطبع ملخص الكلاسترز
    for c, style, avg_ret, avg_dd, avg_wr, count in sorted(
        cluster_summary, key=lambda x: x[2], reverse=True
    ):
        print(f"\nCluster {c}: {style}")
        print(f"  Members        : {count}")
        print(f"  Avg total_ret  : {avg_ret:+.2f}%")
        print(f"  Avg max_dd     : {avg_dd:.2f}%")
        print(f"  Avg win_rate   : {avg_wr:.2f}%")

        # عرض أفضل 3 setups في الكلاستر ده
        top3 = df[df["cluster"] == c].sort_values(
            by="edge_score", ascending=False
        ).head(3)

        print("  👉 Top examples (edge_score, total_return, max_dd, win_rate):")
        for _, row in top3.iterrows():
            print(
                f"    - edge={row['edge_score']:+.2f}, "
                f"tot_ret={row['total_return']:+.2f}%, "
                f"max_dd={row['max_dd']:.2f}%, "
                f"WR={row['win_rate']:.2f}% "
                f"({', '.join(f'{p}={row[p]}' for p in param_cols)})"
            )

    print("\n=================================================")
    print("✅ AI Noteworthies finished.")
    print("   Use this to:")
    print("   - Fix some params near elite-preferred values.")
    print("   - Pick one cluster that matches your risk profile.")
    print("=================================================")

    return df, elite, rest


# Run it:
ai_df, elite_df, rest_df = ai_noteworthy_insights(
    results_df,
    param_grid,
    min_trades=30,      # تقدر تزود/تقلل
    top_quantile=0.8    # top 20% as Elite
)
# Out:
# =================================================
# 🧠 AI Noteworthy Insights - Global Overview
# =================================================
# Total parameter sets (filtered) : 2048
# Elite cutoff (edge_score q80): 24.97
# Elite count                     : 410
# Rest count                      : 1638
#
# -------------------------------------------------
# 📌 PARAMETER PATTERNS (Elite vs Rest)
# -------------------------------------------------
# - Elite prefer **lower rsi_window** (elite≈11.14, rest≈13.47, range[7, 21])
# - Elite prefer **higher mom_window** (elite≈8.33, rest≈7.29, range[5, 10])
# - Elite prefer **higher mfi_window** (elite≈16.76, rest≈14.56, range[10, 20])
# - Elite prefer **higher pivot_prd** (elite≈4.93, rest≈3.77, range[3, 5])
#
# -------------------------------------------------
# 📊 PERFORMANCE PROFILE (Elite vs Rest)
# -------------------------------------------------
#
# Elite:
#   total_return (sum%) : +19.62%
#   win_rate            : 73.79%
#   max_dd              : 5.09%
#   median_dd           : 0.34%
#   avg_pnl per trade   : +0.14%
#   avg trades          : 143.1
#
# Rest:
#   total_return (sum%) : +11.92%
#   win_rate            : 68.67%
#   max_dd              : 5.65%
#   median_dd           : 0.31%
#   avg_pnl per trade   : +0.07%
#   avg trades          : 179.0
#
# -------------------------------------------------
# 🎨 STRATEGY STYLE CLUSTERS
# -------------------------------------------------
#
# Cluster 2: Balanced/Defensive (Decent return, Lower DD)
#   Members        : 1032
#   Avg total_ret  : +15.93%
#   Avg max_dd     : 5.21%
#   Avg win_rate   : 72.65%
#   👉 Top examples (edge_score, total_return, max_dd, win_rate):
#     - edge=+37.24, tot_ret=+25.08%, max_dd=4.41%, WR=76.81% (rsi_window=7, stoch_window=14, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=8, vwma_slow=26, cmf_window=14, pivot_prd=5, use_vwmacd=False, use_cmf=False, use_mfi=True)
#     - edge=+37.24, tot_ret=+25.08%, max_dd=4.41%, WR=76.81% (rsi_window=7, stoch_window=14, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=12, vwma_slow=26, cmf_window=14, pivot_prd=5, use_vwmacd=False, use_cmf=False, use_mfi=True)
#     - edge=+37.24, tot_ret=+25.08%, max_dd=4.41%, WR=76.81% (rsi_window=7, stoch_window=14, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=8, vwma_slow=26, cmf_window=21, pivot_prd=5, use_vwmacd=False, use_cmf=False, use_mfi=True)
#
# Cluster 0: Balanced/Defensive (Decent return, Lower DD)
#   Members        : 397
#   Avg total_ret  : +12.98%
#   Avg max_dd     : 5.37%
#   Avg win_rate   : 67.67%
#   👉 Top examples (edge_score, total_return, max_dd, win_rate):
#     - edge=+27.66, tot_ret=+21.76%, max_dd=5.32%, WR=69.83% (rsi_window=10, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=10, vwma_fast=12, vwma_slow=26, cmf_window=14, pivot_prd=3, use_vwmacd=True, use_cmf=True, use_mfi=False)
#     - edge=+27.66, tot_ret=+21.76%, max_dd=5.32%, WR=69.83% (rsi_window=10, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=12, vwma_slow=26, cmf_window=14, pivot_prd=3, use_vwmacd=True, use_cmf=True, use_mfi=False)
#     - edge=+27.06, tot_ret=+21.61%, max_dd=5.32%, WR=69.20% (rsi_window=7, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=10, vwma_fast=12, vwma_slow=26, cmf_window=14, pivot_prd=3, use_vwmacd=True, use_cmf=True, use_mfi=False)
#
# Cluster 1: Low-edge / noisy
#   Members        : 619
#   Avg total_ret  : +9.66%
#   Avg max_dd     : 6.20%
#   Avg win_rate   : 66.05%
#   👉 Top examples (edge_score, total_return, max_dd, win_rate):
#     - edge=+21.31, tot_ret=+16.97%, max_dd=6.20%, WR=69.47% (rsi_window=14, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=8, vwma_slow=26, cmf_window=14, pivot_prd=3, use_vwmacd=False, use_cmf=False, use_mfi=True)
#     - edge=+21.31, tot_ret=+16.97%, max_dd=6.20%, WR=69.47% (rsi_window=14, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=12, vwma_slow=26, cmf_window=21, pivot_prd=3, use_vwmacd=False, use_cmf=False, use_mfi=True)
#     - edge=+21.31, tot_ret=+16.97%, max_dd=6.20%, WR=69.47% (rsi_window=14, stoch_window=9, stoch_smooth=3, mom_window=10, cci_window=10, mfi_window=20, vwma_fast=8, vwma_slow=26, cmf_window=21, pivot_prd=3, use_vwmacd=False, use_cmf=False, use_mfi=True)
#
# =================================================
# ✅ AI Noteworthies finished.
#    Use this to:
#    - Fix some params near elite-preferred values.
#    - Pick one cluster that matches your risk profile.
# =================================================
