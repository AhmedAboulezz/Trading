# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAboulezz/Trading/blob/main/Divergence_Pipeline_Optimized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install pandas numpy matplotlib plotly scipy ta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.signal import argrelextrema
import ta
from datetime import datetime
import warnings
from numba import njit
warnings.filterwarnings('ignore')

#------------------------------------------------------------------------------
# CONFIGURATION PARAMETERS
#------------------------------------------------------------------------------

class Config:
    # Pivot settings
    prd = 5  # Pivot Period
    source = "Close"  # Source for Pivot Points: "Close" or "High/Low"

    # Divergence settings
    searchdiv = "Regular"  # "Regular", "Hidden", or "Regular/Hidden"
    showlimit = 1  # Minimum Number of Divergence (any)
    maxpp = 10  # Maximum Pivot Points to Check
    maxbars = 100  # Maximum Bars to Check
    dontconfirm = False  # Don't Wait for Confirmation

    # Quality filter
    minPosDivForEntry = 2  # Min # of Positive Divergence for Valid Long
    minNegDivForExit = 1   # Min # of Negative Divergence for Exit

    # Entry delay and drawdown
    delayBars = 0  # Delay For Entry (Bars)
    useDrawdown = False  # Use % Drawdown Before Entry
    drawdownPerc = 1.0  # Drawdown %

    # Indicator selection (all enabled by default)
    calcmacd = True
    calcmacda = True
    calcrsi = True
    calcstoc = True
    calccci = True
    calcmom = True
    calcobv = False
    calcvwmacd = True
    calccmf = True
    calcmfi = True

    # Backtest settings
    initial_capital = 10000
    position_size = 1.0  # Use 100% of capital per trade

config = Config()

#------------------------------------------------------------------------------
# DATA LOADING
#------------------------------------------------------------------------------

def load_data_from_csv(filepath):
    """Load OHLC data from CSV file"""
    print(f"Loading data from {filepath}...")

    # Read CSV
    df = pd.read_csv(filepath)

    # Normalize column names to lowercase
    df.columns = [col.lower().strip() for col in df.columns]

    # Parse time column
    df['time'] = pd.to_datetime(df['time'])
    df.set_index('time', inplace=True)

    # Ensure we have required columns
    required_cols = ['open', 'high', 'low', 'close']
    for col in required_cols:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")

    # Add volume if not present (needed for some indicators)
    if 'volume' not in df.columns:
        df['volume'] = 1000000  # Default volume
        print("Warning: No volume column found, using default values")

    print(f"Loaded {len(df)} bars from {df.index[0]} to {df.index[-1]}")
    return df

#------------------------------------------------------------------------------
# TECHNICAL INDICATORS
#------------------------------------------------------------------------------


def calculate_indicators(df):
    df = df.copy()

    close = df["close"].astype(float)
    high  = df["high"].astype(float)
    low   = df["low"].astype(float)
    vol   = df["volume"].astype(float)  # أو "volume" حسب اسم العمود عندك

    # ------------------------------------------------------------------
    # RSI, MACD, VW-MACD, CMF, ... خليهـم زي ما أنت عاملهم لو متطابقين
    # ------------------------------------------------------------------
    import ta

    # RSI(14) - مطابق لـ ta.rsi(close, 14)
    df["rsi"] = ta.momentum.RSIIndicator(close=close, window=14).rsi()

    # MACD(12,26,9)
    macd_ind = ta.trend.MACD(close=close, window_slow=26,
                             window_fast=12, window_sign=9)
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # Momentum(10)
    df["momentum"] = close - close.shift(10)

    # VW-MACD = VWMA(12) - VWMA(26) (نفس Pine)
    vwma_fast = (close * vol).rolling(12).sum() / vol.rolling(12).sum()
    vwma_slow = (close * vol).rolling(26).sum() / vol.rolling(26).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # CMF(21) زي Pine
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high=high, low=low, close=close, volume=vol, window=21
    ).chaikin_money_flow()

    # ==============================================================
    # ✅ 1) Stochastic(14,3) مطابق لـ Stochastic(14,3) في Pine
    # ==============================================================
    lowest_low_14  = low.rolling(window=14, min_periods=14).min()
    highest_high_14 = high.rolling(window=14, min_periods=14).max()

    stoch_k = 100.0 * (close - lowest_low_14) / (highest_high_14 - lowest_low_14)
    df["stoch"] = stoch_k.rolling(window=3, min_periods=3).mean()

    # ==============================================================
    # ✅ 2) CCI(10) باستخدام الـ close (نفس Pine في csv)
    # ==============================================================
    n_cci = 10
    sma_close = close.rolling(n_cci, min_periods=n_cci).mean()

    # mean absolute deviation من الـ sma على الـ close
    mad_close = close.rolling(n_cci, min_periods=n_cci).apply(
        lambda x: np.mean(np.abs(x - x.mean())),
        raw=True
    )

    df["cci"] = (close - sma_close) / (0.015 * mad_close)

    # ==============================================================
    # ✅ 3) MFI(14) باستخدام الـ close كـ price
    # ==============================================================
    n_mfi = 14
    price = close

    raw_mf = price * vol
    pos_mf = [0.0]
    neg_mf = [0.0]

    for i in range(1, len(df)):
        if price.iloc[i] > price.iloc[i - 1]:
            pos_mf.append(raw_mf.iloc[i])
            neg_mf.append(0.0)
        elif price.iloc[i] < price.iloc[i - 1]:
            pos_mf.append(0.0)
            neg_mf.append(raw_mf.iloc[i])
        else:
            pos_mf.append(0.0)
            neg_mf.append(0.0)

    pos_mf = pd.Series(pos_mf, index=df.index)
    neg_mf = pd.Series(neg_mf, index=df.index)

    pos_roll = pos_mf.rolling(n_mfi, min_periods=n_mfi).sum()
    neg_roll = neg_mf.rolling(n_mfi, min_periods=n_mfi).sum()

    mfi = 100.0 * (pos_roll / (pos_roll + neg_roll))
    df["mfi"] = mfi

    # 9) OBV (هنسيبه زي ما انت عامل)
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i-1]:
            obv_values.append(obv_values[-1] + vol.iloc[i])
        elif close.iloc[i] < close.iloc[i-1]:
            obv_values.append(obv_values[-1] - vol.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df['obv'] = obv_values

    df = df.fillna(method='bfill').fillna(method='ffill')

    # ==============================================================
    # OBV زي ما تحب (وانت أصلاً قلت سيبه)
    # ==============================================================
    # ممكن تخليه زي Pine لو حابب لاحقًا، بس مش ضروري دلوقتي

    return df


#------------------------------------------------------------------------------
# PIVOT POINT DETECTION
#------------------------------------------------------------------------------

def find_pivots(df, period):
    """Find pivot highs and pivot lows"""
    print(f"Finding pivot points with period {period}...")

    if config.source == "Close":
        high_series = df['close']
        low_series = df['close']
    else:
        high_series = df['high']
        low_series = df['low']

    # Initialize pivot columns
    df['pivot_high'] = np.nan
    df['pivot_high_bar'] = np.nan
    df['pivot_low'] = np.nan
    df['pivot_low_bar'] = np.nan

    for i in range(period, len(df) - period):
        # Check pivot high
        is_pivot_high = True
        for j in range(1, period + 1):
            if high_series.iloc[i] <= high_series.iloc[i - j] or \
               high_series.iloc[i] <= high_series.iloc[i + j]:
                is_pivot_high = False
                break

        if is_pivot_high:
            df.iloc[i, df.columns.get_loc('pivot_high')] = high_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_high_bar')] = i

        # Check pivot low
        is_pivot_low = True
        for j in range(1, period + 1):
            if low_series.iloc[i] >= low_series.iloc[i - j] or \
               low_series.iloc[i] >= low_series.iloc[i + j]:
                is_pivot_low = False
                break

        if is_pivot_low:
            df.iloc[i, df.columns.get_loc('pivot_low')] = low_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_low_bar')] = i

    num_highs = df['pivot_high'].notna().sum()
    num_lows = df['pivot_low'].notna().sum()
    print(f"Found {num_highs} pivot highs and {num_lows} pivot lows")

    return df

#------------------------------------------------------------------------------
# DIVERGENCE DETECTION
#------------------------------------------------------------------------------

def detect_divergence(df, indicator_name, bar_idx, pivot_positions, pivot_values,
                     is_bullish, is_regular):
    """
    Detect divergence at a specific bar
    Returns: length of divergence if found, else 0
    """

    if bar_idx < config.prd:
        return 0

    startpoint = 0 if config.dontconfirm else 1

    if config.source == "Close":
        price_series = df['close'].values
    else:
        price_series = df['low'].values if is_bullish else df['high'].values

    indicator_series = df[indicator_name].values

    # Check confirmation condition
    if not config.dontconfirm:
        if is_bullish:
            if not (indicator_series[bar_idx] > indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] > df['close'].values[bar_idx - 1]):
                return 0
        else:
            if not (indicator_series[bar_idx] < indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] < df['close'].values[bar_idx - 1]):
                return 0

    # Check each pivot
    for pivot_idx in range(min(config.maxpp, len(pivot_positions))):
        if pivot_idx >= len(pivot_positions) or np.isnan(pivot_positions[pivot_idx]):
            break

        pivot_bar = int(pivot_positions[pivot_idx])
        length = bar_idx - pivot_bar

        if length > config.maxbars:
            break

        if length > 5:
            # Check divergence conditions
            if is_bullish and is_regular:
                # Positive Regular: indicator makes higher low, price makes lower low
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])
            elif is_bullish and not is_regular:
                # Positive Hidden: indicator makes lower low, price makes higher low
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            elif not is_bullish and is_regular:
                # Negative Regular: indicator makes lower high, price makes higher high
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            else:
                # Negative Hidden: indicator makes higher high, price makes lower high
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])

            if div_condition:
                # Check if line is valid (no crossings)
                slope1 = (indicator_series[bar_idx - startpoint] - indicator_series[pivot_bar]) / length
                slope2 = (df['close'].values[bar_idx - startpoint] - df['close'].values[pivot_bar]) / length

                virtual_line1 = indicator_series[bar_idx - startpoint]
                virtual_line2 = df['close'].values[bar_idx - startpoint]

                valid = True
                for y in range(1 + startpoint, length):
                    virtual_line1 -= slope1
                    virtual_line2 -= slope2

                    check_idx = bar_idx - y
                    if is_bullish:
                        if indicator_series[check_idx] < virtual_line1 or \
                           df['close'].values[check_idx] < virtual_line2:
                            valid = False
                            break
                    else:
                        if indicator_series[check_idx] > virtual_line1 or \
                           df['close'].values[check_idx] > virtual_line2:
                            valid = False
                            break

                if valid:
                    return length

    return 0

from collections import deque
import numpy as np
#------------------------------------------------------------------------------
# NUMBA CORES (لا تغيّر اللوجيك، بس تسرّع التنفيذ)
#------------------------------------------------------------------------------

@njit
def _detect_divergence_core(
    indicator_series,
    close_series,
    low_series,
    high_series,
    price_source_code,   # 0 = Close, 1 = High/Low
    bar_idx,
    pivot_positions,
    pivot_values,
    is_bullish,
    is_regular,
    prd,
    dontconfirm,
    maxpp,
    maxbars
):
    # نفس لوجيك detect_divergence تقريباً لكن على arrays جوّه Numba

    if bar_idx < prd:
        return 0

    startpoint = 0 if dontconfirm else 1

    # اختيار price_series
    if price_source_code == 0:
        price_series = close_series
    else:
        if is_bullish:
            price_series = low_series
        else:
            price_series = high_series

    # شرط الـ confirmation
    if not dontconfirm:
        if is_bullish:
            if not (
                indicator_series[bar_idx] > indicator_series[bar_idx - 1]
                or close_series[bar_idx] > close_series[bar_idx - 1]
            ):
                return 0
        else:
            if not (
                indicator_series[bar_idx] < indicator_series[bar_idx - 1]
                or close_series[bar_idx] < close_series[bar_idx - 1]
            ):
                return 0

    n_pivots = len(pivot_positions)

    for pivot_idx in range(min(maxpp, n_pivots)):
        pivot_bar = int(pivot_positions[pivot_idx])
        length = bar_idx - pivot_bar

        if length > maxbars:
            break

        if length > 5:
            # نفس شروط الديفرجنس بالظبط
            if is_bullish and is_regular:
                # Positive Regular
                div_condition = (
                    indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] < pivot_values[pivot_idx]
                )
            elif is_bullish and not is_regular:
                # Positive Hidden
                div_condition = (
                    indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] > pivot_values[pivot_idx]
                )
            elif (not is_bullish) and is_regular:
                # Negative Regular
                div_condition = (
                    indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] > pivot_values[pivot_idx]
                )
            else:
                # Negative Hidden
                div_condition = (
                    indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar]
                    and price_series[bar_idx - startpoint] < pivot_values[pivot_idx]
                )

            if div_condition:
                # خطين افتراضيين ونفس check-crossing
                slope1 = (indicator_series[bar_idx - startpoint] - indicator_series[pivot_bar]) / length
                slope2 = (close_series[bar_idx - startpoint] - close_series[pivot_bar]) / length

                virtual_line1 = indicator_series[bar_idx - startpoint]
                virtual_line2 = close_series[bar_idx - startpoint]

                valid = True
                for y in range(1 + startpoint, length):
                    virtual_line1 -= slope1
                    virtual_line2 -= slope2

                    check_idx = bar_idx - y
                    if is_bullish:
                        if (
                            indicator_series[check_idx] < virtual_line1
                            or close_series[check_idx] < virtual_line2
                        ):
                            valid = False
                            break
                    else:
                        if (
                            indicator_series[check_idx] > virtual_line1
                            or close_series[check_idx] > virtual_line2
                        ):
                            valid = False
                            break

                if valid:
                    return length

    return 0


@njit
def scan_divergences_for_indicator_core(
    indicator_series,
    close_series,
    low_series,
    high_series,
    pivot_high_series,
    pivot_low_series,
    prd,
    searchdiv_code,      # 0 = Regular, 1 = Hidden, 2 = Regular/Hidden
    maxpp,
    maxbars,
    dontconfirm,
    price_source_code    # 0 = Close, 1 = High/Low
):
    n = len(close_series)

    # هنرجّع 4 arrays: لكل نوع ديفرجنس
    pos_reg = np.zeros(n, dtype=np.int16)
    neg_reg = np.zeros(n, dtype=np.int16)
    pos_hid = np.zeros(n, dtype=np.int16)
    neg_hid = np.zeros(n, dtype=np.int16)

    use_reg = (searchdiv_code == 0 or searchdiv_code == 2)
    use_hid = (searchdiv_code == 1 or searchdiv_code == 2)

    for bar_idx in range(prd + 10, n):
        val = indicator_series[bar_idx]
        if np.isnan(val):
            continue

        # نبني pivots حوالين الشمعة دي (بالظبط زي اللوب الأصلي لكن جوّه Numba)
        # low pivots (للـ bullish)
        pivot_low_pos = np.empty(maxpp, dtype=np.float64)
        pivot_low_val = np.empty(maxpp, dtype=np.float64)
        low_count = 0

        stop = max(0, bar_idx - maxbars)
        for j in range(bar_idx - 1, stop, -1):  # نفس range القديم
            v = pivot_low_series[j]
            if not np.isnan(v):
                pivot_low_pos[low_count] = j
                pivot_low_val[low_count] = v
                low_count += 1
                if low_count >= maxpp:
                    break

        # high pivots (للـ bearish)
        pivot_high_pos = np.empty(maxpp, dtype=np.float64)
        pivot_high_val = np.empty(maxpp, dtype=np.float64)
        high_count = 0

        for j in range(bar_idx - 1, stop, -1):
            v = pivot_high_series[j]
            if not np.isnan(v):
                pivot_high_pos[high_count] = j
                pivot_high_val[high_count] = v
                high_count += 1
                if high_count >= maxpp:
                    break

        # === نفس النداءات اللي كنت بتعملها في scan_all_divergences القديم ===

        # Positive Regular (bullish, regular)
        if use_reg and low_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_low_pos[:low_count],
                pivot_low_val[:low_count],
                True,
                True,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                pos_reg[bar_idx] = div_len

        # Negative Regular (bearish, regular)
        if use_reg and high_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_high_pos[:high_count],
                pivot_high_val[:high_count],
                False,
                True,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                neg_reg[bar_idx] = div_len

        # Positive Hidden (bullish, hidden)
        if use_hid and low_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_low_pos[:low_count],
                pivot_low_val[:low_count],
                True,
                False,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                pos_hid[bar_idx] = div_len

        # Negative Hidden (bearish, hidden)
        if use_hid and high_count > 0:
            div_len = _detect_divergence_core(
                indicator_series,
                close_series,
                low_series,
                high_series,
                price_source_code,
                bar_idx,
                pivot_high_pos[:high_count],
                pivot_high_val[:high_count],
                False,
                False,
                prd,
                dontconfirm,
                maxpp,
                maxbars
            )
            if div_len > 0:
                neg_hid[bar_idx] = div_len

    return pos_reg, neg_reg, pos_hid, neg_hid


def scan_all_divergences(df):
    """Scan for all divergences across all indicators (Numba-accelerated core)"""
    print("Scanning for divergences...")

    div_cols = []
    indicators_to_check = []

    if config.calcmacd:
        indicators_to_check.append('macd')
    if config.calcmacda:
        indicators_to_check.append('macd_hist')
    if config.calcrsi:
        indicators_to_check.append('rsi')
    if config.calcstoc:
        indicators_to_check.append('stoch')
    if config.calccci:
        indicators_to_check.append('cci')
    if config.calcmom:
        indicators_to_check.append('momentum')
    if config.calcobv:
        indicators_to_check.append('obv')
    if config.calcvwmacd:
        indicators_to_check.append('vwmacd')
    if config.calccmf:
        indicators_to_check.append('cmf')
    if config.calcmfi:
        indicators_to_check.append('mfi')

    # جهّز الأعمدة (نفس الأسامي القديمة بالظبط)
    for ind in indicators_to_check:
        for div_type in ['pos_reg', 'neg_reg', 'pos_hid', 'neg_hid']:
            col_name = f'{ind}_{div_type}'
            df[col_name] = 0
            div_cols.append(col_name)

    if not indicators_to_check:
        df['total_divergences'] = 0
        df['pos_div_count'] = 0
        df['neg_div_count'] = 0
        print("No indicators selected for divergence scanning")
        return df

    # Arrays مشتركة
    close_arr = df['close'].astype(float).values
    low_arr   = df['low'].astype(float).values
    high_arr  = df['high'].astype(float).values
    pivot_high_arr = df['pivot_high'].astype(float).values
    pivot_low_arr  = df['pivot_low'].astype(float).values

    # Encode config.searchdiv => رقم
    if config.searchdiv == "Regular":
        searchdiv_code = 0
    elif config.searchdiv == "Hidden":
        searchdiv_code = 1
    else:  # "Regular/Hidden"
        searchdiv_code = 2

    # Encode source => رقم
    price_source_code = 0 if config.source == "Close" else 1

    # ننده الـ core لكل indicator لوحده
    for ind in indicators_to_check:
        ind_arr = df[ind].astype(float).values

        pos_reg_arr, neg_reg_arr, pos_hid_arr, neg_hid_arr = scan_divergences_for_indicator_core(
            ind_arr,
            close_arr,
            low_arr,
            high_arr,
            pivot_high_arr,
            pivot_low_arr,
            config.prd,
            searchdiv_code,
            config.maxpp,
            config.maxbars,
            config.dontconfirm,
            price_source_code
        )

        df[f'{ind}_pos_reg'] = pos_reg_arr
        df[f'{ind}_neg_reg'] = neg_reg_arr
        df[f'{ind}_pos_hid'] = pos_hid_arr
        df[f'{ind}_neg_hid'] = neg_hid_arr

    # نفس البوست-بروسسينج القديم بالظبط 👇

    # Count total divergences
    df['total_divergences'] = 0
    for col in div_cols:
        df['total_divergences'] += (df[col] > 0).astype(int)

    # Filter by minimum divergences
    df.loc[df['total_divergences'] < config.showlimit, div_cols] = 0

    # Count positive and negative divergences
    df['pos_div_count'] = 0
    df['neg_div_count'] = 0

    for col in div_cols:
        if 'pos_' in col:
            df['pos_div_count'] += (df[col] > 0).astype(int)
        else:
            df['neg_div_count'] += (df[col] > 0).astype(int)

    total_divs = (df['total_divergences'] > 0).sum()
    print(f"Found {total_divs} bars with divergences")

    return df



#------------------------------------------------------------------------------
# TRADING STRATEGY
#------------------------------------------------------------------------------

def run_strategy(df):
    """Execute trading strategy based on divergences (optimized loop over NumPy arrays)"""
    print("Running strategy...")

    n = len(df)

    # نشتغل على NumPy arrays بدل iloc/loc جوه اللوب
    close_arr = df['close'].values
    open_arr  = df['open'].values
    pos_div   = df['pos_div_count'].values
    neg_div   = df['neg_div_count'].values

    # نجهز الـ outputs كـ arrays
    signal_arr      = np.zeros(n, dtype=np.int8)
    position_arr    = np.zeros(n, dtype=np.int8)
    entry_price_arr = np.full(n, np.nan, dtype=float)
    exit_price_arr  = np.full(n, np.nan, dtype=float)

    # نفس المتغيرات اللي فوق بس على scalars بسيطة
    buy_signal_bar   = -1
    buy_signal_price = 0.0
    sell_signal_bar  = -1
    in_position      = False

    min_pos_div = config.minPosDivForEntry
    min_neg_div = config.minNegDivForExit
    delay_bars  = max(1, config.delayBars)
    use_dd      = config.useDrawdown
    dd_perc     = config.drawdownPerc

    for i in range(n):
        # -------------------------
        # 1) Entry signal detection
        # -------------------------
        if (not in_position) and (pos_div[i] >= min_pos_div):
            buy_signal_bar   = i
            buy_signal_price = close_arr[i]

        # Process entry after delay
        if (buy_signal_bar != -1) and (not in_position):
            bars_since_signal = i - buy_signal_bar

            if bars_since_signal >= delay_bars:
                enter_trade = True

                if use_dd and i > 0:  # نفس الشرط القديم فعلياً (لأن delay_bars >= 1)
                    cur_drawdown = (buy_signal_price - close_arr[i-1]) / buy_signal_price * 100.0
                    if cur_drawdown < dd_perc:
                        enter_trade = False

                if enter_trade:
                    signal_arr[i]      = 1
                    entry_price_arr[i] = open_arr[i]  # Next bar's open
                    in_position        = True
                    buy_signal_bar     = -1
                    buy_signal_price   = 0.0

        # -------------------------
        # 2) Maintain position flag
        # -------------------------
        if in_position:
            position_arr[i] = 1

        # -------------------------
        # 3) Exit signal detection
        # -------------------------
        if in_position and (neg_div[i] >= min_neg_div):
            sell_signal_bar = i  # Mark the signal bar

        # Process exit at NEXT bar's open
        if (sell_signal_bar != -1) and in_position:
            bars_since_exit_signal = i - sell_signal_bar
            if bars_since_exit_signal >= 1:
                signal_arr[i]    = -1
                exit_price_arr[i] = open_arr[i]  # Next bar's open
                in_position       = False
                sell_signal_bar   = -1

    # نرجّع النتائج للـ DataFrame بنفس الأعمدة القديمة
    df['signal']      = signal_arr
    df['position']    = position_arr
    df['entry_price'] = entry_price_arr
    df['exit_price']  = exit_price_arr

    return df


#------------------------------------------------------------------------------
# VISUALIZATION
#------------------------------------------------------------------------------

def plot_candlestick_with_signals(df):
    """Create interactive candlestick chart with entry/exit signals"""
    print("Creating candlestick chart...")

    # Create figure with subplots
    fig = make_subplots(
        rows=2, cols=1,
        shared_xaxes=True,
        vertical_spacing=0.03,
        subplot_titles=('Price with Entry/Exit Signals', 'Divergence Counts'),
        row_heights=[0.7, 0.3]
    )

    # Add candlestick
    fig.add_trace(
        go.Candlestick(
            x=df.index,
            open=df['open'],
            high=df['high'],
            low=df['low'],
            close=df['close'],
            name='Price',
            increasing_line_color='green',
            decreasing_line_color='red'
        ),
        row=1, col=1
    )

    # Add entry signals (buy)
    entries = df[df['signal'] == 1]
    if len(entries) > 0:
        fig.add_trace(
            go.Scatter(
                x=entries.index,
                y=entries['entry_price'],
                mode='markers',
                name='BUY',
                marker=dict(
                    symbol='triangle-up',
                    size=15,
                    color='lime',
                    line=dict(color='darkgreen', width=2)
                )
            ),
            row=1, col=1
        )

    # Add exit signals (sell)
    exits = df[df['signal'] == -1]
    if len(exits) > 0:
        fig.add_trace(
            go.Scatter(
                x=exits.index,
                y=exits['exit_price'],
                mode='markers',
                name='SELL',
                marker=dict(
                    symbol='triangle-down',
                    size=15,
                    color='red',
                    line=dict(color='darkred', width=2)
                )
            ),
            row=1, col=1
        )

    # Add positive divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['pos_div_count'],
            mode='lines',
            name='Positive Divergences',
            line=dict(color='green', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add negative divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['neg_div_count'],
            mode='lines',
            name='Negative Divergences',
            line=dict(color='red', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add threshold lines
    fig.add_hline(
        y=config.minPosDivForEntry,
        line_dash="dash",
        line_color="green",
        annotation_text=f"Entry Threshold ({config.minPosDivForEntry})",
        row=2, col=1
    )

    fig.add_hline(
        y=config.minNegDivForExit,
        line_dash="dash",
        line_color="red",
        annotation_text=f"Exit Threshold ({config.minNegDivForExit})",
        row=2, col=1
    )

    # Update layout
    fig.update_layout(
        title='Divergence-Based Trading Strategy',
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis2_title='Time',
        yaxis2_title='Divergence Count',
        height=900,
        showlegend=True,
        xaxis_rangeslider_visible=False
    )

    fig.show()
    print("Chart displayed successfully")

#------------------------------------------------------------------------------
# PERFORMANCE METRICS
#------------------------------------------------------------------------------

def calculate_performance(df):
    """Calculate and display performance metrics"""
    print("\n" + "="*60)
    print("PERFORMANCE METRICS")
    print("="*60)

    entries = df[df['signal'] == 1].copy()
    exits = df[df['signal'] == -1].copy()

    if len(entries) == 0:
        print("No trades were executed")
        return

    # Match entries with exits
    trades = []
    for i, entry_row in entries.iterrows():
        entry_idx = df.index.get_loc(i)
        entry_price = entry_row['entry_price']

        # Find next exit
        exit_found = False
        for j, exit_row in exits.iterrows():
            exit_idx = df.index.get_loc(j)
            if exit_idx > entry_idx:
                exit_price = exit_row['exit_price']
                pnl_pct = (exit_price - entry_price) / entry_price * 100
                trades.append({
                    'entry_time': i,
                    'exit_time': j,
                    'entry_price': entry_price,
                    'exit_price': exit_price,
                    'pnl_pct': pnl_pct,
                    'bars_held': exit_idx - entry_idx,
                    'entry_idx': entry_idx  # Store index for indicator lookup
                })
                exit_found = True
                break

        if not exit_found:
            # Still in trade
            trades.append({
                'entry_time': i,
                'exit_time': None,
                'entry_price': entry_price,
                'exit_price': df['close'].iloc[-1],
                'pnl_pct': (df['close'].iloc[-1] - entry_price) / entry_price * 100,
                'bars_held': len(df) - entry_idx - 1,
                'entry_idx': entry_idx
            })

    trades_df = pd.DataFrame(trades)

    # Calculate metrics
    total_trades = len(trades_df)
    winning_trades = len(trades_df[trades_df['pnl_pct'] > 0])
    losing_trades = len(trades_df[trades_df['pnl_pct'] < 0])
    win_rate = (winning_trades / total_trades * 100) if total_trades > 0 else 0
    avg_win = trades_df[trades_df['pnl_pct'] > 0]['pnl_pct'].mean() if winning_trades > 0 else 0
    avg_loss = trades_df[trades_df['pnl_pct'] < 0]['pnl_pct'].mean() if losing_trades > 0 else 0
    avg_pnl = trades_df['pnl_pct'].mean()
    total_return = trades_df['pnl_pct'].sum()
    avg_bars_held = trades_df['bars_held'].mean()

    # Display metrics
    print(f"Total Trades:       {total_trades}")
    print(f"Winning Trades:     {winning_trades}")
    print(f"Losing Trades:      {losing_trades}")
    print(f"Win Rate:           {win_rate:.2f}%")
    print(f"Average Win:        {avg_win:.2f}%")
    print(f"Average Loss:       {avg_loss:.2f}%")
    print(f"Average P&L:        {avg_pnl:.2f}%")
    print(f"Total Return:       {total_return:.2f}%")
    print(f"Avg Bars Held:      {avg_bars_held:.1f}")

    print("\n" + "="*60)

    # Display trade list with indicator values
    print("\nDETAILED TRADE ANALYSIS WITH INDICATORS:")
    print("="*60)

    for idx, trade in trades_df.iterrows():
        status = "CLOSED" if trade['exit_time'] is not None else "OPEN"
        entry_idx = trade['entry_idx']

        print(f"\n{'='*60}")
        print(f"Trade #{idx+1} [{status}]")
        print(f"{'='*60}")

        # Price information
        print(f"\n📊 PRICE INFORMATION:")
        print(f"  Entry Time:      {trade['entry_time']}")
        print(f"  Entry Price:     ${trade['entry_price']:.2f}")
        print(f"  Open:            ${df['open'].iloc[entry_idx]:.2f}")
        print(f"  High:            ${df['high'].iloc[entry_idx]:.2f}")
        print(f"  Low:             ${df['low'].iloc[entry_idx]:.2f}")
        print(f"  Close:           ${df['close'].iloc[entry_idx]:.2f}")

        if trade['exit_time'] is not None:
            print(f"  Exit Time:       {trade['exit_time']}")
            print(f"  Exit Price:      ${trade['exit_price']:.2f}")
        else:
            print(f"  Current Price:   ${trade['exit_price']:.2f}")

        print(f"  P&L:             {trade['pnl_pct']:+.2f}%")
        print(f"  Duration:        {int(trade['bars_held'])} bars")

        # Divergence counts
        print(f"\n🔍 DIVERGENCE SIGNALS:")
        print(f"  Positive Divs:   {int(df['pos_div_count'].iloc[entry_idx])}")
        print(f"  Negative Divs:   {int(df['neg_div_count'].iloc[entry_idx])}")
        print(f"  Total Divs:      {int(df['total_divergences'].iloc[entry_idx])}")

        # Technical indicators
        print(f"\n📈 TECHNICAL INDICATORS AT ENTRY:")

        # Momentum indicators
        if config.calcrsi:
            print(f"  RSI (14):        {df['rsi'].iloc[entry_idx]:.2f}")

        if config.calcstoc:
            print(f"  Stochastic:      {df['stoch'].iloc[entry_idx]:.2f}")

        if config.calcmom:
            print(f"  Momentum (10):   {df['momentum'].iloc[entry_idx]:.2f}")

        if config.calccci:
            print(f"  CCI (10):        {df['cci'].iloc[entry_idx]:.2f}")

        # Trend indicators
        if config.calcmacd:
            print(f"  MACD:            {df['macd'].iloc[entry_idx]:.4f}")
            print(f"  MACD Signal:     {df['macd_signal'].iloc[entry_idx]:.4f}")

        if config.calcmacda:
            print(f"  MACD Histogram:  {df['macd_hist'].iloc[entry_idx]:.4f}")

        # Volume indicators
        if config.calcobv:
            print(f"  OBV:             {df['obv'].iloc[entry_idx]:,.0f}")

        if config.calcvwmacd:
            print(f"  VWMACD:          {df['vwmacd'].iloc[entry_idx]:.4f}")

        if config.calccmf:
            print(f"  CMF (21):        {df['cmf'].iloc[entry_idx]:.4f}")

        if config.calcmfi:
            print(f"  MFI (14):        {df['mfi'].iloc[entry_idx]:.2f}")

        # Individual divergences detected
        print(f"\n🎯 SPECIFIC DIVERGENCES DETECTED:")
        divergence_found = False

        # Check each indicator's divergences
        indicators_list = []
        if config.calcmacd:
            indicators_list.append(('MACD', 'macd'))
        if config.calcmacda:
            indicators_list.append(('MACD Hist', 'macd_hist'))
        if config.calcrsi:
            indicators_list.append(('RSI', 'rsi'))
        if config.calcstoc:
            indicators_list.append(('Stochastic', 'stoch'))
        if config.calccci:
            indicators_list.append(('CCI', 'cci'))
        if config.calcmom:
            indicators_list.append(('Momentum', 'momentum'))
        if config.calcobv:
            indicators_list.append(('OBV', 'obv'))
        if config.calcvwmacd:
            indicators_list.append(('VWMACD', 'vwmacd'))
        if config.calccmf:
            indicators_list.append(('CMF', 'cmf'))
        if config.calcmfi:
            indicators_list.append(('MFI', 'mfi'))

        for ind_name, ind_col in indicators_list:
            divs = []
            if f'{ind_col}_pos_reg' in df.columns and df[f'{ind_col}_pos_reg'].iloc[entry_idx] > 0:
                divs.append(f"Pos Regular ({int(df[f'{ind_col}_pos_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_reg' in df.columns and df[f'{ind_col}_neg_reg'].iloc[entry_idx] > 0:
                divs.append(f"Neg Regular ({int(df[f'{ind_col}_neg_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_pos_hid' in df.columns and df[f'{ind_col}_pos_hid'].iloc[entry_idx] > 0:
                divs.append(f"Pos Hidden ({int(df[f'{ind_col}_pos_hid'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_hid' in df.columns and df[f'{ind_col}_neg_hid'].iloc[entry_idx] > 0:
                divs.append(f"Neg Hidden ({int(df[f'{ind_col}_neg_hid'].iloc[entry_idx])} bars)")
                divergence_found = True

            if divs:
                print(f"  {ind_name:15s}: {', '.join(divs)}")

        if not divergence_found:
            print(f"  No specific divergences recorded (signal from previous bar)")

    print("\n" + "="*60)
def print_bar_debug(df, idx=-1):
    """
    اطبع كل القيم لشمعة واحدة:
    - السعر
    - المؤشرات
    - البيفوتات
    - عدد الديفرجنس
    idx = -1 يعني آخر شمعة
    """
    row = df.iloc[idx]

    print("\n" + "="*80)
    print(f"DEBUG SNAPSHOT @ index {idx} | time = {row.name}")
    print("="*80)

    # السعر
    print("\n📊 PRICE:")
    print(f"  Open   : {row['open']:.4f}")
    print(f"  High   : {row['high']:.4f}")
    print(f"  Low    : {row['low']:.4f}")
    print(f"  Close  : {row['close']:.4f}")
    print(f"  Volume : {row['volume']}")

    # المؤشرات
    print("\n📈 INDICATORS:")
    print(f"  RSI(14)        : {row['rsi']:.4f}")
    print(f"  MACD(12,26,9)  : {row['macd']:.4f}")
    print(f"  MACD Signal    : {row['macd_signal']:.4f}")
    print(f"  MACD Hist      : {row['macd_hist']:.4f}")
    print(f"  Momentum(10)   : {row['momentum']:.4f}")
    print(f"  Stoch(14,3)    : {row['stoch']:.4f}")
    print(f"  CCI(10)        : {row['cci']:.4f}")
    print(f"  VW-MACD        : {row['vwmacd']:.4f}")
    print(f"  CMF(21)        : {row['cmf']:.4f}")
    print(f"  MFI(14)        : {row['mfi']:.4f}")
    print(f"  OBV            : {row['obv']:.4f}")

    # البيفوتات والديفرجنس
    print("\n📌 PIVOTS & DIVERGENCES:")
    print(f"  pivot_high       : {row.get('pivot_high', np.nan)}")
    print(f"  pivot_low        : {row.get('pivot_low', np.nan)}")
    print(f"  pos_div_count    : {row.get('pos_div_count', np.nan)}")
    print(f"  neg_div_count    : {row.get('neg_div_count', np.nan)}")
    print(f"  total_divergences: {row.get('total_divergences', np.nan)}")
    print("="*80)


def print_last_n_bars_debug(df, n=5):
    """
    اطبع snapshot لآخر n شمعات
    عشان تقارن بالـ TradingView بسهولة
    """
    start = max(0, len(df) - n)
    for i in range(start, len(df)):
        print_bar_debug(df, i)

#------------------------------------------------------------------------------
# MAIN EXECUTION
#------------------------------------------------------------------------------

def main(csv_filepath):
    """Main execution function"""

    print("="*60)
    print("DIVERGENCE-BASED TRADING STRATEGY")
    print("="*60)
    print(f"\nConfiguration:")
    print(f"  Pivot Period: {config.prd}")
    print(f"  Divergence Type: {config.searchdiv}")
    print(f"  Min Positive Divergences for Entry: {config.minPosDivForEntry}")
    print(f"  Min Negative Divergences for Exit: {config.minNegDivForExit}")
    print(f"  Entry Delay: {config.delayBars} bars")
    print("\n" + "="*60 + "\n")

    # Load data
    df = load_data_from_csv(csv_filepath)

    # Calculate indicators
    df = calculate_indicators(df)

    # Find pivot points
    df = find_pivots(df, config.prd)

    # Scan for divergences
    df = scan_all_divergences(df)

    # Run strategy
    df = run_strategy(df)

    # Calculate performance
    calculate_performance(df)

    # Plot results
    #plot_candlestick_with_signals(df)

    return df

# ============================================================================
# RUN THE STRATEGY
# ============================================================================

# Upload your CSV file to Colab first, then specify the path
# Example: df_result = main('/content/your_data.csv')

# For Google Colab, you can upload a file like this:
# from google.colab import files
# uploaded = files.upload()

# Get the uploaded filename
csv_filename = 'PLD.csv'

# Run the strategy
df_result = main(csv_filename)
print_last_n_bars_debug(df_result, n=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-26 18:45:00-04:00
#   Entry Price:     $976.45
#   Open:            $976.45
#   High:            $976.61
#   Low:             $973.08
#   Close:           $973.81
#   Exit Time:       2025-03-27 11:30:00-04:00
#   Exit Price:      $986.47
#   P&L:             +1.03%
#   Duration:        67 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.83
#   Stochastic:      30.72
#   Momentum (10):   -2.50
#   CCI (10):        -171.13
#   MACD:            -0.6771
#   MACD Signal:     -0.4679
#   MACD Histogram:  -0.2093
#   VWMACD:          -1.6514
#   CMF (21):        0.0513
#   MFI (14):        40.17
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #47 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-28 06:30:00-04:00
#   Entry Price:     $984.53
#   Open:            $984.53
#   High:            $987.33
#   Low:             $984.32
#   Close:           $985.21
#   Exit Time:       2025-03-30 23:00:00-04:00
#   Exit Price:      $986.81
#   P&L:             +0.23%
#   Duration:        62 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.03
#   Stochastic:      17.75
#   Momentum (10):   -5.38
#   CCI (10):        -16.96
#   MACD:            -0.3555
#   MACD Signal:     0.0039
#   MACD Histogram:  -0.3594
#   VWMACD:          -0.1468
#   CMF (21):        0.0152
#   MFI (14):        38.43
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #48 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-01 12:45:00-04:00
#   Entry Price:     $984.67
#   Open:            $984.67
#   High:            $985.82
#   Low:             $984.32
#   Close:           $985.11
#   Exit Time:       2025-04-01 22:15:00-04:00
#   Exit Price:      $988.56
#   P&L:             +0.39%
#   Duration:        34 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.91
#   Stochastic:      14.52
#   Momentum (10):   -3.98
#   CCI (10):        -76.69
#   MACD:            -1.6961
#   MACD Signal:     -1.0568
#   MACD Histogram:  -0.6393
#   VWMACD:          -1.1963
#   CMF (21):        -0.2074
#   MFI (14):        34.56
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #49 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-02 01:45:00-04:00
#   Entry Price:     $986.05
#   Open:            $986.05
#   High:            $986.14
#   Low:             $983.12
#   Close:           $984.51
#   Exit Time:       2025-04-02 19:30:00-04:00
#   Exit Price:      $981.96
#   P&L:             -0.41%
#   Duration:        67 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.30
#   Stochastic:      24.00
#   Momentum (10):   -3.31
#   CCI (10):        -126.15
#   MACD:            -0.5042
#   MACD Signal:     -0.2191
#   MACD Histogram:  -0.2851
#   VWMACD:          -0.8804
#   CMF (21):        0.0428
#   MFI (14):        32.89
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #50 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-03 13:45:00-04:00
#   Entry Price:     $952.85
#   Open:            $952.85
#   High:            $953.27
#   Low:             $951.92
#   Close:           $952.33
#   Exit Time:       2025-04-04 01:45:00-04:00
#   Exit Price:      $957.39
#   P&L:             +0.48%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.54
#   Stochastic:      2.42
#   Momentum (10):   -2.03
#   CCI (10):        -133.04
#   MACD:            -2.9469
#   MACD Signal:     -2.9973
#   MACD Histogram:  0.0503
#   VWMACD:          -2.9652
#   CMF (21):        -0.2426
#   MFI (14):        31.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #51 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-04 05:15:00-04:00
#   Entry Price:     $944.32
#   Open:            $944.32
#   High:            $945.30
#   Low:             $943.87
#   Close:           $944.02
#   Exit Time:       2025-04-07 06:30:00-04:00
#   Exit Price:      $922.54
#   P&L:             -2.31%
#   Duration:        97 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.20
#   Stochastic:      16.37
#   Momentum (10):   -3.76
#   CCI (10):        3.32
#   MACD:            -2.6039
#   MACD Signal:     -2.0400
#   MACD Histogram:  -0.5639
#   VWMACD:          -4.1003
#   CMF (21):        -0.0401
#   MFI (14):        12.22
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #52 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-07 11:45:00-04:00
#   Entry Price:     $912.07
#   Open:            $912.07
#   High:            $915.07
#   Low:             $911.40
#   Close:           $912.51
#   Exit Time:       2025-04-07 16:45:00-04:00
#   Exit Price:      $914.82
#   P&L:             +0.30%
#   Duration:        20 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.31
#   Stochastic:      18.98
#   Momentum (10):   -5.39
#   CCI (10):        -36.14
#   MACD:            -2.4105
#   MACD Signal:     -1.9449
#   MACD Histogram:  -0.4656
#   VWMACD:          -1.0100
#   CMF (21):        -0.2321
#   MFI (14):        31.00
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #53 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-08 05:45:00-04:00
#   Entry Price:     $922.32
#   Open:            $922.32
#   High:            $923.99
#   Low:             $920.84
#   Close:           $923.20
#   Exit Time:       2025-04-09 01:30:00-04:00
#   Exit Price:      $921.13
#   P&L:             -0.13%
#   Duration:        75 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.04
#   Stochastic:      19.49
#   Momentum (10):   -4.87
#   CCI (10):        -29.14
#   MACD:            -0.7887
#   MACD Signal:     0.0948
#   MACD Histogram:  -0.8835
#   VWMACD:          -2.4063
#   CMF (21):        -0.0027
#   MFI (14):        53.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #54 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-09 09:00:00-04:00
#   Entry Price:     $919.41
#   Open:            $919.41
#   High:            $922.66
#   Low:             $919.02
#   Close:           $922.66
#   Exit Time:       2025-04-09 14:00:00-04:00
#   Exit Price:      $929.83
#   P&L:             +1.13%
#   Duration:        20 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.32
#   Stochastic:      27.17
#   Momentum (10):   -2.55
#   CCI (10):        15.39
#   MACD:            -0.4018
#   MACD Signal:     0.0893
#   MACD Histogram:  -0.4911
#   VWMACD:          -1.0055
#   CMF (21):        -0.2726
#   MFI (14):        45.71
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #55 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-16 02:45:00-04:00
#   Entry Price:     $958.20
#   Open:            $958.20
#   High:            $960.22
#   Low:             $957.43
#   Close:           $959.67
#   Exit Time:       2025-04-16 05:45:00-04:00
#   Exit Price:      $960.91
#   P&L:             +0.28%
#   Duration:        12 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.86
#   Stochastic:      34.81
#   Momentum (10):   -0.04
#   CCI (10):        7.43
#   MACD:            -0.2550
#   MACD Signal:     -0.0318
#   MACD Histogram:  -0.2232
#   VWMACD:          -0.1600
#   CMF (21):        -0.1974
#   MFI (14):        48.50
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #56 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-16 18:15:00-04:00
#   Entry Price:     $970.38
#   Open:            $970.38
#   High:            $972.65
#   Low:             $970.23
#   Close:           $971.47
#   Exit Time:       2025-04-16 19:00:00-04:00
#   Exit Price:      $971.98
#   P&L:             +0.17%
#   Duration:        3 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        55.73
#   Stochastic:      56.41
#   Momentum (10):   0.51
#   CCI (10):        92.69
#   MACD:            0.5218
#   MACD Signal:     0.7335
#   MACD Histogram:  -0.2117
#   VWMACD:          0.3249
#   CMF (21):        0.0441
#   MFI (14):        70.38
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #57 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-17 01:30:00-04:00
#   Entry Price:     $965.07
#   Open:            $965.07
#   High:            $965.82
#   Low:             $963.92
#   Close:           $965.72
#   Exit Time:       2025-04-20 18:30:00-04:00
#   Exit Price:      $969.33
#   P&L:             +0.44%
#   Duration:        64 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.40
#   Stochastic:      19.87
#   Momentum (10):   -2.33
#   CCI (10):        -43.22
#   MACD:            -1.0891
#   MACD Signal:     -0.9420
#   MACD Histogram:  -0.1471
#   VWMACD:          -0.9782
#   CMF (21):        -0.0033
#   MFI (14):        53.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #58 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-21 13:00:00-04:00
#   Entry Price:     $964.51
#   Open:            $964.51
#   High:            $965.77
#   Low:             $963.74
#   Close:           $964.29
#   Exit Time:       2025-04-22 02:30:00-04:00
#   Exit Price:      $972.98
#   P&L:             +0.88%
#   Duration:        50 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   1
#   Negative Divs:   0
#   Total Divs:      1
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.91
#   Stochastic:      9.09
#   Momentum (10):   -1.47
#   CCI (10):        -118.32
#   MACD:            -1.8952
#   MACD Signal:     -1.6646
#   MACD Histogram:  -0.2306
#   VWMACD:          -2.2651
#   CMF (21):        -0.0969
#   MFI (14):        25.55
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   MACD Hist      : Pos Regular (10 bars)
#
# ============================================================
# Trade #59 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-22 09:45:00-04:00
#   Entry Price:     $961.20
#   Open:            $961.20
#   High:            $963.84
#   Low:             $959.93
#   Close:           $960.23
#   Exit Time:       2025-04-23 00:15:00-04:00
#   Exit Price:      $962.64
#   P&L:             +0.15%
#   Duration:        54 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        26.00
#   Stochastic:      13.73
#   Momentum (10):   -10.18
#   CCI (10):        -90.96
#   MACD:            -2.5297
#   MACD Signal:     -1.4847
#   MACD Histogram:  -1.0449
#   VWMACD:          -2.6843
#   CMF (21):        -0.2987
#   MFI (14):        33.80
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #60 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-23 20:15:00-04:00
#   Entry Price:     $974.04
#   Open:            $974.04
#   High:            $975.34
#   Low:             $973.79
#   Close:           $974.75
#   Exit Time:       2025-04-24 03:30:00-04:00
#   Exit Price:      $972.42
#   P&L:             -0.17%
#   Duration:        29 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        56.07
#   Stochastic:      63.95
#   Momentum (10):   0.63
#   CCI (10):        172.46
#   MACD:            0.2387
#   MACD Signal:     0.3352
#   MACD Histogram:  -0.0964
#   VWMACD:          0.0529
#   CMF (21):        0.1337
#   MFI (14):        47.65
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #61 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-24 10:15:00-04:00
#   Entry Price:     $973.25
#   Open:            $973.25
#   High:            $974.80
#   Low:             $971.92
#   Close:           $974.49
#   Exit Time:       2025-04-24 19:15:00-04:00
#   Exit Price:      $975.31
#   P&L:             +0.21%
#   Duration:        32 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        46.68
#   Stochastic:      12.37
#   Momentum (10):   -4.86
#   CCI (10):        -53.58
#   MACD:            -0.0291
#   MACD Signal:     0.5102
#   MACD Histogram:  -0.5393
#   VWMACD:          -0.0728
#   CMF (21):        -0.1251
#   MFI (14):        51.84
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #62 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-24 22:15:00-04:00
#   Entry Price:     $970.87
#   Open:            $970.87
#   High:            $970.91
#   Low:             $970.39
#   Close:           $970.63
#   Exit Time:       2025-04-25 09:15:00-04:00
#   Exit Price:      $970.64
#   P&L:             -0.02%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.35
#   Stochastic:      3.88
#   Momentum (10):   -3.99
#   CCI (10):        -115.10
#   MACD:            -0.6426
#   MACD Signal:     -0.1182
#   MACD Histogram:  -0.5244
#   VWMACD:          0.1507
#   CMF (21):        -0.1850
#   MFI (14):        49.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #63 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-29 09:30:00-04:00
#   Entry Price:     $986.89
#   Open:            $986.89
#   High:            $988.88
#   Low:             $986.19
#   Close:           $986.28
#   Exit Time:       2025-04-29 23:30:00-04:00
#   Exit Price:      $980.82
#   P&L:             -0.61%
#   Duration:        52 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        43.80
#   Stochastic:      32.69
#   Momentum (10):   -4.09
#   CCI (10):        -72.31
#   MACD:            -0.6196
#   MACD Signal:     -0.1223
#   MACD Histogram:  -0.4973
#   VWMACD:          -0.8505
#   CMF (21):        -0.0627
#   MFI (14):        38.92
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #64 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-30 04:45:00-04:00
#   Entry Price:     $969.70
#   Open:            $969.70
#   High:            $971.24
#   Low:             $969.46
#   Close:           $969.85
#   Exit Time:       2025-04-30 11:15:00-04:00
#   Exit Price:      $970.76
#   P&L:             +0.11%
#   Duration:        26 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.88
#   Stochastic:      25.47
#   Momentum (10):   -10.28
#   CCI (10):        -44.50
#   MACD:            -2.8344
#   MACD Signal:     -1.6132
#   MACD Histogram:  -1.2212
#   VWMACD:          -1.4146
#   CMF (21):        -0.3325
#   MFI (14):        23.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #65 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-30 23:30:00-04:00
#   Entry Price:     $963.67
#   Open:            $963.67
#   High:            $963.84
#   Low:             $961.22
#   Close:           $961.74
#   Exit Time:       2025-05-01 09:45:00-04:00
#   Exit Price:      $967.67
#   P&L:             +0.42%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        28.69
#   Stochastic:      10.05
#   Momentum (10):   -3.47
#   CCI (10):        -174.50
#   MACD:            -1.2919
#   MACD Signal:     -0.9631
#   MACD Histogram:  -0.3288
#   VWMACD:          -1.4658
#   CMF (21):        0.0262
#   MFI (14):        22.54
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #66 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-02 12:00:00-04:00
#   Entry Price:     $962.63
#   Open:            $962.63
#   High:            $965.20
#   Low:             $962.63
#   Close:           $964.52
#   Exit Time:       2025-05-05 02:00:00-04:00
#   Exit Price:      $966.02
#   P&L:             +0.35%
#   Duration:        52 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.14
#   Stochastic:      14.30
#   Momentum (10):   -5.86
#   CCI (10):        -57.38
#   MACD:            -1.3416
#   MACD Signal:     -0.4512
#   MACD Histogram:  -0.8904
#   VWMACD:          -0.8401
#   CMF (21):        0.0163
#   MFI (14):        56.54
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #67 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-05 11:30:00-04:00
#   Entry Price:     $959.37
#   Open:            $959.37
#   High:            $960.30
#   Low:             $958.75
#   Close:           $959.68
#   Exit Time:       2025-05-05 21:30:00-04:00
#   Exit Price:      $967.01
#   P&L:             +0.80%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.83
#   Stochastic:      12.60
#   Momentum (10):   -9.22
#   CCI (10):        -58.05
#   MACD:            -1.7741
#   MACD Signal:     -0.9304
#   MACD Histogram:  -0.8436
#   VWMACD:          -1.2206
#   CMF (21):        -0.1195
#   MFI (14):        36.07
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #68 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-07 12:45:00-04:00
#   Entry Price:     $982.62
#   Open:            $982.62
#   High:            $983.52
#   Low:             $982.12
#   Close:           $983.02
#   Exit Time:       2025-05-08 10:00:00-04:00
#   Exit Price:      $987.92
#   P&L:             +0.54%
#   Duration:        81 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.39
#   Stochastic:      12.33
#   Momentum (10):   -4.05
#   CCI (10):        -79.11
#   MACD:            -0.8806
#   MACD Signal:     -0.1751
#   MACD Histogram:  -0.7055
#   VWMACD:          -0.5750
#   CMF (21):        0.0099
#   MFI (14):        50.47
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #69 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-08 22:30:00-04:00
#   Entry Price:     $980.52
#   Open:            $980.52
#   High:            $982.25
#   Low:             $980.52
#   Close:           $982.12
#   Exit Time:       2025-05-09 02:45:00-04:00
#   Exit Price:      $987.82
#   P&L:             +0.74%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.49
#   Stochastic:      31.33
#   Momentum (10):   -0.40
#   CCI (10):        25.21
#   MACD:            -0.6697
#   MACD Signal:     -0.4541
#   MACD Histogram:  -0.2156
#   VWMACD:          -0.4358
#   CMF (21):        0.0301
#   MFI (14):        49.01
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #70 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-11 18:15:00-04:00
#   Entry Price:     $1002.12
#   Open:            $1002.12
#   High:            $1002.71
#   Low:             $1000.00
#   Close:           $1001.23
#   Exit Time:       2025-05-11 18:30:00-04:00
#   Exit Price:      $1000.98
#   P&L:             -0.11%
#   Duration:        1 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   3
#   Total Divs:      3
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        63.45
#   Stochastic:      60.31
#   Momentum (10):   1.44
#   CCI (10):        131.62
#   MACD:            1.5287
#   MACD Signal:     1.7651
#   MACD Histogram:  -0.2364
#   VWMACD:          0.3921
#   CMF (21):        -0.2215
#   MFI (14):        35.56
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   MACD Hist      : Neg Regular (12 bars)
#   RSI            : Neg Regular (12 bars)
#   MFI            : Neg Regular (12 bars)
#
# ============================================================
# Trade #71 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-11 20:45:00-04:00
#   Entry Price:     $996.34
#   Open:            $996.34
#   High:            $997.63
#   Low:             $996.13
#   Close:           $996.86
#   Exit Time:       2025-05-12 02:45:00-04:00
#   Exit Price:      $1001.14
#   P&L:             +0.48%
#   Duration:        24 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.42
#   Stochastic:      15.00
#   Momentum (10):   -4.37
#   CCI (10):        -76.05
#   MACD:            0.1696
#   MACD Signal:     0.9356
#   MACD Histogram:  -0.7659
#   VWMACD:          -0.5734
#   CMF (21):        -0.2499
#   MFI (14):        44.38
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #72 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-12 08:45:00-04:00
#   Entry Price:     $981.82
#   Open:            $981.82
#   High:            $983.20
#   Low:             $977.00
#   Close:           $982.50
#   Exit Time:       2025-05-12 18:45:00-04:00
#   Exit Price:      $982.52
#   P&L:             +0.07%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.35
#   Stochastic:      71.62
#   Momentum (10):   1.40
#   CCI (10):        25.18
#   MACD:            -3.4074
#   MACD Signal:     -3.8536
#   MACD Histogram:  0.4462
#   VWMACD:          -4.3703
#   CMF (21):        0.6236
#   MFI (14):        57.13
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #73 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-15 02:30:00-04:00
#   Entry Price:     $980.84
#   Open:            $980.84
#   High:            $981.59
#   Low:             $970.00
#   Close:           $980.97
#   Exit Time:       2025-05-15 07:00:00-04:00
#   Exit Price:      $985.01
#   P&L:             +0.43%
#   Duration:        18 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.00
#   Stochastic:      68.86
#   Momentum (10):   -4.41
#   CCI (10):        -72.88
#   MACD:            -0.8997
#   MACD Signal:     -0.3516
#   MACD Histogram:  -0.5481
#   VWMACD:          -1.4132
#   CMF (21):        0.8469
#   MFI (14):        54.89
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #74 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-16 03:00:00-04:00
#   Entry Price:     $988.41
#   Open:            $988.41
#   High:            $989.46
#   Low:             $980.00
#   Close:           $987.20
#   Exit Time:       2025-05-18 20:00:00-04:00
#   Exit Price:      $993.91
#   P&L:             +0.56%
#   Duration:        64 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        31.36
#   Stochastic:      63.19
#   Momentum (10):   -3.40
#   CCI (10):        -157.55
#   MACD:            -0.8274
#   MACD Signal:     -0.5369
#   MACD Histogram:  -0.2906
#   VWMACD:          -0.8733
#   CMF (21):        0.7675
#   MFI (14):        45.49
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #75 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-19 04:00:00-04:00
#   Entry Price:     $990.21
#   Open:            $990.21
#   High:            $990.61
#   Low:             $985.50
#   Close:           $989.51
#   Exit Time:       2025-05-19 05:15:00-04:00
#   Exit Price:      $995.30
#   P&L:             +0.51%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.22
#   Stochastic:      45.59
#   Momentum (10):   -3.50
#   CCI (10):        -128.33
#   MACD:            -0.2941
#   MACD Signal:     0.1567
#   MACD Histogram:  -0.4508
#   VWMACD:          0.0486
#   CMF (21):        0.6729
#   MFI (14):        41.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #76 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-21 01:30:00-04:00
#   Entry Price:     $1041.90
#   Open:            $1041.90
#   High:            $1042.58
#   Low:             $1036.50
#   Close:           $1042.43
#   Exit Time:       2025-05-21 09:15:00-04:00
#   Exit Price:      $1062.81
#   P&L:             +2.01%
#   Duration:        31 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.42
#   Stochastic:      30.67
#   Momentum (10):   -6.09
#   CCI (10):        -69.32
#   MACD:            -2.2262
#   MACD Signal:     -1.1808
#   MACD Histogram:  -1.0453
#   VWMACD:          -4.4318
#   CMF (21):        0.4455
#   MFI (14):        41.41
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #77 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-22 05:45:00-04:00
#   Entry Price:     $1069.38
#   Open:            $1069.38
#   High:            $1070.86
#   Low:             $1065.00
#   Close:           $1069.72
#   Exit Time:       2025-05-22 16:45:00-04:00
#   Exit Price:      $1081.13
#   P&L:             +1.10%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.88
#   Stochastic:      26.15
#   Momentum (10):   -10.89
#   CCI (10):        -63.59
#   MACD:            -1.5981
#   MACD Signal:     -0.3747
#   MACD Histogram:  -1.2234
#   VWMACD:          -0.2289
#   CMF (21):        0.4995
#   MFI (14):        49.79
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #78 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-23 05:15:00-04:00
#   Entry Price:     $1084.76
#   Open:            $1084.76
#   High:            $1088.41
#   Low:             $1078.50
#   Close:           $1081.00
#   Exit Time:       2025-05-23 06:45:00-04:00
#   Exit Price:      $1095.97
#   P&L:             +1.03%
#   Duration:        6 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.15
#   Stochastic:      23.38
#   Momentum (10):   -14.14
#   CCI (10):        -78.55
#   MACD:            -0.5656
#   MACD Signal:     0.7790
#   MACD Histogram:  -1.3446
#   VWMACD:          -0.3937
#   CMF (21):        0.2532
#   MFI (14):        36.81
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #79 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-26 06:00:00-04:00
#   Entry Price:     $1088.57
#   Open:            $1088.57
#   High:            $1090.54
#   Low:             $1084.00
#   Close:           $1090.05
#   Exit Time:       2025-05-28 03:30:00-04:00
#   Exit Price:      $1089.39
#   P&L:             +0.08%
#   Duration:        164 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.57
#   Stochastic:      33.92
#   Momentum (10):   3.38
#   CCI (10):        61.08
#   MACD:            -1.4829
#   MACD Signal:     -1.4958
#   MACD Histogram:  0.0129
#   VWMACD:          -2.7751
#   CMF (21):        -0.3726
#   MFI (14):        42.88
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #80 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-28 20:00:00-04:00
#   Entry Price:     $1074.99
#   Open:            $1074.99
#   High:            $1078.30
#   Low:             $1071.50
#   Close:           $1076.59
#   Exit Time:       2025-05-29 05:15:00-04:00
#   Exit Price:      $1078.93
#   P&L:             +0.37%
#   Duration:        37 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.54
#   Stochastic:      44.87
#   Momentum (10):   -1.91
#   CCI (10):        -23.55
#   MACD:            -1.7797
#   MACD Signal:     -1.3350
#   MACD Histogram:  -0.4448
#   VWMACD:          -0.7912
#   CMF (21):        0.3032
#   MFI (14):        43.15
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #81 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-30 00:45:00-04:00
#   Entry Price:     $1075.06
#   Open:            $1075.06
#   High:            $1075.67
#   Low:             $1074.50
#   Close:           $1075.26
#   Exit Time:       2025-06-02 10:15:00-04:00
#   Exit Price:      $1060.05
#   P&L:             -1.40%
#   Duration:        130 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.23
#   Stochastic:      8.25
#   Momentum (10):   -7.14
#   CCI (10):        -70.72
#   MACD:            -1.6761
#   MACD Signal:     -0.8636
#   MACD Histogram:  -0.8126
#   VWMACD:          -1.6235
#   CMF (21):        0.2600
#   MFI (14):        42.24
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #82 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-03 03:45:00-04:00
#   Entry Price:     $1062.87
#   Open:            $1062.87
#   High:            $1064.12
#   Low:             $1061.50
#   Close:           $1062.53
#   Exit Time:       2025-06-03 10:45:00-04:00
#   Exit Price:      $1067.58
#   P&L:             +0.44%
#   Duration:        28 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.36
#   Stochastic:      45.56
#   Momentum (10):   -3.75
#   CCI (10):        -88.44
#   MACD:            -0.4913
#   MACD Signal:     -0.0368
#   MACD Histogram:  -0.4545
#   VWMACD:          0.1631
#   CMF (21):        0.5361
#   MFI (14):        43.97
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #83 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-10 04:30:00-04:00
#   Entry Price:     $1206.50
#   Open:            $1206.50
#   High:            $1209.87
#   Low:             $1199.50
#   Close:           $1207.86
#   Exit Time:       2025-06-10 10:00:00-04:00
#   Exit Price:      $1220.29
#   P&L:             +1.14%
#   Duration:        22 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.24
#   Stochastic:      23.43
#   Momentum (10):   -7.54
#   CCI (10):        -44.96
#   MACD:            -2.4394
#   MACD Signal:     -1.2201
#   MACD Histogram:  -1.2193
#   VWMACD:          -4.5185
#   CMF (21):        0.4248
#   MFI (14):        52.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #84 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-12 21:15:00-04:00
#   Entry Price:     $1280.55
#   Open:            $1280.55
#   High:            $1292.69
#   Low:             $1274.00
#   Close:           $1290.32
#   Exit Time:       2025-06-15 20:15:00-04:00
#   Exit Price:      $1236.22
#   P&L:             -3.46%
#   Duration:        88 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.92
#   Stochastic:      35.68
#   Momentum (10):   -0.31
#   CCI (10):        8.35
#   MACD:            0.1705
#   MACD Signal:     1.7851
#   MACD Histogram:  -1.6146
#   VWMACD:          -0.9567
#   CMF (21):        0.2123
#   MFI (14):        50.44
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #85 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-16 02:00:00-04:00
#   Entry Price:     $1235.08
#   Open:            $1235.08
#   High:            $1239.34
#   Low:             $1232.00
#   Close:           $1238.21
#   Exit Time:       2025-06-16 03:00:00-04:00
#   Exit Price:      $1238.56
#   P&L:             +0.28%
#   Duration:        4 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        56.72
#   Stochastic:      62.79
#   Momentum (10):   5.28
#   CCI (10):        134.91
#   MACD:            0.9982
#   MACD Signal:     0.8798
#   MACD Histogram:  0.1184
#   VWMACD:          1.5138
#   CMF (21):        0.3445
#   MFI (14):        72.39
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #86 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-17 18:45:00-04:00
#   Entry Price:     $1255.83
#   Open:            $1255.83
#   High:            $1260.50
#   Low:             $1253.47
#   Close:           $1254.86
#   Exit Time:       2025-06-17 23:15:00-04:00
#   Exit Price:      $1267.84
#   P&L:             +0.96%
#   Duration:        18 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.48
#   Stochastic:      35.25
#   Momentum (10):   -11.75
#   CCI (10):        -98.52
#   MACD:            -1.7036
#   MACD Signal:     -0.2011
#   MACD Histogram:  -1.5025
#   VWMACD:          -3.7980
#   CMF (21):        0.0192
#   MFI (14):        38.45
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #87 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-19 09:00:00-04:00
#   Entry Price:     $1276.28
#   Open:            $1276.28
#   High:            $1280.37
#   Low:             $1270.00
#   Close:           $1276.56
#   Exit Time:       2025-06-19 21:30:00-04:00
#   Exit Price:      $1303.16
#   P&L:             +2.11%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        27.14
#   Stochastic:      26.34
#   Momentum (10):   -23.11
#   CCI (10):        -85.04
#   MACD:            -9.9799
#   MACD Signal:     -9.2513
#   MACD Histogram:  -0.7287
#   VWMACD:          -10.2443
#   CMF (21):        0.2030
#   MFI (14):        50.20
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #88 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-20 02:15:00-04:00
#   Entry Price:     $1284.91
#   Open:            $1284.91
#   High:            $1285.87
#   Low:             $1278.50
#   Close:           $1280.48
#   Exit Time:       2025-06-23 00:15:00-04:00
#   Exit Price:      $1268.75
#   P&L:             -1.26%
#   Duration:        84 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.46
#   Stochastic:      37.01
#   Momentum (10):   -7.75
#   CCI (10):        -120.24
#   MACD:            -3.3996
#   MACD Signal:     -2.6969
#   MACD Histogram:  -0.7027
#   VWMACD:          -9.5237
#   CMF (21):        0.2347
#   MFI (14):        45.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #89 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-24 00:45:00-04:00
#   Entry Price:     $1294.47
#   Open:            $1294.47
#   High:            $1295.17
#   Low:             $1284.50
#   Close:           $1294.03
#   Exit Time:       2025-06-24 04:00:00-04:00
#   Exit Price:      $1304.22
#   P&L:             +0.75%
#   Duration:        13 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.21
#   Stochastic:      52.85
#   Momentum (10):   -1.48
#   CCI (10):        17.06
#   MACD:            -0.3297
#   MACD Signal:     0.0903
#   MACD Histogram:  -0.4199
#   VWMACD:          0.0922
#   CMF (21):        0.2592
#   MFI (14):        37.11
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #90 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-25 04:30:00-04:00
#   Entry Price:     $1314.86
#   Open:            $1314.86
#   High:            $1315.26
#   Low:             $1305.00
#   Close:           $1313.06
#   Exit Time:       2025-06-25 10:30:00-04:00
#   Exit Price:      $1320.26
#   P&L:             +0.41%
#   Duration:        24 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        46.43
#   Stochastic:      28.71
#   Momentum (10):   -0.94
#   CCI (10):        -64.53
#   MACD:            -0.4653
#   MACD Signal:     0.4698
#   MACD Histogram:  -0.9351
#   VWMACD:          -0.5835
#   CMF (21):        0.2804
#   MFI (14):        49.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #91 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-27 03:00:00-04:00
#   Entry Price:     $1394.00
#   Open:            $1394.00
#   High:            $1394.55
#   Low:             $1382.00
#   Close:           $1384.85
#   Exit Time:       2025-06-29 21:15:00-04:00
#   Exit Price:      $1345.28
#   P&L:             -3.50%
#   Duration:        69 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.24
#   Stochastic:      39.09
#   Momentum (10):   -9.25
#   CCI (10):        -94.24
#   MACD:            -5.5052
#   MACD Signal:     -5.6674
#   MACD Histogram:  0.1622
#   VWMACD:          -5.6360
#   CMF (21):        0.2698
#   MFI (14):        45.88
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #92 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-30 10:30:00-04:00
#   Entry Price:     $1326.37
#   Open:            $1326.37
#   High:            $1331.38
#   Low:             $1325.86
#   Close:           $1329.56
#   Exit Time:       2025-07-01 18:30:00-04:00
#   Exit Price:      $1359.54
#   P&L:             +2.50%
#   Duration:        120 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        26.59
#   Stochastic:      9.77
#   Momentum (10):   -24.80
#   CCI (10):        -83.69
#   MACD:            -8.2764
#   MACD Signal:     -5.1277
#   MACD Histogram:  -3.1487
#   VWMACD:          -7.3120
#   CMF (21):        0.0369
#   MFI (14):        28.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #93 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-07-03 06:00:00-04:00
#   Entry Price:     $1373.71
#   Open:            $1373.71
#   High:            $1385.81
#   Low:             $1366.50
#   Close:           $1383.62
#   Exit Time:       2025-07-03 19:30:00-04:00
#   Exit Price:      $1379.08
#   P&L:             +0.39%
#   Duration:        50 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.33
#   Stochastic:      28.51
#   Momentum (10):   -31.53
#   CCI (10):        -56.41
#   MACD:            -7.0363
#   MACD Signal:     -2.9121
#   MACD Histogram:  -4.1242
#   VWMACD:          -8.6448
#   CMF (21):        0.3943
#   MFI (14):        44.00
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #94 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-07-06 23:45:00-04:00
#   Entry Price:     $1370.88
#   Open:            $1370.88
#   High:            $1371.69
#   Low:             $1362.50
#   Close:           $1370.68
#   Exit Time:       2025-07-07 12:30:00-04:00
#   Exit Price:      $1368.85
#   P&L:             -0.15%
#   Duration:        51 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   1
#   Negative Divs:   0
#   Total Divs:      1
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        29.04
#   Stochastic:      31.91
#   Momentum (10):   -13.27
#   CCI (10):        -108.13
#   MACD:            -4.3777
#   MACD Signal:     -2.3025
#   MACD Histogram:  -2.0752
#   VWMACD:          -6.9179
#   CMF (21):        0.4591
#   MFI (14):        35.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   CMF            : Pos Regular (11 bars)
#
# ============================================================
# Trade #95 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-07-08 10:45:00-04:00
#   Entry Price:     $1349.44
#   Open:            $1349.44
#   High:            $1351.04
#   Low:             $1341.00
#   Close:           $1346.36
#   Exit Time:       2025-07-08 15:15:00-04:00
#   Exit Price:      $1364.77
#   P&L:             +1.14%
#   Duration:        18 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        29.71
#   Stochastic:      10.68
#   Momentum (10):   -32.98
#   CCI (10):        -101.67
#   MACD:            -6.5631
#   MACD Signal:     -3.4301
#   MACD Histogram:  -3.1330
#   VWMACD:          -5.0448
#   CMF (21):        0.2654
#   MFI (14):        39.19
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #96 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-07-08 22:15:00-04:00
#   Entry Price:     $1353.55
#   Open:            $1353.55
#   High:            $1359.50
#   Low:             $1349.62
#   Close:           $1353.87
#   Exit Time:       2025-07-09 07:45:00-04:00
#   Exit Price:      $1353.96
#   P&L:             +0.03%
#   Duration:        38 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.98
#   Stochastic:      16.19
# ...
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.49
#   Stochastic:      32.81
#   Momentum (10):   1.27
#   CCI (10):        -37.87
#   MACD:            -1.8486
#   MACD Signal:     -1.2179
#   MACD Histogram:  -0.6307
#   VWMACD:          -7.5337
#   CMF (21):        0.2583
#   MFI (14):        47.03
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #169 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-06 09:00:00-05:00
#   Entry Price:     $1560.28
#   Open:            $1560.28
#   High:            $1563.19
#   Low:             $1553.00
#   Close:           $1562.04
#   Exit Time:       2025-11-06 19:45:00-05:00
#   Exit Price:      $1543.46
#   P&L:             -1.08%
#   Duration:        39 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        47.39
#   Stochastic:      38.00
#   Momentum (10):   -3.98
#   CCI (10):        -29.38
#   MACD:            -1.0939
#   MACD Signal:     -0.4370
#   MACD Histogram:  -0.6568
#   VWMACD:          -4.3626
#   CMF (21):        0.2206
#   MFI (14):        52.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #170 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-07 10:00:00-05:00
#   Entry Price:     $1546.41
#   Open:            $1546.41
#   High:            $1550.75
#   Low:             $1537.50
#   Close:           $1541.96
#   Exit Time:       2025-11-07 12:00:00-05:00
#   Exit Price:      $1550.87
#   P&L:             +0.29%
#   Duration:        8 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.49
#   Stochastic:      38.37
#   Momentum (10):   -5.34
#   CCI (10):        -127.37
#   MACD:            -1.8021
#   MACD Signal:     -0.6351
#   MACD Histogram:  -1.1670
#   VWMACD:          -3.0646
#   CMF (21):        0.0973
#   MFI (14):        35.05
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #171 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-07 12:45:00-05:00
#   Entry Price:     $1537.35
#   Open:            $1537.35
#   High:            $1542.81
#   Low:             $1531.50
#   Close:           $1541.69
#   Exit Time:       2025-11-10 00:00:00-05:00
#   Exit Price:      $1569.02
#   P&L:             +2.06%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.33
#   Stochastic:      25.03
#   Momentum (10):   -0.67
#   CCI (10):        -32.39
#   MACD:            -2.4398
#   MACD Signal:     -1.6649
#   MACD Histogram:  -0.7749
#   VWMACD:          -2.0011
#   CMF (21):        0.2360
#   MFI (14):        46.46
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #172 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-10 06:00:00-05:00
#   Entry Price:     $1574.44
#   Open:            $1574.44
#   High:            $1577.21
#   Low:             $1568.50
#   Close:           $1572.41
#   Exit Time:       2025-11-10 07:45:00-05:00
#   Exit Price:      $1580.73
#   P&L:             +0.40%
#   Duration:        7 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.32
#   Stochastic:      36.66
#   Momentum (10):   -3.92
#   CCI (10):        -57.90
#   MACD:            1.5883
#   MACD Signal:     2.5232
#   MACD Histogram:  -0.9349
#   VWMACD:          0.5595
#   CMF (21):        -0.1173
#   MFI (14):        42.10
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #173 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-11 23:30:00-05:00
#   Entry Price:     $1583.33
#   Open:            $1583.33
#   High:            $1584.20
#   Low:             $1578.00
#   Close:           $1580.03
#   Exit Time:       2025-11-12 03:45:00-05:00
#   Exit Price:      $1593.21
#   P&L:             +0.62%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.61
#   Stochastic:      40.33
#   Momentum (10):   -12.99
#   CCI (10):        -149.98
#   MACD:            -1.3392
#   MACD Signal:     -0.6693
#   MACD Histogram:  -0.6698
#   VWMACD:          0.5851
#   CMF (21):        0.3272
#   MFI (14):        34.86
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #174 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-13 03:00:00-05:00
#   Entry Price:     $1616.25
#   Open:            $1616.25
#   High:            $1624.00
#   Low:             $1613.50
#   Close:           $1618.86
#   Exit Time:       2025-11-13 04:15:00-05:00
#   Exit Price:      $1618.50
#   P&L:             +0.14%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        53.02
#   Stochastic:      54.57
#   Momentum (10):   0.24
#   CCI (10):        48.76
#   MACD:            0.5908
#   MACD Signal:     0.7987
#   MACD Histogram:  -0.2079
#   VWMACD:          -0.1361
#   CMF (21):        0.2447
#   MFI (14):        50.17
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #175 [OPEN]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-13 09:00:00-05:00
#   Entry Price:     $1604.31
#   Open:            $1604.31
#   High:            $1604.42
#   Low:             $1582.00
#   Close:           $1598.36
#   Current Price:   $1541.40
#   P&L:             -3.92%
#   Duration:        123 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.71
#   Stochastic:      39.33
#   Momentum (10):   -15.45
#   CCI (10):        -100.38
#   MACD:            -4.5159
#   MACD Signal:     -2.4774
#   MACD Histogram:  -2.0384
#   VWMACD:          -8.2664
#   CMF (21):        0.4206
#   MFI (14):        28.57
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20647 | time = 2025-11-14 14:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1549.6300
#   High   : 1550.5100
#   Low    : 1545.5000
#   Close  : 1548.6700
#   Volume : 1620.0
#
# 📈 INDICATORS:
#   RSI(14)        : 43.2789
#   MACD(12,26,9)  : -2.4513
#   MACD Signal    : -2.0332
#   MACD Hist      : -0.4181
#   Momentum(10)   : -5.3490
#   Stoch(14,3)    : 21.6223
#   CCI(10)        : -65.1573
#   VW-MACD        : 1.0669
#   CMF(21)        : 0.3420
#   MFI(14)        : 47.7278
#   OBV            : 147837.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20648 | time = 2025-11-14 14:45:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1548.7500
#   High   : 1550.5900
#   Low    : 1546.0000
#   Close  : 1548.9500
#   Volume : 1640.0
#
# 📈 INDICATORS:
#   RSI(14)        : 43.6628
#   MACD(12,26,9)  : -2.4753
#   MACD Signal    : -2.1216
#   MACD Hist      : -0.3537
#   Momentum(10)   : -5.8190
#   Stoch(14,3)    : 21.9297
#   CCI(10)        : -50.1242
#   VW-MACD        : -0.7626
#   CMF(21)        : 0.2886
#   MFI(14)        : 45.3228
#   OBV            : 149477.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20649 | time = 2025-11-14 15:00:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1548.9700
#   High   : 1549.9900
#   Low    : 1545.0000
#   Close  : 1547.2910
#   Volume : 1686.0
#
# 📈 INDICATORS:
#   RSI(14)        : 41.8553
#   MACD(12,26,9)  : -2.5982
#   MACD Signal    : -2.2170
#   MACD Hist      : -0.3813
#   Momentum(10)   : -8.0180
#   Stoch(14,3)    : 19.4495
#   CCI(10)        : -101.9353
#   VW-MACD        : -1.9455
#   CMF(21)        : 0.2296
#   MFI(14)        : 37.9103
#   OBV            : 147791.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20650 | time = 2025-11-14 15:15:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1547.1910
#   High   : 1548.6900
#   Low    : 1539.5000
#   Close  : 1545.0410
#   Volume : 1972.0
#
# 📈 INDICATORS:
#   RSI(14)        : 39.4690
#   MACD(12,26,9)  : -2.8444
#   MACD Signal    : -2.3424
#   MACD Hist      : -0.5020
#   Momentum(10)   : -10.8880
#   Stoch(14,3)    : 20.8798
#   CCI(10)        : -191.4225
#   VW-MACD        : -3.7308
#   CMF(21)        : 0.2339
#   MFI(14)        : 38.6481
#   OBV            : 145819.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20651 | time = 2025-11-14 15:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1545.0610
#   High   : 1548.6300
#   Low    : 1542.5000
#   Close  : 1545.3810
#   Volume : 1672.0
#
# 📈 INDICATORS:
#   RSI(14)        : 40.0254
#   MACD(12,26,9)  : -2.9778
#   MACD Signal    : -2.4695
#   MACD Hist      : -0.5082
#   Momentum(10)   : -6.8090
#   Stoch(14,3)    : 24.8907
#   CCI(10)        : -127.9956
#   VW-MACD        : -5.7861
#   CMF(21)        : 0.2297
#   MFI(14)        : 45.5272
#   OBV            : 147491.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20652 | time = 2025-11-14 15:45:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1545.3610
#   High   : 1546.4910
#   Low    : 1541.0000
#   Close  : 1545.3910
#   Volume : 1653.0
#
# 📈 INDICATORS:
#   RSI(14)        : 40.0429
#   MACD(12,26,9)  : -3.0475
#   MACD Signal    : -2.5851
#   MACD Hist      : -0.4624
#   Momentum(10)   : -4.5090
#   Stoch(14,3)    : 31.0980
#   CCI(10)        : -99.9003
#   VW-MACD        : -7.0577
#   CMF(21)        : 0.2903
#   MFI(14)        : 44.7101
#   OBV            : 149144.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20653 | time = 2025-11-14 16:00:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1545.3910
#   High   : 1545.3910
#   Low    : 1538.5000
#   Close  : 1541.4220
#   Volume : 923.0
#
# 📈 INDICATORS:
#   RSI(14)        : 35.6120
#   MACD(12,26,9)  : -3.3840
#   MACD Signal    : -2.7449
#   MACD Hist      : -0.6391
#   Momentum(10)   : -7.7780
#   Stoch(14,3)    : 28.0791
#   CCI(10)        : -177.3416
#   VW-MACD        : -7.9871
#   CMF(21)        : 0.2323
#   MFI(14)        : 38.3291
#   OBV            : 148221.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20654 | time = 2025-11-14 16:15:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1541.4420
#   High   : 1544.0210
#   Low    : 1540.0000
#   Close  : 1543.8110
#   Volume : 571.0
#
# 📈 INDICATORS:
#   RSI(14)        : 39.9213
#   MACD(12,26,9)  : -3.4185
#   MACD Signal    : -2.8796
#   MACD Hist      : -0.5389
#   Momentum(10)   : -3.7900
#   Stoch(14,3)    : 26.4324
#   CCI(10)        : -78.3125
#   VW-MACD        : -7.6745
#   CMF(21)        : 0.2840
#   MFI(14)        : 34.4834
#   OBV            : 148792.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20655 | time = 2025-11-14 16:30:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1543.8610
#   High   : 1543.8910
#   Low    : 1540.5000
#   Close  : 1541.9620
#   Volume : 715.0
#
# 📈 INDICATORS:
#   RSI(14)        : 37.8120
#   MACD(12,26,9)  : -3.5541
#   MACD Signal    : -3.0145
#   MACD Hist      : -0.5396
#   Momentum(10)   : -7.3180
#   Stoch(14,3)    : 23.0798
#   CCI(10)        : -109.6786
#   VW-MACD        : -7.4753
#   CMF(21)        : 0.2619
#   MFI(14)        : 38.4059
#   OBV            : 148077.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================
#
# ================================================================================
# DEBUG SNAPSHOT @ index 20656 | time = 2025-11-14 16:45:00-05:00
# ================================================================================
#
# 📊 PRICE:
#   Open   : 1541.9620
#   High   : 1542.2910
#   Low    : 1541.1020
#   Close  : 1541.4020
#   Volume : 213.0
#
# 📈 INDICATORS:
#   RSI(14)        : 37.1714
#   MACD(12,26,9)  : -3.6645
#   MACD Signal    : -3.1445
#   MACD Hist      : -0.5200
#   Momentum(10)   : -8.2480
#   Stoch(14,3)    : 24.4636
#   CCI(10)        : -105.7100
#   VW-MACD        : -7.2956
#   CMF(21)        : 0.2315
#   MFI(14)        : 44.0375
#   OBV            : 147864.0000
#
# 📌 PIVOTS & DIVERGENCES:
#   pivot_high       : nan
#   pivot_low        : nan
#   pos_div_count    : 0.0
#   neg_div_count    : 0.0
#   total_divergences: 0.0
# ================================================================================

# %%
#===============================================================================
# CELL 2: Auto "window + indicators + pivots" search (with drawdown stats)
#===============================================================================

# !pip install scikit-learn

from sklearn.model_selection import ParameterGrid

#-------------------------------------------
# 0) Load CSV ONCE and prepare pivot cache
#-------------------------------------------

# نفس csv_filename اللي فوق في الـ main
# لو حابب تغيره، غيّره مرة واحدة هنا وهنا في main
base_df = load_data_from_csv(csv_filename)

# هنسجّل فيها pivots لكل pivot_prd (3,5, ...)
pivot_cache = {}

#-------------------------------------------
# 1) Parametric indicator calculator
#-------------------------------------------

def calculate_indicators_with_params(df, params):
    """
    نسخة من calculate_indicators لكن بالـ windows جاية من params
    ما بنلمسش Config ولا الاستراتيجية نفسها، بس بنغير إعدادات المؤشرات.
    """
    df = df.copy()

    # نقرأ الـ windows من params مع قيم default
    rsi_window      = params.get("rsi_window",      14)
    macd_fast       = params.get("macd_fast",       12)
    macd_slow       = params.get("macd_slow",       26)
    macd_signal     = params.get("macd_signal",      9)
    mom_window      = params.get("mom_window",      10)
    stoch_window    = params.get("stoch_window",    14)
    stoch_smooth    = params.get("stoch_smooth",     3)
    vwma_fast_win   = params.get("vwma_fast",       12)
    vwma_slow_win   = params.get("vwma_slow",       26)
    cmf_window      = params.get("cmf_window",      21)
    cci_window      = params.get("cci_window",      10)
    mfi_window      = params.get("mfi_window",      14)

    close  = df["close"]
    high   = df["high"]
    low    = df["low"]
    volume = df["volume"]

    # ----- RSI -----
    df["rsi"] = ta.momentum.RSIIndicator(
        close, window=rsi_window
    ).rsi()

    # ----- MACD -----
    macd_ind = ta.trend.MACD(
        close,
        window_slow=macd_slow,
        window_fast=macd_fast,
        window_sign=macd_signal,
    )
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # ----- Momentum -----
    df["momentum"] = close - close.shift(mom_window)

    # ----- Stochastic -----
    lowest_low   = low.rolling(window=stoch_window).min()
    highest_high = high.rolling(window=stoch_window).max()
    stoch_k = 100 * (close - lowest_low) / (highest_high - lowest_low)
    df["stoch"] = stoch_k.rolling(window=stoch_smooth).mean()

    # ----- VW-MACD (VWMA fast - VWMA slow) -----
    vwma_fast = (close * volume).rolling(vwma_fast_win).sum() / volume.rolling(vwma_fast_win).sum()
    vwma_slow = (close * volume).rolling(vwma_slow_win).sum() / volume.rolling(vwma_slow_win).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # ----- CMF -----
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high, low, close, volume, window=cmf_window
    ).chaikin_money_flow()

    # ----- CCI -----
    df["cci"] = ta.trend.CCIIndicator(
        high, low, close,
        window=cci_window, constant=0.015, fillna=False
    ).cci()

    # ----- MFI -----
    df["mfi"] = ta.volume.MFIIndicator(
        high, low, close, volume,
        window=mfi_window, fillna=False
    ).money_flow_index()

    # ----- OBV (نفس الكود القديم) -----
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i - 1]:
            obv_values.append(obv_values[-1] + volume.iloc[i])
        elif close.iloc[i] < close.iloc[i - 1]:
            obv_values.append(obv_values[-1] - volume.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df["obv"] = obv_values

    # Fill NaNs
    df = df.fillna(method="bfill").fillna(method="ffill")

    return df

#-------------------------------------------
# 2) Fast performance evaluator (بدون طباعة) + drawdown per trade
#-------------------------------------------

def quick_performance(df):
    """
    - يحسب P&L لكل صفقة
    - يحسب max drawdown% لكل صفقة (أكبر نزول عن سعر الدخول)
    - يرجّع ملخّص: total_trades, win_rate, avg_pnl, total_return,
                    max_dd, avg_dd, median_dd
    """
    entries = df[df["signal"] == 1].copy()
    exits   = df[df["signal"] == -1].copy()

    if len(entries) == 0:
        return {
            "total_trades": 0,
            "win_rate": 0.0,
            "avg_pnl": 0.0,
            "total_return": 0.0,
            "max_dd": 0.0,
            "avg_dd": 0.0,
            "median_dd": 0.0,
        }

    pnl_list = []
    dd_list  = []

    for i, entry_row in entries.iterrows():
        entry_idx   = df.index.get_loc(i)
        entry_price = entry_row["entry_price"]

        # نلاقي أول exit بعد entry
        exit_idx = None
        exit_price = None
        for j, exit_row in exits.iterrows():
            candidate_idx = df.index.get_loc(j)
            if candidate_idx > entry_idx:
                exit_idx   = candidate_idx
                exit_price = exit_row["exit_price"]
                break

        # لو مفيش exit -> نخرج عند آخر شمعة
        if exit_idx is None:
            exit_idx   = len(df) - 1
            exit_price = df["close"].iloc[-1]

        # --- P&L للصفقة ---
        pnl_pct = (exit_price - entry_price) / entry_price * 100.0
        pnl_list.append(pnl_pct)

        # --- Drawdown للصفقة ---
        trade_slice = df.iloc[entry_idx:exit_idx + 1]
        dd_series = (trade_slice["low"] - entry_price) / entry_price * 100.0
        worst_dd = dd_series.min()   # سالب غالباً
        dd_mag   = abs(worst_dd)     # نخليه موجب
        dd_list.append(dd_mag)

    trades = np.array(pnl_list)
    dds    = np.array(dd_list)

    total_trades = len(trades)
    wins   = (trades > 0).sum()
    win_rate = (wins / total_trades * 100.0) if total_trades > 0 else 0.0
    avg_pnl = trades.mean() if total_trades > 0 else 0.0
    total_return = trades.sum()

    max_dd     = dds.max()      if len(dds) > 0 else 0.0
    avg_dd     = dds.mean()     if len(dds) > 0 else 0.0
    median_dd  = np.median(dds) if len(dds) > 0 else 0.0

    return {
        "total_trades": int(total_trades),
        "win_rate": float(win_rate),
        "avg_pnl": float(avg_pnl),
        "total_return": float(total_return),
        "max_dd": float(max_dd),
        "avg_dd": float(avg_dd),
        "median_dd": float(median_dd),
    }

#-------------------------------------------
# 3) Pipeline for one parameter set (مع pivot cache)
#-------------------------------------------

def run_pipeline_with_params(df_base, params):
    """
    - يستخدم df_base (loaded once)
    - يحسب المؤشرات بالـ windows الجديدة
    - يظبط Config:
        * pivot period (prd)
        * أي indicators عايز تطفيها/تشغّلها
    - يركّب pivots من pivot_cache حسب pivot_prd
    - يطلع divergences + strategy + quick metrics
    """
    # نخزن الـ state الأصلي عشان نرجّعه بعدين
    orig_state = {
        "prd":       config.prd,
        "calcmacd":  config.calcmacd,
        "calcmacda": config.calcmacda,
        "calcrsi":   config.calcrsi,
        "calcstoc":  config.calcstoc,
        "calccci":   config.calccci,
        "calcmom":   config.calcmom,
        "calcobv":   config.calcobv,
        "calcvwmacd":config.calcvwmacd,
        "calccmf":   config.calccmf,
        "calcmfi":   config.calcmfi,
    }

    try:
        # 1) نغيّر الـ pivot period لو موجود في params
        pivot_prd = params.get("pivot_prd", config.prd)
        config.prd = int(pivot_prd)

        # 2) نطبّق ON/OFF للمؤشرات لو params فيها flags
        indicator_flags = {
            "use_macd":      "calcmacd",
            "use_macd_hist": "calcmacda",
            "use_rsi":       "calcrsi",
            "use_stoch":     "calcstoc",
            "use_mom":       "calcmom",
            "use_cci":       "calccci",
            "use_obv":       "calcobv",
            "use_vwmacd":    "calcvwmacd",
            "use_cmf":       "calccmf",
            "use_mfi":       "calcmfi",
        }
        for param_key, cfg_attr in indicator_flags.items():
            if param_key in params:
                setattr(config, cfg_attr, bool(params[param_key]))

        # 3) Indicators على نسخة من الـ base df
        df = calculate_indicators_with_params(df_base, params)

        # 4) Pivots من الـ cache (أو نحسب ونخزّن أول مرة)
        prd = config.prd
        if prd not in pivot_cache:
            tmp = base_df.copy()
            tmp = find_pivots(tmp, prd)
            pivot_cache[prd] = {
                "pivot_high"     : tmp["pivot_high"].to_numpy(),
                "pivot_low"      : tmp["pivot_low"].to_numpy(),
                "pivot_high_bar" : tmp["pivot_high_bar"].to_numpy(),
                "pivot_low_bar"  : tmp["pivot_low_bar"].to_numpy(),
            }

        piv = pivot_cache[prd]
        df["pivot_high"]     = piv["pivot_high"]
        df["pivot_low"]      = piv["pivot_low"]
        df["pivot_high_bar"] = piv["pivot_high_bar"]
        df["pivot_low_bar"]  = piv["pivot_low_bar"]

        # 5) Divergences + strategy
        df = scan_all_divergences(df)
        df = run_strategy(df)
        metrics = quick_performance(df)
    finally:
        # نرجّع Config زي ما كانت عشان التجربة اللي بعدها
        config.prd       = orig_state["prd"]
        config.calcmacd  = orig_state["calcmacd"]
        config.calcmacda = orig_state["calcmacda"]
        config.calcrsi   = orig_state["calcrsi"]
        config.calcstoc  = orig_state["calcstoc"]
        config.calccci   = orig_state["calccci"]
        config.calcmom   = orig_state["calcmom"]
        config.calcobv   = orig_state["calcobv"]
        config.calcvwmacd= orig_state["calcvwmacd"]
        config.calccmf   = orig_state["calccmf"]
        config.calcmfi   = orig_state["calcmfi"]

    return metrics, df

#-------------------------------------------
# 4) Grid search على windows + indicators + pivot period
#-------------------------------------------

param_grid = {
    # ---- indicator windows ----
    "rsi_window"   : [7, 10, 14, 21],
    "stoch_window" : [9, 14],
    "stoch_smooth" : [3],
    "mom_window"   : [5, 10],
    "cci_window"   : [10],
    "mfi_window"   : [10, 20],
    "vwma_fast"    : [8, 12],
    "vwma_slow"    : [26],
    "cmf_window"   : [14, 21],

    # ---- pivot period ----
    "pivot_prd"    : [3, 5],

    # ---- indicator ON/OFF ----
    "use_vwmacd"   : [True, False],
    "use_cmf"      : [True, False],
    "use_mfi"      : [True, False],
}

grid = list(ParameterGrid(param_grid))
print(f"🔍 Number of combinations to test: {len(grid)}")

results = []

for idx, params in enumerate(grid, start=1):
    metrics, _ = run_pipeline_with_params(base_df, params)
    row = {**params, **metrics}
    results.append(row)

    print(f"\n[{idx}/{len(grid)}]")
    print(f"  params : {params}")
    print(
        "  metrics: "
        f"trades={metrics['total_trades']}, "
        f"win_rate={metrics['win_rate']:.2f}%, "
        f"avg_pnl={metrics['avg_pnl']:.2f}%, "
        f"total_return={metrics['total_return']:.2f}%, "
        f"max_dd={metrics['max_dd']:.2f}%, "
        f"avg_dd={metrics['avg_dd']:.2f}%, "
        f"median_dd={metrics['median_dd']:.2f}%"
    )

    # 💾 checkpoint كل 100 combo عشان الأمان
    if idx % 100 == 0 or idx == len(grid):
        tmp_df = pd.DataFrame(results)
        tmp_df.to_csv("divergence_param_grid_results_partial.csv", index=False)
        print("  💾 checkpoint saved: divergence_param_grid_results_partial.csv")

results_df = pd.DataFrame(results)

# نرتب حسب:
#   1) أعلى Total Return
#   2) أعلى Win Rate
#   3) أقل Max Drawdown
results_df = results_df.sort_values(
    by=["total_return", "win_rate", "max_dd"],
    ascending=[False, False, True]
).reset_index(drop=True)

print("\n===============================================")
print("🏆 TOP 10 PARAMETER SETS (by total_return, win_rate, low max_dd)")
print("===============================================")
print(results_df.head(10))

#-------------------------------------------
# 5) Export full grid-search results to CSV
#-------------------------------------------

csv_output_path = "divergence_param_grid_results.csv"
results_df.to_csv(csv_output_path, index=False)
print(f"\n📁 Full grid-search results saved to: {csv_output_path}")

best_params = results_df.iloc[0][list(param_grid.keys())].to_dict()
print("\n🔥 BEST PARAMS FOUND:")
for k, v in best_params.items():
    print(f"  {k}: {v}")

# شغّل الاستراتيجية تاني على أحسن params وشوف الشارت:
best_metrics, best_df = run_pipeline_with_params(base_df, best_params)
print("\nBest metrics on full sample:")
print(best_metrics)

# لو حابب تشوف الشارت:
# plot_candlestick_with_signals(best_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [1346/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=269, win_rate=72.12%, avg_pnl=0.20%, total_return=54.55%, max_dd=7.98%, avg_dd=0.90%, median_dd=0.57%
# Scanning for divergences...
# Found 2212 bars with divergences
# Running strategy...
#
# [1347/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=242, win_rate=73.55%, avg_pnl=0.22%, total_return=52.83%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.58%
# Scanning for divergences...
# Found 2212 bars with divergences
# Running strategy...
#
# [1348/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=242, win_rate=73.55%, avg_pnl=0.22%, total_return=52.83%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.58%
# Scanning for divergences...
# Found 2189 bars with divergences
# Running strategy...
#
# [1349/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=245, win_rate=72.65%, avg_pnl=0.20%, total_return=49.21%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.57%
# Scanning for divergences...
# Found 2235 bars with divergences
# Running strategy...
#
# [1350/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=251, win_rate=72.11%, avg_pnl=0.20%, total_return=50.95%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.58%
# Scanning for divergences...
# Found 2096 bars with divergences
# Running strategy...
#
# [1351/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=220, win_rate=72.27%, avg_pnl=0.19%, total_return=42.89%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.60%
# Scanning for divergences...
# Found 2096 bars with divergences
# Running strategy...
#
# [1352/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=220, win_rate=72.27%, avg_pnl=0.19%, total_return=42.89%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.60%
# Scanning for divergences...
# Found 2078 bars with divergences
# Running strategy...
#
# [1353/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=229, win_rate=73.80%, avg_pnl=0.19%, total_return=43.39%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.58%
# Scanning for divergences...
# Found 2149 bars with divergences
# Running strategy...
#
# [1354/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=233, win_rate=71.24%, avg_pnl=0.19%, total_return=43.89%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.58%
# Scanning for divergences...
# Found 1995 bars with divergences
# Running strategy...
#
# [1355/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=205, win_rate=73.17%, avg_pnl=0.20%, total_return=40.44%, max_dd=7.98%, avg_dd=1.01%, median_dd=0.58%
# Scanning for divergences...
# Found 1995 bars with divergences
# Running strategy...
#
# [1356/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=205, win_rate=73.17%, avg_pnl=0.20%, total_return=40.44%, max_dd=7.98%, avg_dd=1.01%, median_dd=0.58%
# Scanning for divergences...
# Found 1965 bars with divergences
# Running strategy...
#
# [1357/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=213, win_rate=73.71%, avg_pnl=0.19%, total_return=41.08%, max_dd=7.07%, avg_dd=0.96%, median_dd=0.57%
# Scanning for divergences...
# Found 2028 bars with divergences
# Running strategy...
#
# [1358/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=217, win_rate=70.97%, avg_pnl=0.20%, total_return=44.01%, max_dd=7.07%, avg_dd=0.95%, median_dd=0.58%
# Scanning for divergences...
# Found 1860 bars with divergences
# Running strategy...
#
# [1359/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=183, win_rate=71.04%, avg_pnl=0.18%, total_return=32.66%, max_dd=7.07%, avg_dd=1.02%, median_dd=0.60%
# Scanning for divergences...
# Found 1860 bars with divergences
# Running strategy...
#
# [1360/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=183, win_rate=71.04%, avg_pnl=0.18%, total_return=32.66%, max_dd=7.07%, avg_dd=1.02%, median_dd=0.60%
# Scanning for divergences...
# Found 2291 bars with divergences
# Running strategy...
#
# [1361/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=257, win_rate=73.93%, avg_pnl=0.21%, total_return=54.78%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.58%
# Scanning for divergences...
# Found 2347 bars with divergences
# Running strategy...
#
# [1362/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=264, win_rate=73.48%, avg_pnl=0.20%, total_return=53.46%, max_dd=7.98%, avg_dd=0.91%, median_dd=0.58%
# Scanning for divergences...
# Found 2217 bars with divergences
# Running strategy...
#
# [1363/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=235, win_rate=74.47%, avg_pnl=0.22%, total_return=50.67%, max_dd=7.98%, avg_dd=0.95%, median_dd=0.60%
# Scanning for divergences...
# Found 2217 bars with divergences
# Running strategy...
#
# [1364/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=235, win_rate=74.47%, avg_pnl=0.22%, total_return=50.67%, max_dd=7.98%, avg_dd=0.95%, median_dd=0.60%
# Scanning for divergences...
# Found 2187 bars with divergences
# Running strategy...
#
# [1365/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=238, win_rate=74.37%, avg_pnl=0.21%, total_return=50.41%, max_dd=7.98%, avg_dd=0.94%, median_dd=0.58%
# Scanning for divergences...
# Found 2237 bars with divergences
# Running strategy...
#
# [1366/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=244, win_rate=74.18%, avg_pnl=0.21%, total_return=51.17%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.59%
# Scanning for divergences...
# Found 2096 bars with divergences
# Running strategy...
#
# [1367/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=212, win_rate=74.06%, avg_pnl=0.20%, total_return=42.55%, max_dd=7.98%, avg_dd=1.00%, median_dd=0.63%
# Scanning for divergences...
# Found 2096 bars with divergences
# Running strategy...
#
# [1368/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=212, win_rate=74.06%, avg_pnl=0.20%, total_return=42.55%, max_dd=7.98%, avg_dd=1.00%, median_dd=0.63%
# Scanning for divergences...
# Found 2079 bars with divergences
# Running strategy...
#
# [1369/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=222, win_rate=73.87%, avg_pnl=0.19%, total_return=42.28%, max_dd=7.98%, avg_dd=0.99%, median_dd=0.61%
# Scanning for divergences...
# Found 2152 bars with divergences
# Running strategy...
#
# [1370/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=225, win_rate=72.44%, avg_pnl=0.19%, total_return=42.59%, max_dd=7.98%, avg_dd=0.99%, median_dd=0.61%
# Scanning for divergences...
# Found 1997 bars with divergences
# Running strategy...
#
# [1371/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=196, win_rate=73.47%, avg_pnl=0.19%, total_return=37.47%, max_dd=7.98%, avg_dd=1.04%, median_dd=0.61%
# Scanning for divergences...
# Found 1997 bars with divergences
# Running strategy...
#
# [1372/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=196, win_rate=73.47%, avg_pnl=0.19%, total_return=37.47%, max_dd=7.98%, avg_dd=1.04%, median_dd=0.61%
# Scanning for divergences...
# Found 1957 bars with divergences
# Running strategy...
#
# [1373/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=206, win_rate=74.76%, avg_pnl=0.21%, total_return=42.38%, max_dd=7.07%, avg_dd=0.98%, median_dd=0.59%
# Scanning for divergences...
# Found 2024 bars with divergences
# Running strategy...
#
# [1374/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=208, win_rate=73.08%, avg_pnl=0.21%, total_return=43.96%, max_dd=7.07%, avg_dd=0.97%, median_dd=0.61%
# Scanning for divergences...
# Found 1854 bars with divergences
# Running strategy...
#
# [1375/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=172, win_rate=72.67%, avg_pnl=0.18%, total_return=30.91%, max_dd=7.07%, avg_dd=1.06%, median_dd=0.61%
# Scanning for divergences...
# Found 1854 bars with divergences
# Running strategy...
#
# [1376/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 14, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=172, win_rate=72.67%, avg_pnl=0.18%, total_return=30.91%, max_dd=7.07%, avg_dd=1.06%, median_dd=0.61%
# Scanning for divergences...
# Found 2286 bars with divergences
# Running strategy...
#
# [1377/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=263, win_rate=73.00%, avg_pnl=0.21%, total_return=55.67%, max_dd=7.98%, avg_dd=0.90%, median_dd=0.56%
# Scanning for divergences...
# Found 2338 bars with divergences
# Running strategy...
#
# [1378/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=268, win_rate=72.01%, avg_pnl=0.20%, total_return=54.92%, max_dd=7.98%, avg_dd=0.90%, median_dd=0.56%
# Scanning for divergences...
# Found 2210 bars with divergences
# Running strategy...
#
# [1379/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=243, win_rate=73.66%, avg_pnl=0.22%, total_return=53.85%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.57%
# Scanning for divergences...
# Found 2210 bars with divergences
# Running strategy...
#
# [1380/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=243, win_rate=73.66%, avg_pnl=0.22%, total_return=53.85%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.57%
# Scanning for divergences...
# Found 2187 bars with divergences
# Running strategy...
#
# [1381/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=245, win_rate=72.65%, avg_pnl=0.20%, total_return=49.48%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.57%
# Scanning for divergences...
# Found 2232 bars with divergences
# Running strategy...
#
# [1382/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=249, win_rate=71.89%, avg_pnl=0.20%, total_return=49.86%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.57%
# Scanning for divergences...
# Found 2093 bars with divergences
# Running strategy...
#
# [1383/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=220, win_rate=72.27%, avg_pnl=0.19%, total_return=42.71%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.59%
# Scanning for divergences...
# Found 2093 bars with divergences
# Running strategy...
#
# [1384/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=220, win_rate=72.27%, avg_pnl=0.19%, total_return=42.71%, max_dd=7.98%, avg_dd=0.97%, median_dd=0.59%
# Scanning for divergences...
# Found 2072 bars with divergences
# Running strategy...
#
# [1385/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=230, win_rate=73.91%, avg_pnl=0.20%, total_return=44.86%, max_dd=7.98%, avg_dd=0.96%, median_dd=0.57%
# Scanning for divergences...
# Found 2143 bars with divergences
# Running strategy...
#
# [1386/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=234, win_rate=71.37%, avg_pnl=0.19%, total_return=44.44%, max_dd=7.98%, avg_dd=0.96%, median_dd=0.58%
# Scanning for divergences...
# Found 1989 bars with divergences
# Running strategy...
#
# [1387/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=208, win_rate=73.56%, avg_pnl=0.21%, total_return=43.26%, max_dd=7.98%, avg_dd=1.00%, median_dd=0.58%
# Scanning for divergences...
# Found 1989 bars with divergences
# Running strategy...
#
# [1388/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=208, win_rate=73.56%, avg_pnl=0.21%, total_return=43.26%, max_dd=7.98%, avg_dd=1.00%, median_dd=0.58%
# Scanning for divergences...
# Found 1959 bars with divergences
# Running strategy...
#
# [1389/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=213, win_rate=73.71%, avg_pnl=0.20%, total_return=41.97%, max_dd=7.07%, avg_dd=0.96%, median_dd=0.57%
# Scanning for divergences...
# Found 2023 bars with divergences
# Running strategy...
#
# [1390/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=216, win_rate=70.83%, avg_pnl=0.20%, total_return=42.51%, max_dd=7.07%, avg_dd=0.95%, median_dd=0.58%
# Scanning for divergences...
# Found 1853 bars with divergences
# Running strategy...
#
# [1391/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=71.35%, avg_pnl=0.18%, total_return=34.03%, max_dd=7.07%, avg_dd=1.01%, median_dd=0.58%
# Scanning for divergences...
# Found 1853 bars with divergences
# Running strategy...
#
# [1392/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=185, win_rate=71.35%, avg_pnl=0.18%, total_return=34.03%, max_dd=7.07%, avg_dd=1.01%, median_dd=0.58%
# Scanning for divergences...
# Found 2289 bars with divergences
# Running strategy...
#
# [1393/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=257, win_rate=73.93%, avg_pnl=0.21%, total_return=55.12%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.57%
# Scanning for divergences...
# Found 2344 bars with divergences
# Running strategy...
#
# [1394/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=263, win_rate=73.38%, avg_pnl=0.20%, total_return=53.90%, max_dd=7.98%, avg_dd=0.91%, median_dd=0.57%
# Scanning for divergences...
# Found 2215 bars with divergences
# Running strategy...
#
# [1395/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=236, win_rate=74.58%, avg_pnl=0.22%, total_return=51.76%, max_dd=7.98%, avg_dd=0.95%, median_dd=0.59%
# Scanning for divergences...
# Found 2215 bars with divergences
# Running strategy...
#
# [1396/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=236, win_rate=74.58%, avg_pnl=0.22%, total_return=51.76%, max_dd=7.98%, avg_dd=0.95%, median_dd=0.59%
# Scanning for divergences...
# Found 2185 bars with divergences
# Running strategy...
#
# [1397/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=238, win_rate=74.37%, avg_pnl=0.21%, total_return=50.75%, max_dd=7.98%, avg_dd=0.94%, median_dd=0.58%
# Scanning for divergences...
# Found 2235 bars with divergences
# Running strategy...
#
# [1398/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=243, win_rate=74.07%, avg_pnl=0.21%, total_return=51.61%, max_dd=7.98%, avg_dd=0.93%, median_dd=0.58%
# Scanning for divergences...
# Found 2094 bars with divergences
# Running strategy...
#
# [1399/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=213, win_rate=74.18%, avg_pnl=0.20%, total_return=43.64%, max_dd=7.98%, avg_dd=0.99%, median_dd=0.61%
# Scanning for divergences...
# Found 2094 bars with divergences
# Running strategy...
#
# [1400/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=213, win_rate=74.18%, avg_pnl=0.20%, total_return=43.64%, max_dd=7.98%, avg_dd=0.99%, median_dd=0.61%
#   💾 checkpoint saved: divergence_param_grid_results_partial.csv
# Scanning for divergences...
# Found 2073 bars with divergences
# Running strategy...
#
# [1401/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=223, win_rate=73.99%, avg_pnl=0.20%, total_return=43.83%, max_dd=7.98%, avg_dd=0.98%, median_dd=0.61%
# Scanning for divergences...
# Found 2146 bars with divergences
# Running strategy...
#
# [1402/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=226, win_rate=72.57%, avg_pnl=0.19%, total_return=43.21%, max_dd=7.98%, avg_dd=0.98%, median_dd=0.61%
# Scanning for divergences...
# Found 1992 bars with divergences
# Running strategy...
#
# [1403/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=199, win_rate=73.87%, avg_pnl=0.20%, total_return=40.10%, max_dd=7.98%, avg_dd=1.03%, median_dd=0.61%
# Scanning for divergences...
# Found 1992 bars with divergences
# Running strategy...
#
# [1404/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=199, win_rate=73.87%, avg_pnl=0.20%, total_return=40.10%, max_dd=7.98%, avg_dd=1.03%, median_dd=0.61%
# Scanning for divergences...
# Found 1952 bars with divergences
# Running strategy...
#
# [1405/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=207, win_rate=74.88%, avg_pnl=0.21%, total_return=43.65%, max_dd=7.07%, avg_dd=0.97%, median_dd=0.58%
# Scanning for divergences...
# Found 2020 bars with divergences
# Running strategy...
#
# [1406/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=209, win_rate=73.21%, avg_pnl=0.21%, total_return=44.30%, max_dd=7.07%, avg_dd=0.96%, median_dd=0.61%
# Scanning for divergences...
# Found 1850 bars with divergences
# Running strategy...
#
# [1407/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=175, win_rate=73.14%, avg_pnl=0.19%, total_return=34.08%, max_dd=7.07%, avg_dd=1.04%, median_dd=0.61%
# Scanning for divergences...
# Found 1850 bars with divergences
# Running strategy...
#
# [1408/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 3, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=175, win_rate=73.14%, avg_pnl=0.19%, total_return=34.08%, max_dd=7.07%, avg_dd=1.04%, median_dd=0.61%
# Scanning for divergences...
# Found 1669 bars with divergences
# Running strategy...
#
# [1409/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=181, win_rate=74.03%, avg_pnl=0.31%, total_return=56.78%, max_dd=6.02%, avg_dd=1.06%, median_dd=0.67%
# Scanning for divergences...
# Found 1700 bars with divergences
# Running strategy...
#
# [1410/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=190, win_rate=74.21%, avg_pnl=0.33%, total_return=63.48%, max_dd=7.92%, avg_dd=1.05%, median_dd=0.68%
# Scanning for divergences...
# Found 1631 bars with divergences
# Running strategy...
#
# [1411/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=176, win_rate=74.43%, avg_pnl=0.31%, total_return=55.16%, max_dd=6.02%, avg_dd=1.05%, median_dd=0.66%
# Scanning for divergences...
# Found 1631 bars with divergences
# Running strategy...
#
# [1412/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=176, win_rate=74.43%, avg_pnl=0.31%, total_return=55.16%, max_dd=6.02%, avg_dd=1.05%, median_dd=0.66%
# Scanning for divergences...
# Found 1594 bars with divergences
# Running strategy...
#
# [1413/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=168, win_rate=73.81%, avg_pnl=0.30%, total_return=50.38%, max_dd=5.29%, avg_dd=1.06%, median_dd=0.68%
# Scanning for divergences...
# Found 1626 bars with divergences
# Running strategy...
#
# [1414/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=178, win_rate=74.72%, avg_pnl=0.33%, total_return=59.35%, max_dd=7.92%, avg_dd=1.05%, median_dd=0.67%
# Scanning for divergences...
# Found 1551 bars with divergences
# Running strategy...
#
# [1415/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=163, win_rate=74.23%, avg_pnl=0.29%, total_return=47.55%, max_dd=5.29%, avg_dd=1.06%, median_dd=0.67%
# Scanning for divergences...
# Found 1551 bars with divergences
# Running strategy...
#
# [1416/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=163, win_rate=74.23%, avg_pnl=0.29%, total_return=47.55%, max_dd=5.29%, avg_dd=1.06%, median_dd=0.67%
# Scanning for divergences...
# Found 1516 bars with divergences
# Running strategy...
#
# [1417/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=160, win_rate=74.38%, avg_pnl=0.33%, total_return=52.07%, max_dd=6.02%, avg_dd=1.12%, median_dd=0.73%
# Scanning for divergences...
# Found 1554 bars with divergences
# Running strategy...
#
# [1418/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=74.25%, avg_pnl=0.34%, total_return=57.40%, max_dd=6.02%, avg_dd=1.10%, median_dd=0.72%
# Scanning for divergences...
# Found 1471 bars with divergences
# Running strategy...
#
# [1419/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=155, win_rate=75.48%, avg_pnl=0.34%, total_return=52.34%, max_dd=6.02%, avg_dd=1.11%, median_dd=0.73%
# Scanning for divergences...
# Found 1471 bars with divergences
# Running strategy...
#
# [1420/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=155, win_rate=75.48%, avg_pnl=0.34%, total_return=52.34%, max_dd=6.02%, avg_dd=1.11%, median_dd=0.73%
# Scanning for divergences...
# Found 1434 bars with divergences
# Running strategy...
#
# [1421/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=150, win_rate=74.67%, avg_pnl=0.33%, total_return=49.19%, max_dd=5.29%, avg_dd=1.11%, median_dd=0.73%
# Scanning for divergences...
# Found 1472 bars with divergences
# Running strategy...
#
# [1422/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=74.52%, avg_pnl=0.37%, total_return=57.99%, max_dd=5.29%, avg_dd=1.08%, median_dd=0.71%
# Scanning for divergences...
# Found 1382 bars with divergences
# Running strategy...
#
# [1423/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=146, win_rate=75.34%, avg_pnl=0.33%, total_return=48.82%, max_dd=5.29%, avg_dd=1.10%, median_dd=0.73%
# Scanning for divergences...
# Found 1382 bars with divergences
# Running strategy...
#
# [1424/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=146, win_rate=75.34%, avg_pnl=0.33%, total_return=48.82%, max_dd=5.29%, avg_dd=1.10%, median_dd=0.73%
# Scanning for divergences...
# Found 1673 bars with divergences
# Running strategy...
#
# [1425/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=177, win_rate=74.01%, avg_pnl=0.34%, total_return=59.90%, max_dd=5.84%, avg_dd=1.06%, median_dd=0.68%
# Scanning for divergences...
# Found 1707 bars with divergences
# Running strategy...
#
# [1426/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=186, win_rate=74.19%, avg_pnl=0.34%, total_return=63.95%, max_dd=7.92%, avg_dd=1.06%, median_dd=0.69%
# Scanning for divergences...
# Found 1636 bars with divergences
# Running strategy...
#
# [1427/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=172, win_rate=73.84%, avg_pnl=0.33%, total_return=56.88%, max_dd=5.84%, avg_dd=1.06%, median_dd=0.68%
# Scanning for divergences...
# Found 1636 bars with divergences
# Running strategy...
#
# [1428/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=172, win_rate=73.84%, avg_pnl=0.33%, total_return=56.88%, max_dd=5.84%, avg_dd=1.06%, median_dd=0.68%
# Scanning for divergences...
# Found 1594 bars with divergences
# Running strategy...
#
# [1429/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=163, win_rate=74.85%, avg_pnl=0.31%, total_return=51.07%, max_dd=5.29%, avg_dd=1.08%, median_dd=0.68%
# Scanning for divergences...
# Found 1629 bars with divergences
# Running strategy...
#
# [1430/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=173, win_rate=75.72%, avg_pnl=0.35%, total_return=60.12%, max_dd=7.92%, avg_dd=1.07%, median_dd=0.68%
# Scanning for divergences...
# Found 1552 bars with divergences
# Running strategy...
#
# [1431/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=158, win_rate=74.68%, avg_pnl=0.30%, total_return=47.33%, max_dd=5.29%, avg_dd=1.09%, median_dd=0.68%
# Scanning for divergences...
# Found 1552 bars with divergences
# Running strategy...
#
# [1432/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=158, win_rate=74.68%, avg_pnl=0.30%, total_return=47.33%, max_dd=5.29%, avg_dd=1.09%, median_dd=0.68%
# Scanning for divergences...
# Found 1521 bars with divergences
# Running strategy...
#
# [1433/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=157, win_rate=74.52%, avg_pnl=0.36%, total_return=55.87%, max_dd=5.84%, avg_dd=1.12%, median_dd=0.78%
# Scanning for divergences...
# Found 1563 bars with divergences
# Running strategy...
#
# [1434/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=164, win_rate=73.78%, avg_pnl=0.37%, total_return=61.09%, max_dd=5.84%, avg_dd=1.10%, median_dd=0.75%
# Scanning for divergences...
# Found 1477 bars with divergences
# Running strategy...
#
# [1435/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=74.17%, avg_pnl=0.36%, total_return=54.27%, max_dd=5.84%, avg_dd=1.13%, median_dd=0.80%
# Scanning for divergences...
# Found 1477 bars with divergences
# Running strategy...
#
# [1436/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=74.17%, avg_pnl=0.36%, total_return=54.27%, max_dd=5.84%, avg_dd=1.13%, median_dd=0.80%
# Scanning for divergences...
# Found 1432 bars with divergences
# Running strategy...
#
# [1437/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=145, win_rate=75.17%, avg_pnl=0.35%, total_return=50.59%, max_dd=5.29%, avg_dd=1.12%, median_dd=0.73%
# Scanning for divergences...
# Found 1474 bars with divergences
# Running strategy...
#
# [1438/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=152, win_rate=74.34%, avg_pnl=0.39%, total_return=59.16%, max_dd=5.29%, avg_dd=1.09%, median_dd=0.71%
# Scanning for divergences...
# Found 1381 bars with divergences
# Running strategy...
#
# [1439/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=74.10%, avg_pnl=0.34%, total_return=47.14%, max_dd=5.29%, avg_dd=1.13%, median_dd=0.78%
# Scanning for divergences...
# Found 1381 bars with divergences
# Running strategy...
#
# [1440/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=74.10%, avg_pnl=0.34%, total_return=47.14%, max_dd=5.29%, avg_dd=1.13%, median_dd=0.78%
# Scanning for divergences...
# Found 1662 bars with divergences
# Running strategy...
#
# [1441/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=172, win_rate=74.42%, avg_pnl=0.34%, total_return=58.38%, max_dd=6.02%, avg_dd=1.06%, median_dd=0.66%
# Scanning for divergences...
# Found 1693 bars with divergences
# Running strategy...
#
# [1442/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=182, win_rate=74.73%, avg_pnl=0.36%, total_return=65.73%, max_dd=7.92%, avg_dd=1.05%, median_dd=0.67%
# Scanning for divergences...
# Found 1625 bars with divergences
# Running strategy...
#
# [1443/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=74.85%, avg_pnl=0.34%, total_return=57.26%, max_dd=6.02%, avg_dd=1.06%, median_dd=0.66%
# Scanning for divergences...
# Found 1625 bars with divergences
# Running strategy...
#
# [1444/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=74.85%, avg_pnl=0.34%, total_return=57.26%, max_dd=6.02%, avg_dd=1.06%, median_dd=0.66%
# Scanning for divergences...
# Found 1588 bars with divergences
# Running strategy...
#
# [1445/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=156, win_rate=74.36%, avg_pnl=0.33%, total_return=50.72%, max_dd=6.02%, avg_dd=1.09%, median_dd=0.67%
# Scanning for divergences...
# Found 1619 bars with divergences
# Running strategy...
#
# [1446/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=75.45%, avg_pnl=0.36%, total_return=60.70%, max_dd=7.92%, avg_dd=1.06%, median_dd=0.67%
# Scanning for divergences...
# Found 1547 bars with divergences
# Running strategy...
#
# [1447/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=152, win_rate=75.00%, avg_pnl=0.33%, total_return=50.08%, max_dd=6.02%, avg_dd=1.08%, median_dd=0.67%
# Scanning for divergences...
# Found 1547 bars with divergences
# Running strategy...
#
# [1448/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=152, win_rate=75.00%, avg_pnl=0.33%, total_return=50.08%, max_dd=6.02%, avg_dd=1.08%, median_dd=0.67%
# Scanning for divergences...
# Found 1507 bars with divergences
# Running strategy...
#
# [1449/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 10, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 10, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=152, win_rate=74.34%, avg_pnl=0.34%, total_return=52.23%, max_dd=6.02%, avg_dd=1.13%, median_dd=0.73%
# Scanning for divergences...
# Found 1546 bars with divergences
# Running strategy...
#
# [1450/2048]
# ...
# Found 1617 bars with divergences
# Running strategy...
#
# [2022/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=162, win_rate=74.69%, avg_pnl=0.32%, total_return=52.38%, max_dd=7.92%, avg_dd=1.10%, median_dd=0.66%
# Scanning for divergences...
# Found 1546 bars with divergences
# Running strategy...
#
# [2023/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=148, win_rate=74.32%, avg_pnl=0.29%, total_return=43.30%, max_dd=6.02%, avg_dd=1.12%, median_dd=0.65%
# Scanning for divergences...
# Found 1546 bars with divergences
# Running strategy...
#
# [2024/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=148, win_rate=74.32%, avg_pnl=0.29%, total_return=43.30%, max_dd=6.02%, avg_dd=1.12%, median_dd=0.65%
# Scanning for divergences...
# Found 1527 bars with divergences
# Running strategy...
#
# [2025/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=153, win_rate=75.82%, avg_pnl=0.33%, total_return=51.05%, max_dd=6.02%, avg_dd=1.11%, median_dd=0.67%
# Scanning for divergences...
# Found 1566 bars with divergences
# Running strategy...
#
# [2026/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=158, win_rate=75.95%, avg_pnl=0.34%, total_return=54.44%, max_dd=6.55%, avg_dd=1.09%, median_dd=0.67%
# Scanning for divergences...
# Found 1488 bars with divergences
# Running strategy...
#
# [2027/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=76.16%, avg_pnl=0.33%, total_return=49.17%, max_dd=6.02%, avg_dd=1.11%, median_dd=0.67%
# Scanning for divergences...
# Found 1488 bars with divergences
# Running strategy...
#
# [2028/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=76.16%, avg_pnl=0.33%, total_return=49.17%, max_dd=6.02%, avg_dd=1.11%, median_dd=0.67%
# Scanning for divergences...
# Found 1420 bars with divergences
# Running strategy...
#
# [2029/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=73.88%, avg_pnl=0.30%, total_return=40.69%, max_dd=6.02%, avg_dd=1.18%, median_dd=0.68%
# Scanning for divergences...
# Found 1460 bars with divergences
# Running strategy...
#
# [2030/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=140, win_rate=73.57%, avg_pnl=0.33%, total_return=46.72%, max_dd=6.02%, avg_dd=1.14%, median_dd=0.68%
# Scanning for divergences...
# Found 1373 bars with divergences
# Running strategy...
#
# [2031/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=130, win_rate=73.85%, avg_pnl=0.31%, total_return=40.56%, max_dd=6.02%, avg_dd=1.17%, median_dd=0.70%
# Scanning for divergences...
# Found 1373 bars with divergences
# Running strategy...
#
# [2032/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=130, win_rate=73.85%, avg_pnl=0.31%, total_return=40.56%, max_dd=6.02%, avg_dd=1.17%, median_dd=0.70%
# Scanning for divergences...
# Found 1664 bars with divergences
# Running strategy...
#
# [2033/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=170, win_rate=76.47%, avg_pnl=0.33%, total_return=55.87%, max_dd=8.73%, avg_dd=1.12%, median_dd=0.66%
# Scanning for divergences...
# Found 1700 bars with divergences
# Running strategy...
#
# [2034/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=173, win_rate=76.88%, avg_pnl=0.33%, total_return=56.39%, max_dd=8.73%, avg_dd=1.11%, median_dd=0.67%
# Scanning for divergences...
# Found 1632 bars with divergences
# Running strategy...
#
# [2035/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=76.05%, avg_pnl=0.31%, total_return=52.33%, max_dd=8.73%, avg_dd=1.13%, median_dd=0.67%
# Scanning for divergences...
# Found 1632 bars with divergences
# Running strategy...
#
# [2036/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=167, win_rate=76.05%, avg_pnl=0.31%, total_return=52.33%, max_dd=8.73%, avg_dd=1.13%, median_dd=0.67%
# Scanning for divergences...
# Found 1581 bars with divergences
# Running strategy...
#
# [2037/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=75.50%, avg_pnl=0.31%, total_return=47.10%, max_dd=8.73%, avg_dd=1.15%, median_dd=0.67%
# Scanning for divergences...
# Found 1617 bars with divergences
# Running strategy...
#
# [2038/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=160, win_rate=76.88%, avg_pnl=0.32%, total_return=51.46%, max_dd=8.73%, avg_dd=1.14%, median_dd=0.66%
# Scanning for divergences...
# Found 1543 bars with divergences
# Running strategy...
#
# [2039/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=146, win_rate=75.34%, avg_pnl=0.30%, total_return=43.68%, max_dd=8.73%, avg_dd=1.15%, median_dd=0.66%
# Scanning for divergences...
# Found 1543 bars with divergences
# Running strategy...
#
# [2040/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': True, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=146, win_rate=75.34%, avg_pnl=0.30%, total_return=43.68%, max_dd=8.73%, avg_dd=1.15%, median_dd=0.66%
# Scanning for divergences...
# Found 1521 bars with divergences
# Running strategy...
#
# [2041/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=151, win_rate=75.50%, avg_pnl=0.33%, total_return=49.51%, max_dd=8.73%, avg_dd=1.14%, median_dd=0.67%
# Scanning for divergences...
# Found 1563 bars with divergences
# Running strategy...
#
# [2042/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=155, win_rate=76.13%, avg_pnl=0.32%, total_return=49.82%, max_dd=8.73%, avg_dd=1.14%, median_dd=0.67%
# Scanning for divergences...
# Found 1483 bars with divergences
# Running strategy...
#
# [2043/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=149, win_rate=75.17%, avg_pnl=0.32%, total_return=47.41%, max_dd=8.73%, avg_dd=1.15%, median_dd=0.67%
# Scanning for divergences...
# Found 1483 bars with divergences
# Running strategy...
#
# [2044/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': True, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=149, win_rate=75.17%, avg_pnl=0.32%, total_return=47.41%, max_dd=8.73%, avg_dd=1.15%, median_dd=0.67%
# Scanning for divergences...
# Found 1414 bars with divergences
# Running strategy...
#
# [2045/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=134, win_rate=75.37%, avg_pnl=0.32%, total_return=42.43%, max_dd=8.73%, avg_dd=1.19%, median_dd=0.67%
# Scanning for divergences...
# Found 1458 bars with divergences
# Running strategy...
#
# [2046/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': True, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=139, win_rate=74.82%, avg_pnl=0.34%, total_return=47.81%, max_dd=8.73%, avg_dd=1.16%, median_dd=0.68%
# Scanning for divergences...
# Found 1369 bars with divergences
# Running strategy...
#
# [2047/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=128, win_rate=73.44%, avg_pnl=0.31%, total_return=39.73%, max_dd=8.73%, avg_dd=1.21%, median_dd=0.72%
# Scanning for divergences...
# Found 1369 bars with divergences
# Running strategy...
#
# [2048/2048]
#   params : {'cci_window': 10, 'cmf_window': 21, 'mfi_window': 20, 'mom_window': 10, 'pivot_prd': 5, 'rsi_window': 21, 'stoch_smooth': 3, 'stoch_window': 14, 'use_cmf': False, 'use_mfi': False, 'use_vwmacd': False, 'vwma_fast': 12, 'vwma_slow': 26}
#   metrics: trades=128, win_rate=73.44%, avg_pnl=0.31%, total_return=39.73%, max_dd=8.73%, avg_dd=1.21%, median_dd=0.72%
#   💾 checkpoint saved: divergence_param_grid_results_partial.csv
#
# ===============================================
# 🏆 TOP 10 PARAMETER SETS (by total_return, win_rate, low max_dd)
# ===============================================
#    cci_window  cmf_window  mfi_window  mom_window  pivot_prd  rsi_window  \
# 0          10          21          10          10          5          10
# 1          10          21          20          10          5          10
# 2          10          21          20           5          5          10
# 3          10          21          10          10          5          10
# 4          10          21          10          10          5           7
# 5          10          21          20          10          5           7
# 6          10          21          10          10          5           7
# 7          10          21          20           5          5           7
# 8          10          21          20          10          5           7
# 9          10          21          20          10          5          14
#
#    stoch_smooth  stoch_window  use_cmf  use_mfi  use_vwmacd  vwma_fast  \
# 0             3             9     True     True        True         12
# 1             3             9     True     True        True         12
# 2             3             9     True     True        True         12
# 3             3            14     True     True        True         12
# 4             3            14     True     True        True         12
# 5             3             9     True     True        True         12
# 6             3             9     True     True        True         12
# 7             3             9     True     True        True         12
# 8             3            14     True     True        True         12
# 9             3             9     True     True        True         12
#
#    vwma_slow  total_trades   win_rate   avg_pnl  total_return    max_dd  \
# 0         26           182  74.725275  0.361176     65.734072  7.921587
# 1         26           179  75.418994  0.364849     65.307973  7.921587
# 2         26           184  75.000000  0.352515     64.862785  7.921587
# 3         26           181  75.690608  0.357010     64.618773  7.921587
# 4         26           186  74.193548  0.343793     63.945545  7.921587
# 5         26           189  75.132275  0.337539     63.794852  7.921587
# 6         26           190  74.210526  0.334091     63.477310  7.921587
# 7         26           190  75.263158  0.333564     63.377217  7.921587
# 8         26           185  76.756757  0.341688     63.212280  7.921587
# 9         26           176  75.000000  0.354904     62.463113  7.921587
#
#      avg_dd  median_dd
# 0  1.047129   0.669551
# 1  1.034779   0.665759
# 2  1.004323   0.666091
# 3  1.075260   0.684252
# 4  1.064484   0.692150
# 5  1.023702   0.658821
# 6  1.050387   0.678797
# 7  1.006288   0.662290
# 8  1.047249   0.665759
# 9  1.072285   0.666091
#
# 📁 Full grid-search results saved to: divergence_param_grid_results.csv
#
# 🔥 BEST PARAMS FOUND:
#   rsi_window: 10
#   stoch_window: 9
#   stoch_smooth: 3
#   mom_window: 10
#   cci_window: 10
#   mfi_window: 10
#   vwma_fast: 12
#   vwma_slow: 26
#   cmf_window: 21
#   pivot_prd: 5
#   use_vwmacd: True
#   use_cmf: True
#   use_mfi: True
# Scanning for divergences...
# Found 1693 bars with divergences
# Running strategy...
#
# Best metrics on full sample:
# {'total_trades': 182, 'win_rate': 74.72527472527473, 'avg_pnl': 0.361176218605176, 'total_return': 65.73407178614204, 'max_dd': 7.92158674592103, 'avg_dd': 1.0471285922917735, 'median_dd': 0.6695505542646334}
