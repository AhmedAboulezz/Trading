# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAboulezz/Trading/blob/main/Divergence_Strategy_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install pandas numpy matplotlib plotly scipy ta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.signal import argrelextrema
import ta
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

#------------------------------------------------------------------------------
# CONFIGURATION PARAMETERS
#------------------------------------------------------------------------------

class Config:
    # Pivot settings
    prd = 5  # Pivot Period
    source = "Close"  # Source for Pivot Points: "Close" or "High/Low"

    # Divergence settings
    searchdiv = "Regular"  # "Regular", "Hidden", or "Regular/Hidden"
    showlimit = 1  # Minimum Number of Divergence (any)
    maxpp = 10  # Maximum Pivot Points to Check
    maxbars = 100  # Maximum Bars to Check
    dontconfirm = False  # Don't Wait for Confirmation

    # Quality filter
    minPosDivForEntry = 2  # Min # of Positive Divergence for Valid Long
    minNegDivForExit = 1   # Min # of Negative Divergence for Exit

    # Entry delay and drawdown
    delayBars = 0  # Delay For Entry (Bars)
    useDrawdown = False  # Use % Drawdown Before Entry
    drawdownPerc = 1.0  # Drawdown %

    # Indicator selection (all enabled by default)
    calcmacd = True
    calcmacda = True
    calcrsi = True
    calcstoc = True
    calccci = True
    calcmom = True
    calcobv = False
    calcvwmacd = True
    calccmf = True
    calcmfi = True

    # Backtest settings
    initial_capital = 10000
    position_size = 1.0  # Use 100% of capital per trade

config = Config()

#------------------------------------------------------------------------------
# DATA LOADING
#------------------------------------------------------------------------------

def load_data_from_csv(filepath):
    """Load OHLC data from CSV file"""
    print(f"Loading data from {filepath}...")

    # Read CSV
    df = pd.read_csv(filepath)

    # Normalize column names to lowercase
    df.columns = [col.lower().strip() for col in df.columns]

    # Parse time column
    df['time'] = pd.to_datetime(df['time'])
    df.set_index('time', inplace=True)

    # Ensure we have required columns
    required_cols = ['open', 'high', 'low', 'close']
    for col in required_cols:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")

    # Add volume if not present (needed for some indicators)
    if 'volume' not in df.columns:
        df['volume'] = 1000000  # Default volume
        print("Warning: No volume column found, using default values")

    print(f"Loaded {len(df)} bars from {df.index[0]} to {df.index[-1]}")
    return df

#------------------------------------------------------------------------------
# TECHNICAL INDICATORS
#------------------------------------------------------------------------------

def calculate_indicators(df):
    df = df.copy()

    close = df["close"].astype(float)
    high  = df["high"].astype(float)
    low   = df["low"].astype(float)
    vol   = df["volume"].astype(float)  # أو "volume" حسب اسم العمود عندك

    # ------------------------------------------------------------------
    # RSI, MACD, VW-MACD, CMF, ... خليهـم زي ما أنت عاملهم لو متطابقين
    # ------------------------------------------------------------------
    import ta

    # RSI(14) - مطابق لـ ta.rsi(close, 14)
    df["rsi"] = ta.momentum.RSIIndicator(close=close, window=14).rsi()

    # MACD(12,26,9)
    macd_ind = ta.trend.MACD(close=close, window_slow=26,
                             window_fast=12, window_sign=9)
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # Momentum(10)
    df["momentum"] = close - close.shift(10)

    # VW-MACD = VWMA(12) - VWMA(26) (نفس Pine)
    vwma_fast = (close * vol).rolling(12).sum() / vol.rolling(12).sum()
    vwma_slow = (close * vol).rolling(26).sum() / vol.rolling(26).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # CMF(21) زي Pine
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high=high, low=low, close=close, volume=vol, window=21
    ).chaikin_money_flow()

    # ==============================================================
    # ✅ 1) Stochastic(14,3) مطابق لـ Stochastic(14,3) في Pine
    # ==============================================================
    lowest_low_14  = low.rolling(window=14, min_periods=14).min()
    highest_high_14 = high.rolling(window=14, min_periods=14).max()

    stoch_k = 100.0 * (close - lowest_low_14) / (highest_high_14 - lowest_low_14)
    df["stoch"] = stoch_k.rolling(window=3, min_periods=3).mean()

    # ==============================================================
    # ✅ 2) CCI(10) باستخدام الـ close (نفس Pine في csv)
    # ==============================================================
    n_cci = 10
    sma_close = close.rolling(n_cci, min_periods=n_cci).mean()

    # mean absolute deviation من الـ sma على الـ close
    mad_close = close.rolling(n_cci, min_periods=n_cci).apply(
        lambda x: np.mean(np.abs(x - x.mean())),
        raw=True
    )

    df["cci"] = (close - sma_close) / (0.015 * mad_close)

    # ==============================================================
    # ✅ 3) MFI(14) باستخدام الـ close كـ price
    # ==============================================================
    n_mfi = 14
    price = close

    raw_mf = price * vol
    pos_mf = [0.0]
    neg_mf = [0.0]

    for i in range(1, len(df)):
        if price.iloc[i] > price.iloc[i - 1]:
            pos_mf.append(raw_mf.iloc[i])
            neg_mf.append(0.0)
        elif price.iloc[i] < price.iloc[i - 1]:
            pos_mf.append(0.0)
            neg_mf.append(raw_mf.iloc[i])
        else:
            pos_mf.append(0.0)
            neg_mf.append(0.0)

    pos_mf = pd.Series(pos_mf, index=df.index)
    neg_mf = pd.Series(neg_mf, index=df.index)

    pos_roll = pos_mf.rolling(n_mfi, min_periods=n_mfi).sum()
    neg_roll = neg_mf.rolling(n_mfi, min_periods=n_mfi).sum()

    mfi = 100.0 * (pos_roll / (pos_roll + neg_roll))
    df["mfi"] = mfi

    # 9) OBV (هنسيبه زي ما انت عامل)
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i-1]:
            obv_values.append(obv_values[-1] + vol.iloc[i])
        elif close.iloc[i] < close.iloc[i-1]:
            obv_values.append(obv_values[-1] - vol.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df['obv'] = obv_values

    df = df.fillna(method='bfill').fillna(method='ffill')

    # ==============================================================
    # OBV زي ما تحب (وانت أصلاً قلت سيبه)
    # ==============================================================
    # ممكن تخليه زي Pine لو حابب لاحقًا، بس مش ضروري دلوقتي

    return df
#------------------------------------------------------------------------------
# PIVOT POINT DETECTION
#------------------------------------------------------------------------------

def find_pivots(df, period):
    """Find pivot highs and pivot lows"""
    print(f"Finding pivot points with period {period}...")

    if config.source == "Close":
        high_series = df['close']
        low_series = df['close']
    else:
        high_series = df['high']
        low_series = df['low']

    # Initialize pivot columns
    df['pivot_high'] = np.nan
    df['pivot_high_bar'] = np.nan
    df['pivot_low'] = np.nan
    df['pivot_low_bar'] = np.nan

    for i in range(period, len(df) - period):
        # Check pivot high
        is_pivot_high = True
        for j in range(1, period + 1):
            if high_series.iloc[i] <= high_series.iloc[i - j] or \
               high_series.iloc[i] <= high_series.iloc[i + j]:
                is_pivot_high = False
                break

        if is_pivot_high:
            df.iloc[i, df.columns.get_loc('pivot_high')] = high_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_high_bar')] = i

        # Check pivot low
        is_pivot_low = True
        for j in range(1, period + 1):
            if low_series.iloc[i] >= low_series.iloc[i - j] or \
               low_series.iloc[i] >= low_series.iloc[i + j]:
                is_pivot_low = False
                break

        if is_pivot_low:
            df.iloc[i, df.columns.get_loc('pivot_low')] = low_series.iloc[i]
            df.iloc[i, df.columns.get_loc('pivot_low_bar')] = i

    num_highs = df['pivot_high'].notna().sum()
    num_lows = df['pivot_low'].notna().sum()
    print(f"Found {num_highs} pivot highs and {num_lows} pivot lows")

    return df

#------------------------------------------------------------------------------
# DIVERGENCE DETECTION
#------------------------------------------------------------------------------

def detect_divergence(df, indicator_name, bar_idx, pivot_positions, pivot_values,
                     is_bullish, is_regular):
    """
    Detect divergence at a specific bar
    Returns: length of divergence if found, else 0
    """

    if bar_idx < config.prd:
        return 0

    startpoint = 0 if config.dontconfirm else 1

    if config.source == "Close":
        price_series = df['close'].values
    else:
        price_series = df['low'].values if is_bullish else df['high'].values

    indicator_series = df[indicator_name].values

    # Check confirmation condition
    if not config.dontconfirm:
        if is_bullish:
            if not (indicator_series[bar_idx] > indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] > df['close'].values[bar_idx - 1]):
                return 0
        else:
            if not (indicator_series[bar_idx] < indicator_series[bar_idx - 1] or
                   df['close'].values[bar_idx] < df['close'].values[bar_idx - 1]):
                return 0

    # Check each pivot
    for pivot_idx in range(min(config.maxpp, len(pivot_positions))):
        if pivot_idx >= len(pivot_positions) or np.isnan(pivot_positions[pivot_idx]):
            break

        pivot_bar = int(pivot_positions[pivot_idx])
        length = bar_idx - pivot_bar

        if length > config.maxbars:
            break

        if length > 5:
            # Check divergence conditions
            if is_bullish and is_regular:
                # Positive Regular: indicator makes higher low, price makes lower low
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])
            elif is_bullish and not is_regular:
                # Positive Hidden: indicator makes lower low, price makes higher low
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            elif not is_bullish and is_regular:
                # Negative Regular: indicator makes lower high, price makes higher high
                div_condition = (indicator_series[bar_idx - startpoint] < indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] > pivot_values[pivot_idx])
            else:
                # Negative Hidden: indicator makes higher high, price makes lower high
                div_condition = (indicator_series[bar_idx - startpoint] > indicator_series[pivot_bar] and
                               price_series[bar_idx - startpoint] < pivot_values[pivot_idx])

            if div_condition:
                # Check if line is valid (no crossings)
                slope1 = (indicator_series[bar_idx - startpoint] - indicator_series[pivot_bar]) / length
                slope2 = (df['close'].values[bar_idx - startpoint] - df['close'].values[pivot_bar]) / length

                virtual_line1 = indicator_series[bar_idx - startpoint]
                virtual_line2 = df['close'].values[bar_idx - startpoint]

                valid = True
                for y in range(1 + startpoint, length):
                    virtual_line1 -= slope1
                    virtual_line2 -= slope2

                    check_idx = bar_idx - y
                    if is_bullish:
                        if indicator_series[check_idx] < virtual_line1 or \
                           df['close'].values[check_idx] < virtual_line2:
                            valid = False
                            break
                    else:
                        if indicator_series[check_idx] > virtual_line1 or \
                           df['close'].values[check_idx] > virtual_line2:
                            valid = False
                            break

                if valid:
                    return length

    return 0

from collections import deque
import numpy as np

def scan_all_divergences(df):
    """Scan for all divergences across all indicators (optimized arrays)"""
    print("Scanning for divergences...")

    n = len(df)

    # 1) جهّز قائمة المؤشرات اللي بنشتغل عليها (زي ما هي)
    indicators_to_check = []
    if config.calcmacd:
        indicators_to_check.append('macd')
    if config.calcmacda:
        indicators_to_check.append('macd_hist')
    if config.calcrsi:
        indicators_to_check.append('rsi')
    if config.calcstoc:
        indicators_to_check.append('stoch')
    if config.calccci:
        indicators_to_check.append('cci')
    if config.calcmom:
        indicators_to_check.append('momentum')
    if config.calcobv:
        indicators_to_check.append('obv')
    if config.calcvwmacd:
        indicators_to_check.append('vwmacd')
    if config.calccmf:
        indicators_to_check.append('cmf')
    if config.calcmfi:
        indicators_to_check.append('mfi')

    # 2) حضّر أعمدة الديفرجنس في Arrays بدل DataFrame مباشر
    div_cols = []
    div_arrays = {}
    for ind in indicators_to_check:
        for div_type in ['pos_reg', 'neg_reg', 'pos_hid', 'neg_hid']:
            col_name = f'{ind}_{div_type}'
            div_cols.append(col_name)
            div_arrays[col_name] = np.zeros(n, dtype=np.int32)

    # 3) حوّل الـ series المهمة إلى Arrays مرّة واحدة
    close_arr = df['close'].values.astype(float)
    low_arr   = df['low'].values.astype(float)
    high_arr  = df['high'].values.astype(float)

    ind_arrays = {
        ind: df[ind].values.astype(float)
        for ind in indicators_to_check
    }

    # 4) Arrays للـ pivots عشان نستخدمها مع deque
    pivot_high_vals_all = df['pivot_high'].values.astype(float)
    pivot_low_vals_all  = df['pivot_low'].values.astype(float)

    recent_high_bars = deque()
    recent_high_vals = deque()
    recent_low_bars  = deque()
    recent_low_vals  = deque()

    # ------------------------------------------------------------------
    # 👇 Helper داخلي: نفس detect_divergence بس شغال على Arrays
    # ------------------------------------------------------------------
    def detect_with_arrays(indicator_series, bar_idx,
                           pivot_positions, pivot_values,
                           is_bullish, is_regular):
        """نفس منطق detect_divergence بالظبط لكن باستخدام arrays فقط"""
        if bar_idx < config.prd:
            return 0

        dontconfirm = config.dontconfirm
        startpoint = 0 if dontconfirm else 1

        # اختيار الـ price series بناءً على الـ source
        if config.source == "Close":
            price_series = close_arr
        else:
            price_series = low_arr if is_bullish else high_arr

        # شرط الـ confirmation زي ما هو
        if not dontconfirm:
            if is_bullish:
                if not (
                    indicator_series[bar_idx] > indicator_series[bar_idx - 1] or
                    close_arr[bar_idx] > close_arr[bar_idx - 1]
                ):
                    return 0
            else:
                if not (
                    indicator_series[bar_idx] < indicator_series[bar_idx - 1] or
                    close_arr[bar_idx] < close_arr[bar_idx - 1]
                ):
                    return 0

        maxpp = config.maxpp
        maxbars = config.maxbars

        m = len(pivot_positions)

        # لوب على الـ pivots (نفس الفكرة)
        for pivot_idx in range(min(maxpp, m)):
            pivot_bar = pivot_positions[pivot_idx]
            length = bar_idx - pivot_bar

            if length > maxbars:
                break
            if length <= 5:
                continue

            pivot_price = pivot_values[pivot_idx]

            ind_curr   = indicator_series[bar_idx - startpoint]
            ind_pivot  = indicator_series[pivot_bar]
            price_curr = price_series[bar_idx - startpoint]

            # نفس شروط الديفرجنس بالظبط
            if is_bullish and is_regular:
                # Positive Regular
                div_condition = (
                    ind_curr > ind_pivot and
                    price_curr < pivot_price
                )
            elif is_bullish and not is_regular:
                # Positive Hidden
                div_condition = (
                    ind_curr < ind_pivot and
                    price_curr > pivot_price
                )
            elif (not is_bullish) and is_regular:
                # Negative Regular
                div_condition = (
                    ind_curr < ind_pivot and
                    price_curr > pivot_price
                )
            else:
                # Negative Hidden
                div_condition = (
                    ind_curr > ind_pivot and
                    price_curr < pivot_price
                )

            if not div_condition:
                continue

            # خطّين الـ virtual line – نفس الكود القديم
            slope1 = (ind_curr - ind_pivot) / length
            slope2 = (close_arr[bar_idx - startpoint] - close_arr[pivot_bar]) / length

            virtual_line1 = ind_curr
            virtual_line2 = close_arr[bar_idx - startpoint]

            valid = True
            for y in range(1 + startpoint, length):
                virtual_line1 -= slope1
                virtual_line2 -= slope2
                check_idx = bar_idx - y

                if is_bullish:
                    if (indicator_series[check_idx] < virtual_line1 or
                        close_arr[check_idx] < virtual_line2):
                        valid = False
                        break
                else:
                    if (indicator_series[check_idx] > virtual_line1 or
                        close_arr[check_idx] > virtual_line2):
                        valid = False
                        break

            if valid:
                return length

        return 0

    # ------------------------------------------------------------------
    # 5) اللوب الرئيسي على البارات + استخدام deque للـ pivots
    # ------------------------------------------------------------------
    for i in range(n):
        prev = i - 1
        if prev >= 0:
            ph = pivot_high_vals_all[prev]
            if not np.isnan(ph):
                recent_high_bars.appendleft(prev)
                recent_high_vals.appendleft(ph)

            pl = pivot_low_vals_all[prev]
            if not np.isnan(pl):
                recent_low_bars.appendleft(prev)
                recent_low_vals.appendleft(pl)

        # شيل أي pivots قديمة أقدم من maxbars
        cutoff = i - config.maxbars
        while recent_high_bars and recent_high_bars[-1] < cutoff:
            recent_high_bars.pop()
            recent_high_vals.pop()
        while recent_low_bars and recent_low_bars[-1] < cutoff:
            recent_low_bars.pop()
            recent_low_vals.pop()

        if i < config.prd + 10:
            continue

        pivot_high_bars = list(recent_high_bars)
        pivot_high_vals = list(recent_high_vals)
        pivot_low_bars  = list(recent_low_bars)
        pivot_low_vals  = list(recent_low_vals)

        has_highs = len(pivot_high_bars) > 0
        has_lows  = len(pivot_low_bars) > 0

        # 6) لوب على المؤشرات – بس على الـ arrays
        for ind in indicators_to_check:
            ind_arr = ind_arrays[ind]

            if np.isnan(ind_arr[i]):
                continue

            # Positive Regular
            if config.searchdiv in ["Regular", "Regular/Hidden"] and has_lows:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_low_bars, pivot_low_vals,
                    is_bullish=True, is_regular=True
                )
                if div_len > 0:
                    div_arrays[f'{ind}_pos_reg'][i] = div_len

            # Negative Regular
            if config.searchdiv in ["Regular", "Regular/Hidden"] and has_highs:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_high_bars, pivot_high_vals,
                    is_bullish=False, is_regular=True
                )
                if div_len > 0:
                    div_arrays[f'{ind}_neg_reg'][i] = div_len

            # Positive Hidden
            if config.searchdiv in ["Hidden", "Regular/Hidden"] and has_lows:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_low_bars, pivot_low_vals,
                    is_bullish=True, is_regular=False
                )
                if div_len > 0:
                    div_arrays[f'{ind}_pos_hid'][i] = div_len

            # Negative Hidden
            if config.searchdiv in ["Hidden", "Regular/Hidden"] and has_highs:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_high_bars, pivot_high_vals,
                    is_bullish=False, is_regular=False
                )
                if div_len > 0:
                    div_arrays[f'{ind}_neg_hid'][i] = div_len

    # 7) ارجع النتايج للـ DataFrame زي ما كانت
    for col_name in div_cols:
        df[col_name] = div_arrays[col_name]

    # Count total divergences
    df['total_divergences'] = 0
    for col in div_cols:
        df['total_divergences'] += (df[col] > 0).astype(int)

    # Filter by minimum divergences
    df.loc[df['total_divergences'] < config.showlimit, div_cols] = 0

    # Count positive and negative divergences
    df['pos_div_count'] = 0
    df['neg_div_count'] = 0
    for col in div_cols:
        if 'pos_' in col:
            df['pos_div_count'] += (df[col] > 0).astype(int)
        else:
            df['neg_div_count'] += (df[col] > 0).astype(int)

    total_divs = (df['total_divergences'] > 0).sum()
    print(f"Found {total_divs} bars with divergences")

    return df

#------------------------------------------------------------------------------
# TRADING STRATEGY
#------------------------------------------------------------------------------

from collections import deque
import numpy as np

def scan_all_divergences(df):
    """Scan for all divergences across all indicators (optimized arrays)"""
    print("Scanning for divergences...")

    n = len(df)

    # 1) جهّز قائمة المؤشرات اللي بنشتغل عليها (زي ما هي)
    indicators_to_check = []
    if config.calcmacd:
        indicators_to_check.append('macd')
    if config.calcmacda:
        indicators_to_check.append('macd_hist')
    if config.calcrsi:
        indicators_to_check.append('rsi')
    if config.calcstoc:
        indicators_to_check.append('stoch')
    if config.calccci:
        indicators_to_check.append('cci')
    if config.calcmom:
        indicators_to_check.append('momentum')
    if config.calcobv:
        indicators_to_check.append('obv')
    if config.calcvwmacd:
        indicators_to_check.append('vwmacd')
    if config.calccmf:
        indicators_to_check.append('cmf')
    if config.calcmfi:
        indicators_to_check.append('mfi')

    # 2) حضّر أعمدة الديفرجنس في Arrays بدل DataFrame مباشر
    div_cols = []
    div_arrays = {}
    for ind in indicators_to_check:
        for div_type in ['pos_reg', 'neg_reg', 'pos_hid', 'neg_hid']:
            col_name = f'{ind}_{div_type}'
            div_cols.append(col_name)
            div_arrays[col_name] = np.zeros(n, dtype=np.int32)

    # 3) حوّل الـ series المهمة إلى Arrays مرّة واحدة
    close_arr = df['close'].values.astype(float)
    low_arr   = df['low'].values.astype(float)
    high_arr  = df['high'].values.astype(float)

    ind_arrays = {
        ind: df[ind].values.astype(float)
        for ind in indicators_to_check
    }

    # 4) Arrays للـ pivots عشان نستخدمها مع deque
    pivot_high_vals_all = df['pivot_high'].values.astype(float)
    pivot_low_vals_all  = df['pivot_low'].values.astype(float)

    recent_high_bars = deque()
    recent_high_vals = deque()
    recent_low_bars  = deque()
    recent_low_vals  = deque()

    # ------------------------------------------------------------------
    # 👇 Helper داخلي: نفس detect_divergence بس شغال على Arrays
    # ------------------------------------------------------------------
    def detect_with_arrays(indicator_series, bar_idx,
                           pivot_positions, pivot_values,
                           is_bullish, is_regular):
        """نفس منطق detect_divergence بالظبط لكن باستخدام arrays فقط"""
        if bar_idx < config.prd:
            return 0

        dontconfirm = config.dontconfirm
        startpoint = 0 if dontconfirm else 1

        # اختيار الـ price series بناءً على الـ source
        if config.source == "Close":
            price_series = close_arr
        else:
            price_series = low_arr if is_bullish else high_arr

        # شرط الـ confirmation زي ما هو
        if not dontconfirm:
            if is_bullish:
                if not (
                    indicator_series[bar_idx] > indicator_series[bar_idx - 1] or
                    close_arr[bar_idx] > close_arr[bar_idx - 1]
                ):
                    return 0
            else:
                if not (
                    indicator_series[bar_idx] < indicator_series[bar_idx - 1] or
                    close_arr[bar_idx] < close_arr[bar_idx - 1]
                ):
                    return 0

        maxpp = config.maxpp
        maxbars = config.maxbars

        m = len(pivot_positions)

        # لوب على الـ pivots (نفس الفكرة)
        for pivot_idx in range(min(maxpp, m)):
            pivot_bar = pivot_positions[pivot_idx]
            length = bar_idx - pivot_bar

            if length > maxbars:
                break
            if length <= 5:
                continue

            pivot_price = pivot_values[pivot_idx]

            ind_curr   = indicator_series[bar_idx - startpoint]
            ind_pivot  = indicator_series[pivot_bar]
            price_curr = price_series[bar_idx - startpoint]

            # نفس شروط الديفرجنس بالظبط
            if is_bullish and is_regular:
                # Positive Regular
                div_condition = (
                    ind_curr > ind_pivot and
                    price_curr < pivot_price
                )
            elif is_bullish and not is_regular:
                # Positive Hidden
                div_condition = (
                    ind_curr < ind_pivot and
                    price_curr > pivot_price
                )
            elif (not is_bullish) and is_regular:
                # Negative Regular
                div_condition = (
                    ind_curr < ind_pivot and
                    price_curr > pivot_price
                )
            else:
                # Negative Hidden
                div_condition = (
                    ind_curr > ind_pivot and
                    price_curr < pivot_price
                )

            if not div_condition:
                continue

            # خطّين الـ virtual line – نفس الكود القديم
            slope1 = (ind_curr - ind_pivot) / length
            slope2 = (close_arr[bar_idx - startpoint] - close_arr[pivot_bar]) / length

            virtual_line1 = ind_curr
            virtual_line2 = close_arr[bar_idx - startpoint]

            valid = True
            for y in range(1 + startpoint, length):
                virtual_line1 -= slope1
                virtual_line2 -= slope2
                check_idx = bar_idx - y

                if is_bullish:
                    if (indicator_series[check_idx] < virtual_line1 or
                        close_arr[check_idx] < virtual_line2):
                        valid = False
                        break
                else:
                    if (indicator_series[check_idx] > virtual_line1 or
                        close_arr[check_idx] > virtual_line2):
                        valid = False
                        break

            if valid:
                return length

        return 0

    # ------------------------------------------------------------------
    # 5) اللوب الرئيسي على البارات + استخدام deque للـ pivots
    # ------------------------------------------------------------------
    for i in range(n):
        prev = i - 1
        if prev >= 0:
            ph = pivot_high_vals_all[prev]
            if not np.isnan(ph):
                recent_high_bars.appendleft(prev)
                recent_high_vals.appendleft(ph)

            pl = pivot_low_vals_all[prev]
            if not np.isnan(pl):
                recent_low_bars.appendleft(prev)
                recent_low_vals.appendleft(pl)

        # شيل أي pivots قديمة أقدم من maxbars
        cutoff = i - config.maxbars
        while recent_high_bars and recent_high_bars[-1] < cutoff:
            recent_high_bars.pop()
            recent_high_vals.pop()
        while recent_low_bars and recent_low_bars[-1] < cutoff:
            recent_low_bars.pop()
            recent_low_vals.pop()

        if i < config.prd + 10:
            continue

        pivot_high_bars = list(recent_high_bars)
        pivot_high_vals = list(recent_high_vals)
        pivot_low_bars  = list(recent_low_bars)
        pivot_low_vals  = list(recent_low_vals)

        has_highs = len(pivot_high_bars) > 0
        has_lows  = len(pivot_low_bars) > 0

        # 6) لوب على المؤشرات – بس على الـ arrays
        for ind in indicators_to_check:
            ind_arr = ind_arrays[ind]

            if np.isnan(ind_arr[i]):
                continue

            # Positive Regular
            if config.searchdiv in ["Regular", "Regular/Hidden"] and has_lows:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_low_bars, pivot_low_vals,
                    is_bullish=True, is_regular=True
                )
                if div_len > 0:
                    div_arrays[f'{ind}_pos_reg'][i] = div_len

            # Negative Regular
            if config.searchdiv in ["Regular", "Regular/Hidden"] and has_highs:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_high_bars, pivot_high_vals,
                    is_bullish=False, is_regular=True
                )
                if div_len > 0:
                    div_arrays[f'{ind}_neg_reg'][i] = div_len

            # Positive Hidden
            if config.searchdiv in ["Hidden", "Regular/Hidden"] and has_lows:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_low_bars, pivot_low_vals,
                    is_bullish=True, is_regular=False
                )
                if div_len > 0:
                    div_arrays[f'{ind}_pos_hid'][i] = div_len

            # Negative Hidden
            if config.searchdiv in ["Hidden", "Regular/Hidden"] and has_highs:
                div_len = detect_with_arrays(
                    ind_arr, i,
                    pivot_high_bars, pivot_high_vals,
                    is_bullish=False, is_regular=False
                )
                if div_len > 0:
                    div_arrays[f'{ind}_neg_hid'][i] = div_len

    # 7) ارجع النتايج للـ DataFrame زي ما كانت
    for col_name in div_cols:
        df[col_name] = div_arrays[col_name]

    # Count total divergences
    df['total_divergences'] = 0
    for col in div_cols:
        df['total_divergences'] += (df[col] > 0).astype(int)

    # Filter by minimum divergences
    df.loc[df['total_divergences'] < config.showlimit, div_cols] = 0

    # Count positive and negative divergences
    df['pos_div_count'] = 0
    df['neg_div_count'] = 0
    for col in div_cols:
        if 'pos_' in col:
            df['pos_div_count'] += (df[col] > 0).astype(int)
        else:
            df['neg_div_count'] += (df[col] > 0).astype(int)

    total_divs = (df['total_divergences'] > 0).sum()
    print(f"Found {total_divs} bars with divergences")

    return df


#------------------------------------------------------------------------------
# VISUALIZATION
#------------------------------------------------------------------------------

def plot_candlestick_with_signals(df):
    """Create interactive candlestick chart with entry/exit signals"""
    print("Creating candlestick chart...")

    # Create figure with subplots
    fig = make_subplots(
        rows=2, cols=1,
        shared_xaxes=True,
        vertical_spacing=0.03,
        subplot_titles=('Price with Entry/Exit Signals', 'Divergence Counts'),
        row_heights=[0.7, 0.3]
    )

    # Add candlestick
    fig.add_trace(
        go.Candlestick(
            x=df.index,
            open=df['open'],
            high=df['high'],
            low=df['low'],
            close=df['close'],
            name='Price',
            increasing_line_color='green',
            decreasing_line_color='red'
        ),
        row=1, col=1
    )

    # Add entry signals (buy)
    entries = df[df['signal'] == 1]
    if len(entries) > 0:
        fig.add_trace(
            go.Scatter(
                x=entries.index,
                y=entries['entry_price'],
                mode='markers',
                name='BUY',
                marker=dict(
                    symbol='triangle-up',
                    size=15,
                    color='lime',
                    line=dict(color='darkgreen', width=2)
                )
            ),
            row=1, col=1
        )

    # Add exit signals (sell)
    exits = df[df['signal'] == -1]
    if len(exits) > 0:
        fig.add_trace(
            go.Scatter(
                x=exits.index,
                y=exits['exit_price'],
                mode='markers',
                name='SELL',
                marker=dict(
                    symbol='triangle-down',
                    size=15,
                    color='red',
                    line=dict(color='darkred', width=2)
                )
            ),
            row=1, col=1
        )

    # Add positive divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['pos_div_count'],
            mode='lines',
            name='Positive Divergences',
            line=dict(color='green', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add negative divergence count
    fig.add_trace(
        go.Scatter(
            x=df.index,
            y=df['neg_div_count'],
            mode='lines',
            name='Negative Divergences',
            line=dict(color='red', width=1),
            fill='tozeroy'
        ),
        row=2, col=1
    )

    # Add threshold lines
    fig.add_hline(
        y=config.minPosDivForEntry,
        line_dash="dash",
        line_color="green",
        annotation_text=f"Entry Threshold ({config.minPosDivForEntry})",
        row=2, col=1
    )

    fig.add_hline(
        y=config.minNegDivForExit,
        line_dash="dash",
        line_color="red",
        annotation_text=f"Exit Threshold ({config.minNegDivForExit})",
        row=2, col=1
    )

    # Update layout
    fig.update_layout(
        title='Divergence-Based Trading Strategy',
        xaxis_title='Time',
        yaxis_title='Price',
        xaxis2_title='Time',
        yaxis2_title='Divergence Count',
        height=900,
        showlegend=True,
        xaxis_rangeslider_visible=False
    )

    fig.show()
    print("Chart displayed successfully")

#------------------------------------------------------------------------------
# PERFORMANCE METRICS
#------------------------------------------------------------------------------

def calculate_performance(df):
    """Calculate and display performance metrics"""
    print("\n" + "="*60)
    print("PERFORMANCE METRICS")
    print("="*60)

    entries = df[df['signal'] == 1].copy()
    exits = df[df['signal'] == -1].copy()

    if len(entries) == 0:
        print("No trades were executed")
        return

    # Match entries with exits
    trades = []
    for i, entry_row in entries.iterrows():
        entry_idx = df.index.get_loc(i)
        entry_price = entry_row['entry_price']

        # Find next exit
        exit_found = False
        for j, exit_row in exits.iterrows():
            exit_idx = df.index.get_loc(j)
            if exit_idx > entry_idx:
                exit_price = exit_row['exit_price']
                pnl_pct = (exit_price - entry_price) / entry_price * 100
                trades.append({
                    'entry_time': i,
                    'exit_time': j,
                    'entry_price': entry_price,
                    'exit_price': exit_price,
                    'pnl_pct': pnl_pct,
                    'bars_held': exit_idx - entry_idx,
                    'entry_idx': entry_idx  # Store index for indicator lookup
                })
                exit_found = True
                break

        if not exit_found:
            # Still in trade
            trades.append({
                'entry_time': i,
                'exit_time': None,
                'entry_price': entry_price,
                'exit_price': df['close'].iloc[-1],
                'pnl_pct': (df['close'].iloc[-1] - entry_price) / entry_price * 100,
                'bars_held': len(df) - entry_idx - 1,
                'entry_idx': entry_idx
            })

    trades_df = pd.DataFrame(trades)

    # Calculate metrics
    total_trades = len(trades_df)
    winning_trades = len(trades_df[trades_df['pnl_pct'] > 0])
    losing_trades = len(trades_df[trades_df['pnl_pct'] < 0])
    win_rate = (winning_trades / total_trades * 100) if total_trades > 0 else 0
    avg_win = trades_df[trades_df['pnl_pct'] > 0]['pnl_pct'].mean() if winning_trades > 0 else 0
    avg_loss = trades_df[trades_df['pnl_pct'] < 0]['pnl_pct'].mean() if losing_trades > 0 else 0
    avg_pnl = trades_df['pnl_pct'].mean()
    total_return = trades_df['pnl_pct'].sum()
    avg_bars_held = trades_df['bars_held'].mean()

    # Display metrics
    print(f"Total Trades:       {total_trades}")
    print(f"Winning Trades:     {winning_trades}")
    print(f"Losing Trades:      {losing_trades}")
    print(f"Win Rate:           {win_rate:.2f}%")
    print(f"Average Win:        {avg_win:.2f}%")
    print(f"Average Loss:       {avg_loss:.2f}%")
    print(f"Average P&L:        {avg_pnl:.2f}%")
    print(f"Total Return:       {total_return:.2f}%")
    print(f"Avg Bars Held:      {avg_bars_held:.1f}")

    print("\n" + "="*60)

    # Display trade list with indicator values
    print("\nDETAILED TRADE ANALYSIS WITH INDICATORS:")
    print("="*60)

    for idx, trade in trades_df.iterrows():
        status = "CLOSED" if trade['exit_time'] is not None else "OPEN"
        entry_idx = trade['entry_idx']

        print(f"\n{'='*60}")
        print(f"Trade #{idx+1} [{status}]")
        print(f"{'='*60}")

        # Price information
        print(f"\n📊 PRICE INFORMATION:")
        print(f"  Entry Time:      {trade['entry_time']}")
        print(f"  Entry Price:     ${trade['entry_price']:.2f}")
        print(f"  Open:            ${df['open'].iloc[entry_idx]:.2f}")
        print(f"  High:            ${df['high'].iloc[entry_idx]:.2f}")
        print(f"  Low:             ${df['low'].iloc[entry_idx]:.2f}")
        print(f"  Close:           ${df['close'].iloc[entry_idx]:.2f}")

        if trade['exit_time'] is not None:
            print(f"  Exit Time:       {trade['exit_time']}")
            print(f"  Exit Price:      ${trade['exit_price']:.2f}")
        else:
            print(f"  Current Price:   ${trade['exit_price']:.2f}")

        print(f"  P&L:             {trade['pnl_pct']:+.2f}%")
        print(f"  Duration:        {int(trade['bars_held'])} bars")

        # Divergence counts
        print(f"\n🔍 DIVERGENCE SIGNALS:")
        print(f"  Positive Divs:   {int(df['pos_div_count'].iloc[entry_idx])}")
        print(f"  Negative Divs:   {int(df['neg_div_count'].iloc[entry_idx])}")
        print(f"  Total Divs:      {int(df['total_divergences'].iloc[entry_idx])}")

        # Technical indicators
        print(f"\n📈 TECHNICAL INDICATORS AT ENTRY:")

        # Momentum indicators
        if config.calcrsi:
            print(f"  RSI (14):        {df['rsi'].iloc[entry_idx]:.2f}")

        if config.calcstoc:
            print(f"  Stochastic:      {df['stoch'].iloc[entry_idx]:.2f}")

        if config.calcmom:
            print(f"  Momentum (10):   {df['momentum'].iloc[entry_idx]:.2f}")

        if config.calccci:
            print(f"  CCI (10):        {df['cci'].iloc[entry_idx]:.2f}")

        # Trend indicators
        if config.calcmacd:
            print(f"  MACD:            {df['macd'].iloc[entry_idx]:.4f}")
            print(f"  MACD Signal:     {df['macd_signal'].iloc[entry_idx]:.4f}")

        if config.calcmacda:
            print(f"  MACD Histogram:  {df['macd_hist'].iloc[entry_idx]:.4f}")

        # Volume indicators
        if config.calcobv:
            print(f"  OBV:             {df['obv'].iloc[entry_idx]:,.0f}")

        if config.calcvwmacd:
            print(f"  VWMACD:          {df['vwmacd'].iloc[entry_idx]:.4f}")

        if config.calccmf:
            print(f"  CMF (21):        {df['cmf'].iloc[entry_idx]:.4f}")

        if config.calcmfi:
            print(f"  MFI (14):        {df['mfi'].iloc[entry_idx]:.2f}")

        # Individual divergences detected
        print(f"\n🎯 SPECIFIC DIVERGENCES DETECTED:")
        divergence_found = False

        # Check each indicator's divergences
        indicators_list = []
        if config.calcmacd:
            indicators_list.append(('MACD', 'macd'))
        if config.calcmacda:
            indicators_list.append(('MACD Hist', 'macd_hist'))
        if config.calcrsi:
            indicators_list.append(('RSI', 'rsi'))
        if config.calcstoc:
            indicators_list.append(('Stochastic', 'stoch'))
        if config.calccci:
            indicators_list.append(('CCI', 'cci'))
        if config.calcmom:
            indicators_list.append(('Momentum', 'momentum'))
        if config.calcobv:
            indicators_list.append(('OBV', 'obv'))
        if config.calcvwmacd:
            indicators_list.append(('VWMACD', 'vwmacd'))
        if config.calccmf:
            indicators_list.append(('CMF', 'cmf'))
        if config.calcmfi:
            indicators_list.append(('MFI', 'mfi'))

        for ind_name, ind_col in indicators_list:
            divs = []
            if f'{ind_col}_pos_reg' in df.columns and df[f'{ind_col}_pos_reg'].iloc[entry_idx] > 0:
                divs.append(f"Pos Regular ({int(df[f'{ind_col}_pos_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_reg' in df.columns and df[f'{ind_col}_neg_reg'].iloc[entry_idx] > 0:
                divs.append(f"Neg Regular ({int(df[f'{ind_col}_neg_reg'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_pos_hid' in df.columns and df[f'{ind_col}_pos_hid'].iloc[entry_idx] > 0:
                divs.append(f"Pos Hidden ({int(df[f'{ind_col}_pos_hid'].iloc[entry_idx])} bars)")
                divergence_found = True
            if f'{ind_col}_neg_hid' in df.columns and df[f'{ind_col}_neg_hid'].iloc[entry_idx] > 0:
                divs.append(f"Neg Hidden ({int(df[f'{ind_col}_neg_hid'].iloc[entry_idx])} bars)")
                divergence_found = True

            if divs:
                print(f"  {ind_name:15s}: {', '.join(divs)}")

        if not divergence_found:
            print(f"  No specific divergences recorded (signal from previous bar)")

    print("\n" + "="*60)

#------------------------------------------------------------------------------
# MAIN EXECUTION
#------------------------------------------------------------------------------

def main(csv_filepath):
    """Main execution function"""

    print("="*60)
    print("DIVERGENCE-BASED TRADING STRATEGY")
    print("="*60)
    print(f"\nConfiguration:")
    print(f"  Pivot Period: {config.prd}")
    print(f"  Divergence Type: {config.searchdiv}")
    print(f"  Min Positive Divergences for Entry: {config.minPosDivForEntry}")
    print(f"  Min Negative Divergences for Exit: {config.minNegDivForExit}")
    print(f"  Entry Delay: {config.delayBars} bars")
    print("\n" + "="*60 + "\n")

    # Load data
    df = load_data_from_csv(csv_filepath)

    # Calculate indicators
    df = calculate_indicators(df)

    # Find pivot points
    df = find_pivots(df, config.prd)

    # Scan for divergences
    df = scan_all_divergences(df)

    # Run strategy
    df = run_strategy(df)

    # Calculate performance
    calculate_performance(df)

    # Plot results
    # plot_candlestick_with_signals(df)

    return df

# ============================================================================
# RUN THE STRATEGY
# ============================================================================

# Upload your CSV file to Colab first, then specify the path
# Example: df_result = main('/content/your_data.csv')

# For Google Colab, you can upload a file like this:
# from google.colab import files
# uploaded = files.upload()

# Get the uploaded filename
csv_filename = 'PLD.csv'

# Run the strategy
df_result = main(csv_filename)
# Out:
# Streaming output truncated to the last 5000 lines.
#   Entry Price:     $984.51
#   Open:            $984.51
#   High:            $984.71
#   Low:             $982.24
#   Close:           $982.81
#   Exit Time:       2025-03-13 19:45:00-04:00
#   Exit Price:      $995.41
#   P&L:             +1.11%
#   Duration:        76 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.49
#   Stochastic:      10.72
#   Momentum (10):   -4.10
#   CCI (10):        -142.62
#   MACD:            -0.5217
#   MACD Signal:     -0.0807
#   MACD Histogram:  -0.4410
#   VWMACD:          -0.1737
#   CMF (21):        -0.0370
#   MFI (14):        41.61
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #38 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-14 10:45:00-04:00
#   Entry Price:     $993.19
#   Open:            $993.19
#   High:            $993.32
#   Low:             $989.62
#   Close:           $990.62
#   Exit Time:       2025-03-16 22:00:00-04:00
#   Exit Price:      $995.22
#   P&L:             +0.20%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.63
#   Stochastic:      24.07
#   Momentum (10):   -4.45
#   CCI (10):        -91.33
#   MACD:            -0.4609
#   MACD Signal:     -0.1159
#   MACD Histogram:  -0.3450
#   VWMACD:          0.8495
#   CMF (21):        -0.0706
#   MFI (14):        48.00
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #39 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-18 10:30:00-04:00
#   Entry Price:     $1003.49
#   Open:            $1003.49
#   High:            $1005.60
#   Low:             $1002.08
#   Close:           $1003.11
#   Exit Time:       2025-03-19 12:15:00-04:00
#   Exit Price:      $997.15
#   P&L:             -0.63%
#   Duration:        99 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.04
#   Stochastic:      37.03
#   Momentum (10):   -4.29
#   CCI (10):        15.24
#   MACD:            -0.7306
#   MACD Signal:     -0.5696
#   MACD Histogram:  -0.1610
#   VWMACD:          -0.9681
#   CMF (21):        -0.1286
#   MFI (14):        45.86
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #40 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-20 22:45:00-04:00
#   Entry Price:     $983.61
#   Open:            $983.61
#   High:            $984.51
#   Low:             $983.51
#   Close:           $983.81
#   Exit Time:       2025-03-21 03:00:00-04:00
#   Exit Price:      $984.56
#   P&L:             +0.10%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.38
#   Stochastic:      28.77
#   Momentum (10):   -1.62
#   CCI (10):        -65.59
#   MACD:            -0.6811
#   MACD Signal:     -0.4334
#   MACD Histogram:  -0.2477
#   VWMACD:          -0.3886
#   CMF (21):        0.3016
#   MFI (14):        66.81
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #41 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-21 04:45:00-04:00
#   Entry Price:     $978.83
#   Open:            $978.83
#   High:            $979.80
#   Low:             $978.09
#   Close:           $979.43
#   Exit Time:       2025-03-21 12:30:00-04:00
#   Exit Price:      $978.94
#   P&L:             +0.01%
#   Duration:        31 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.02
#   Stochastic:      16.68
#   Momentum (10):   -6.33
#   CCI (10):        -57.46
#   MACD:            -1.2736
#   MACD Signal:     -0.8110
#   MACD Histogram:  -0.4626
#   VWMACD:          0.1930
#   CMF (21):        -0.0480
#   MFI (14):        51.61
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #42 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-24 01:00:00-04:00
#   Entry Price:     $980.45
#   Open:            $980.45
#   High:            $980.69
#   Low:             $979.24
#   Close:           $980.48
#   Exit Time:       2025-03-24 03:45:00-04:00
#   Exit Price:      $980.67
#   P&L:             +0.02%
#   Duration:        11 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.29
#   Stochastic:      19.48
#   Momentum (10):   -1.85
#   CCI (10):        -84.74
#   MACD:            -0.1597
#   MACD Signal:     0.1054
#   MACD Histogram:  -0.2652
#   VWMACD:          -0.5838
#   CMF (21):        -0.0661
#   MFI (14):        47.09
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #43 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-24 04:15:00-04:00
#   Entry Price:     $982.90
#   Open:            $982.90
#   High:            $985.79
#   Low:             $982.42
#   Close:           $984.95
#   Exit Time:       2025-03-24 04:45:00-04:00
#   Exit Price:      $982.44
#   P&L:             -0.05%
#   Duration:        2 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        59.75
#   Stochastic:      59.98
#   Momentum (10):   3.01
#   CCI (10):        154.12
#   MACD:            0.2363
#   MACD Signal:     -0.0262
#   MACD Histogram:  0.2625
#   VWMACD:          0.0055
#   CMF (21):        0.0903
#   MFI (14):        61.68
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #44 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-24 07:00:00-04:00
#   Entry Price:     $977.20
#   Open:            $977.20
#   High:            $979.21
#   Low:             $975.32
#   Close:           $978.62
#   Exit Time:       2025-03-25 01:45:00-04:00
#   Exit Price:      $976.31
#   P&L:             -0.09%
#   Duration:        71 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.10
#   Stochastic:      23.08
#   Momentum (10):   -3.82
#   CCI (10):        -38.99
#   MACD:            -0.8105
#   MACD Signal:     -0.4630
#   MACD Histogram:  -0.3475
#   VWMACD:          -0.3507
#   CMF (21):        0.2270
#   MFI (14):        64.54
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #45 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-25 18:15:00-04:00
#   Entry Price:     $977.76
#   Open:            $977.76
#   High:            $977.77
#   Low:             $977.17
#   Close:           $977.47
#   Exit Time:       2025-03-26 09:30:00-04:00
#   Exit Price:      $980.84
#   P&L:             +0.32%
#   Duration:        61 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.12
#   Stochastic:      22.26
#   Momentum (10):   -1.14
#   CCI (10):        -123.08
#   MACD:            -1.0246
#   MACD Signal:     -0.8318
#   MACD Histogram:  -0.1928
#   VWMACD:          -3.3385
#   CMF (21):        -0.2634
#   MFI (14):        54.89
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #46 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-26 18:45:00-04:00
#   Entry Price:     $976.45
#   Open:            $976.45
#   High:            $976.61
#   Low:             $973.08
#   Close:           $973.81
#   Exit Time:       2025-03-27 11:30:00-04:00
#   Exit Price:      $986.47
#   P&L:             +1.03%
#   Duration:        67 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.83
#   Stochastic:      30.72
#   Momentum (10):   -2.50
#   CCI (10):        -171.13
#   MACD:            -0.6771
#   MACD Signal:     -0.4679
#   MACD Histogram:  -0.2093
#   VWMACD:          -1.6514
#   CMF (21):        0.0513
#   MFI (14):        40.17
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #47 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-03-28 06:30:00-04:00
#   Entry Price:     $984.53
#   Open:            $984.53
#   High:            $987.33
#   Low:             $984.32
#   Close:           $985.21
#   Exit Time:       2025-03-30 23:00:00-04:00
#   Exit Price:      $986.81
#   P&L:             +0.23%
#   Duration:        62 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.03
#   Stochastic:      17.75
#   Momentum (10):   -5.38
#   CCI (10):        -16.96
#   MACD:            -0.3555
#   MACD Signal:     0.0039
#   MACD Histogram:  -0.3594
#   VWMACD:          -0.1468
#   CMF (21):        0.0152
#   MFI (14):        38.43
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #48 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-01 12:45:00-04:00
#   Entry Price:     $984.67
#   Open:            $984.67
#   High:            $985.82
#   Low:             $984.32
#   Close:           $985.11
#   Exit Time:       2025-04-01 22:15:00-04:00
#   Exit Price:      $988.56
#   P&L:             +0.39%
#   Duration:        34 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.91
#   Stochastic:      14.52
#   Momentum (10):   -3.98
#   CCI (10):        -76.69
#   MACD:            -1.6961
#   MACD Signal:     -1.0568
#   MACD Histogram:  -0.6393
#   VWMACD:          -1.1963
#   CMF (21):        -0.2074
#   MFI (14):        34.56
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #49 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-02 01:45:00-04:00
#   Entry Price:     $986.05
#   Open:            $986.05
#   High:            $986.14
#   Low:             $983.12
#   Close:           $984.51
#   Exit Time:       2025-04-02 19:30:00-04:00
#   Exit Price:      $981.96
#   P&L:             -0.41%
#   Duration:        67 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.30
#   Stochastic:      24.00
#   Momentum (10):   -3.31
#   CCI (10):        -126.15
#   MACD:            -0.5042
#   MACD Signal:     -0.2191
#   MACD Histogram:  -0.2851
#   VWMACD:          -0.8804
#   CMF (21):        0.0428
#   MFI (14):        32.89
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #50 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-03 13:45:00-04:00
#   Entry Price:     $952.85
#   Open:            $952.85
#   High:            $953.27
#   Low:             $951.92
#   Close:           $952.33
#   Exit Time:       2025-04-04 01:45:00-04:00
#   Exit Price:      $957.39
#   P&L:             +0.48%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.54
#   Stochastic:      2.42
#   Momentum (10):   -2.03
#   CCI (10):        -133.04
#   MACD:            -2.9469
#   MACD Signal:     -2.9973
#   MACD Histogram:  0.0503
#   VWMACD:          -2.9652
#   CMF (21):        -0.2426
#   MFI (14):        31.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #51 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-04 05:15:00-04:00
#   Entry Price:     $944.32
#   Open:            $944.32
#   High:            $945.30
#   Low:             $943.87
#   Close:           $944.02
#   Exit Time:       2025-04-07 06:30:00-04:00
#   Exit Price:      $922.54
#   P&L:             -2.31%
#   Duration:        97 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.20
#   Stochastic:      16.37
#   Momentum (10):   -3.76
#   CCI (10):        3.32
#   MACD:            -2.6039
#   MACD Signal:     -2.0400
#   MACD Histogram:  -0.5639
#   VWMACD:          -4.1003
#   CMF (21):        -0.0401
#   MFI (14):        12.22
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #52 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-07 11:45:00-04:00
#   Entry Price:     $912.07
#   Open:            $912.07
#   High:            $915.07
#   Low:             $911.40
#   Close:           $912.51
#   Exit Time:       2025-04-07 16:45:00-04:00
#   Exit Price:      $914.82
#   P&L:             +0.30%
#   Duration:        20 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.31
#   Stochastic:      18.98
#   Momentum (10):   -5.39
#   CCI (10):        -36.14
#   MACD:            -2.4105
#   MACD Signal:     -1.9449
#   MACD Histogram:  -0.4656
#   VWMACD:          -1.0100
#   CMF (21):        -0.2321
#   MFI (14):        31.00
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #53 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-08 05:45:00-04:00
#   Entry Price:     $922.32
#   Open:            $922.32
#   High:            $923.99
#   Low:             $920.84
#   Close:           $923.20
#   Exit Time:       2025-04-09 01:30:00-04:00
#   Exit Price:      $921.13
#   P&L:             -0.13%
#   Duration:        75 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.04
#   Stochastic:      19.49
#   Momentum (10):   -4.87
#   CCI (10):        -29.14
#   MACD:            -0.7887
#   MACD Signal:     0.0948
#   MACD Histogram:  -0.8835
#   VWMACD:          -2.4063
#   CMF (21):        -0.0027
#   MFI (14):        53.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #54 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-09 09:00:00-04:00
#   Entry Price:     $919.41
#   Open:            $919.41
#   High:            $922.66
#   Low:             $919.02
#   Close:           $922.66
#   Exit Time:       2025-04-09 14:00:00-04:00
#   Exit Price:      $929.83
#   P&L:             +1.13%
#   Duration:        20 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.32
#   Stochastic:      27.17
#   Momentum (10):   -2.55
#   CCI (10):        15.39
#   MACD:            -0.4018
#   MACD Signal:     0.0893
#   MACD Histogram:  -0.4911
#   VWMACD:          -1.0055
#   CMF (21):        -0.2726
#   MFI (14):        45.71
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #55 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-16 02:45:00-04:00
#   Entry Price:     $958.20
#   Open:            $958.20
#   High:            $960.22
#   Low:             $957.43
#   Close:           $959.67
#   Exit Time:       2025-04-16 05:45:00-04:00
#   Exit Price:      $960.91
#   P&L:             +0.28%
#   Duration:        12 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.86
#   Stochastic:      34.81
#   Momentum (10):   -0.04
#   CCI (10):        7.43
#   MACD:            -0.2550
#   MACD Signal:     -0.0318
#   MACD Histogram:  -0.2232
#   VWMACD:          -0.1600
#   CMF (21):        -0.1974
#   MFI (14):        48.50
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #56 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-16 18:15:00-04:00
#   Entry Price:     $970.38
#   Open:            $970.38
#   High:            $972.65
#   Low:             $970.23
#   Close:           $971.47
#   Exit Time:       2025-04-16 19:00:00-04:00
#   Exit Price:      $971.98
#   P&L:             +0.17%
#   Duration:        3 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        55.73
#   Stochastic:      56.41
#   Momentum (10):   0.51
#   CCI (10):        92.69
#   MACD:            0.5218
#   MACD Signal:     0.7335
#   MACD Histogram:  -0.2117
#   VWMACD:          0.3249
#   CMF (21):        0.0441
#   MFI (14):        70.38
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #57 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-17 01:30:00-04:00
#   Entry Price:     $965.07
#   Open:            $965.07
#   High:            $965.82
#   Low:             $963.92
#   Close:           $965.72
#   Exit Time:       2025-04-20 18:30:00-04:00
#   Exit Price:      $969.33
#   P&L:             +0.44%
#   Duration:        64 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.40
#   Stochastic:      19.87
#   Momentum (10):   -2.33
#   CCI (10):        -43.22
#   MACD:            -1.0891
#   MACD Signal:     -0.9420
#   MACD Histogram:  -0.1471
#   VWMACD:          -0.9782
#   CMF (21):        -0.0033
#   MFI (14):        53.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #58 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-21 13:00:00-04:00
#   Entry Price:     $964.51
#   Open:            $964.51
#   High:            $965.77
#   Low:             $963.74
#   Close:           $964.29
#   Exit Time:       2025-04-22 02:30:00-04:00
#   Exit Price:      $972.98
#   P&L:             +0.88%
#   Duration:        50 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   1
#   Negative Divs:   0
#   Total Divs:      1
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.91
#   Stochastic:      9.09
#   Momentum (10):   -1.47
#   CCI (10):        -118.32
#   MACD:            -1.8952
#   MACD Signal:     -1.6646
#   MACD Histogram:  -0.2306
#   VWMACD:          -2.2651
#   CMF (21):        -0.0969
#   MFI (14):        25.55
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   MACD Hist      : Pos Regular (10 bars)
#
# ============================================================
# Trade #59 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-22 09:45:00-04:00
#   Entry Price:     $961.20
#   Open:            $961.20
#   High:            $963.84
#   Low:             $959.93
#   Close:           $960.23
#   Exit Time:       2025-04-23 00:15:00-04:00
#   Exit Price:      $962.64
#   P&L:             +0.15%
#   Duration:        54 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        26.00
#   Stochastic:      13.73
#   Momentum (10):   -10.18
#   CCI (10):        -90.96
#   MACD:            -2.5297
#   MACD Signal:     -1.4847
#   MACD Histogram:  -1.0449
#   VWMACD:          -2.6843
#   CMF (21):        -0.2987
#   MFI (14):        33.80
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #60 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-23 20:15:00-04:00
#   Entry Price:     $974.04
#   Open:            $974.04
#   High:            $975.34
#   Low:             $973.79
#   Close:           $974.75
#   Exit Time:       2025-04-24 03:30:00-04:00
#   Exit Price:      $972.42
#   P&L:             -0.17%
#   Duration:        29 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        56.07
#   Stochastic:      63.95
#   Momentum (10):   0.63
#   CCI (10):        172.46
#   MACD:            0.2387
#   MACD Signal:     0.3352
#   MACD Histogram:  -0.0964
#   VWMACD:          0.0529
#   CMF (21):        0.1337
#   MFI (14):        47.65
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #61 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-24 10:15:00-04:00
#   Entry Price:     $973.25
#   Open:            $973.25
#   High:            $974.80
#   Low:             $971.92
#   Close:           $974.49
#   Exit Time:       2025-04-24 19:15:00-04:00
#   Exit Price:      $975.31
#   P&L:             +0.21%
#   Duration:        32 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        46.68
#   Stochastic:      12.37
#   Momentum (10):   -4.86
#   CCI (10):        -53.58
#   MACD:            -0.0291
#   MACD Signal:     0.5102
#   MACD Histogram:  -0.5393
#   VWMACD:          -0.0728
#   CMF (21):        -0.1251
#   MFI (14):        51.84
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #62 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-24 22:15:00-04:00
#   Entry Price:     $970.87
#   Open:            $970.87
#   High:            $970.91
#   Low:             $970.39
#   Close:           $970.63
#   Exit Time:       2025-04-25 09:15:00-04:00
#   Exit Price:      $970.64
#   P&L:             -0.02%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        33.35
#   Stochastic:      3.88
#   Momentum (10):   -3.99
#   CCI (10):        -115.10
#   MACD:            -0.6426
#   MACD Signal:     -0.1182
#   MACD Histogram:  -0.5244
#   VWMACD:          0.1507
#   CMF (21):        -0.1850
#   MFI (14):        49.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #63 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-29 09:30:00-04:00
#   Entry Price:     $986.89
#   Open:            $986.89
#   High:            $988.88
#   Low:             $986.19
#   Close:           $986.28
#   Exit Time:       2025-04-29 23:30:00-04:00
#   Exit Price:      $980.82
#   P&L:             -0.61%
#   Duration:        52 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        43.80
#   Stochastic:      32.69
#   Momentum (10):   -4.09
#   CCI (10):        -72.31
#   MACD:            -0.6196
#   MACD Signal:     -0.1223
#   MACD Histogram:  -0.4973
#   VWMACD:          -0.8505
#   CMF (21):        -0.0627
#   MFI (14):        38.92
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #64 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-30 04:45:00-04:00
#   Entry Price:     $969.70
#   Open:            $969.70
#   High:            $971.24
#   Low:             $969.46
#   Close:           $969.85
#   Exit Time:       2025-04-30 11:15:00-04:00
#   Exit Price:      $970.76
#   P&L:             +0.11%
#   Duration:        26 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.88
#   Stochastic:      25.47
#   Momentum (10):   -10.28
#   CCI (10):        -44.50
#   MACD:            -2.8344
#   MACD Signal:     -1.6132
#   MACD Histogram:  -1.2212
#   VWMACD:          -1.4146
#   CMF (21):        -0.3325
#   MFI (14):        23.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #65 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-04-30 23:30:00-04:00
#   Entry Price:     $963.67
#   Open:            $963.67
#   High:            $963.84
#   Low:             $961.22
#   Close:           $961.74
#   Exit Time:       2025-05-01 09:45:00-04:00
#   Exit Price:      $967.67
#   P&L:             +0.42%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        28.69
#   Stochastic:      10.05
#   Momentum (10):   -3.47
#   CCI (10):        -174.50
#   MACD:            -1.2919
#   MACD Signal:     -0.9631
#   MACD Histogram:  -0.3288
#   VWMACD:          -1.4658
#   CMF (21):        0.0262
#   MFI (14):        22.54
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #66 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-02 12:00:00-04:00
#   Entry Price:     $962.63
#   Open:            $962.63
#   High:            $965.20
#   Low:             $962.63
#   Close:           $964.52
#   Exit Time:       2025-05-05 02:00:00-04:00
#   Exit Price:      $966.02
#   P&L:             +0.35%
#   Duration:        52 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.14
#   Stochastic:      14.30
#   Momentum (10):   -5.86
#   CCI (10):        -57.38
#   MACD:            -1.3416
#   MACD Signal:     -0.4512
#   MACD Histogram:  -0.8904
#   VWMACD:          -0.8401
#   CMF (21):        0.0163
#   MFI (14):        56.54
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #67 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-05 11:30:00-04:00
#   Entry Price:     $959.37
#   Open:            $959.37
#   High:            $960.30
#   Low:             $958.75
#   Close:           $959.68
#   Exit Time:       2025-05-05 21:30:00-04:00
#   Exit Price:      $967.01
#   P&L:             +0.80%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.83
#   Stochastic:      12.60
#   Momentum (10):   -9.22
#   CCI (10):        -58.05
#   MACD:            -1.7741
#   MACD Signal:     -0.9304
#   MACD Histogram:  -0.8436
#   VWMACD:          -1.2206
#   CMF (21):        -0.1195
#   MFI (14):        36.07
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #68 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-07 12:45:00-04:00
#   Entry Price:     $982.62
#   Open:            $982.62
#   High:            $983.52
#   Low:             $982.12
#   Close:           $983.02
#   Exit Time:       2025-05-08 10:00:00-04:00
#   Exit Price:      $987.92
#   P&L:             +0.54%
#   Duration:        81 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.39
#   Stochastic:      12.33
#   Momentum (10):   -4.05
#   CCI (10):        -79.11
#   MACD:            -0.8806
#   MACD Signal:     -0.1751
#   MACD Histogram:  -0.7055
#   VWMACD:          -0.5750
#   CMF (21):        0.0099
#   MFI (14):        50.47
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #69 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-08 22:30:00-04:00
#   Entry Price:     $980.52
#   Open:            $980.52
#   High:            $982.25
#   Low:             $980.52
#   Close:           $982.12
#   Exit Time:       2025-05-09 02:45:00-04:00
#   Exit Price:      $987.82
#   P&L:             +0.74%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.49
#   Stochastic:      31.33
#   Momentum (10):   -0.40
#   CCI (10):        25.21
#   MACD:            -0.6697
#   MACD Signal:     -0.4541
#   MACD Histogram:  -0.2156
#   VWMACD:          -0.4358
#   CMF (21):        0.0301
#   MFI (14):        49.01
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #70 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-11 18:15:00-04:00
#   Entry Price:     $1002.12
#   Open:            $1002.12
#   High:            $1002.71
#   Low:             $1000.00
#   Close:           $1001.23
#   Exit Time:       2025-05-11 18:30:00-04:00
#   Exit Price:      $1000.98
#   P&L:             -0.11%
#   Duration:        1 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   3
#   Total Divs:      3
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        63.45
#   Stochastic:      60.31
#   Momentum (10):   1.44
#   CCI (10):        131.62
#   MACD:            1.5287
#   MACD Signal:     1.7651
#   MACD Histogram:  -0.2364
#   VWMACD:          0.3921
#   CMF (21):        -0.2215
#   MFI (14):        35.56
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   MACD Hist      : Neg Regular (12 bars)
#   RSI            : Neg Regular (12 bars)
#   MFI            : Neg Regular (12 bars)
#
# ============================================================
# Trade #71 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-11 20:45:00-04:00
#   Entry Price:     $996.34
#   Open:            $996.34
#   High:            $997.63
#   Low:             $996.13
#   Close:           $996.86
#   Exit Time:       2025-05-12 02:45:00-04:00
#   Exit Price:      $1001.14
#   P&L:             +0.48%
#   Duration:        24 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.42
#   Stochastic:      15.00
#   Momentum (10):   -4.37
#   CCI (10):        -76.05
#   MACD:            0.1696
#   MACD Signal:     0.9356
#   MACD Histogram:  -0.7659
#   VWMACD:          -0.5734
#   CMF (21):        -0.2499
#   MFI (14):        44.38
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #72 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-12 08:45:00-04:00
#   Entry Price:     $981.82
#   Open:            $981.82
#   High:            $983.20
#   Low:             $977.00
#   Close:           $982.50
#   Exit Time:       2025-05-12 18:45:00-04:00
#   Exit Price:      $982.52
#   P&L:             +0.07%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        42.35
#   Stochastic:      71.62
#   Momentum (10):   1.40
#   CCI (10):        25.18
#   MACD:            -3.4074
#   MACD Signal:     -3.8536
#   MACD Histogram:  0.4462
#   VWMACD:          -4.3703
#   CMF (21):        0.6236
#   MFI (14):        57.13
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #73 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-15 02:30:00-04:00
#   Entry Price:     $980.84
#   Open:            $980.84
#   High:            $981.59
#   Low:             $970.00
#   Close:           $980.97
#   Exit Time:       2025-05-15 07:00:00-04:00
#   Exit Price:      $985.01
#   P&L:             +0.43%
#   Duration:        18 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.00
#   Stochastic:      68.86
#   Momentum (10):   -4.41
#   CCI (10):        -72.88
#   MACD:            -0.8997
#   MACD Signal:     -0.3516
#   MACD Histogram:  -0.5481
#   VWMACD:          -1.4132
#   CMF (21):        0.8469
#   MFI (14):        54.89
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #74 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-16 03:00:00-04:00
#   Entry Price:     $988.41
#   Open:            $988.41
#   High:            $989.46
#   Low:             $980.00
#   Close:           $987.20
#   Exit Time:       2025-05-18 20:00:00-04:00
#   Exit Price:      $993.91
#   P&L:             +0.56%
#   Duration:        64 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        31.36
#   Stochastic:      63.19
#   Momentum (10):   -3.40
#   CCI (10):        -157.55
#   MACD:            -0.8274
#   MACD Signal:     -0.5369
#   MACD Histogram:  -0.2906
#   VWMACD:          -0.8733
#   CMF (21):        0.7675
#   MFI (14):        45.49
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #75 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-19 04:00:00-04:00
#   Entry Price:     $990.21
#   Open:            $990.21
#   High:            $990.61
#   Low:             $985.50
#   Close:           $989.51
#   Exit Time:       2025-05-19 05:15:00-04:00
#   Exit Price:      $995.30
#   P&L:             +0.51%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.22
#   Stochastic:      45.59
#   Momentum (10):   -3.50
#   CCI (10):        -128.33
#   MACD:            -0.2941
#   MACD Signal:     0.1567
#   MACD Histogram:  -0.4508
#   VWMACD:          0.0486
#   CMF (21):        0.6729
#   MFI (14):        41.90
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #76 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-21 01:30:00-04:00
#   Entry Price:     $1041.90
#   Open:            $1041.90
#   High:            $1042.58
#   Low:             $1036.50
#   Close:           $1042.43
#   Exit Time:       2025-05-21 09:15:00-04:00
#   Exit Price:      $1062.81
#   P&L:             +2.01%
#   Duration:        31 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.42
#   Stochastic:      30.67
#   Momentum (10):   -6.09
#   CCI (10):        -69.32
#   MACD:            -2.2262
#   MACD Signal:     -1.1808
#   MACD Histogram:  -1.0453
#   VWMACD:          -4.4318
#   CMF (21):        0.4455
#   MFI (14):        41.41
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #77 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-22 05:45:00-04:00
#   Entry Price:     $1069.38
#   Open:            $1069.38
#   High:            $1070.86
#   Low:             $1065.00
#   Close:           $1069.72
#   Exit Time:       2025-05-22 16:45:00-04:00
#   Exit Price:      $1081.13
#   P&L:             +1.10%
#   Duration:        44 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.88
#   Stochastic:      26.15
#   Momentum (10):   -10.89
#   CCI (10):        -63.59
#   MACD:            -1.5981
#   MACD Signal:     -0.3747
#   MACD Histogram:  -1.2234
#   VWMACD:          -0.2289
#   CMF (21):        0.4995
#   MFI (14):        49.79
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #78 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-23 05:15:00-04:00
#   Entry Price:     $1084.76
#   Open:            $1084.76
#   High:            $1088.41
#   Low:             $1078.50
#   Close:           $1081.00
#   Exit Time:       2025-05-23 06:45:00-04:00
#   Exit Price:      $1095.97
#   P&L:             +1.03%
#   Duration:        6 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.15
#   Stochastic:      23.38
#   Momentum (10):   -14.14
#   CCI (10):        -78.55
#   MACD:            -0.5656
#   MACD Signal:     0.7790
#   MACD Histogram:  -1.3446
#   VWMACD:          -0.3937
#   CMF (21):        0.2532
#   MFI (14):        36.81
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #79 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-26 06:00:00-04:00
#   Entry Price:     $1088.57
#   Open:            $1088.57
#   High:            $1090.54
#   Low:             $1084.00
#   Close:           $1090.05
#   Exit Time:       2025-05-28 03:30:00-04:00
#   Exit Price:      $1089.39
#   P&L:             +0.08%
#   Duration:        164 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        48.57
#   Stochastic:      33.92
#   Momentum (10):   3.38
#   CCI (10):        61.08
#   MACD:            -1.4829
#   MACD Signal:     -1.4958
#   MACD Histogram:  0.0129
#   VWMACD:          -2.7751
#   CMF (21):        -0.3726
#   MFI (14):        42.88
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #80 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-28 20:00:00-04:00
#   Entry Price:     $1074.99
#   Open:            $1074.99
#   High:            $1078.30
#   Low:             $1071.50
#   Close:           $1076.59
#   Exit Time:       2025-05-29 05:15:00-04:00
#   Exit Price:      $1078.93
#   P&L:             +0.37%
#   Duration:        37 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.54
#   Stochastic:      44.87
#   Momentum (10):   -1.91
#   CCI (10):        -23.55
#   MACD:            -1.7797
#   MACD Signal:     -1.3350
#   MACD Histogram:  -0.4448
#   VWMACD:          -0.7912
#   CMF (21):        0.3032
#   MFI (14):        43.15
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #81 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-05-30 00:45:00-04:00
#   Entry Price:     $1075.06
#   Open:            $1075.06
#   High:            $1075.67
#   Low:             $1074.50
#   Close:           $1075.26
#   Exit Time:       2025-06-02 10:15:00-04:00
#   Exit Price:      $1060.05
#   P&L:             -1.40%
#   Duration:        130 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        34.23
#   Stochastic:      8.25
#   Momentum (10):   -7.14
#   CCI (10):        -70.72
#   MACD:            -1.6761
#   MACD Signal:     -0.8636
#   MACD Histogram:  -0.8126
#   VWMACD:          -1.6235
#   CMF (21):        0.2600
#   MFI (14):        42.24
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #82 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-03 03:45:00-04:00
#   Entry Price:     $1062.87
#   Open:            $1062.87
#   High:            $1064.12
#   Low:             $1061.50
#   Close:           $1062.53
#   Exit Time:       2025-06-03 10:45:00-04:00
#   Exit Price:      $1067.58
#   P&L:             +0.44%
#   Duration:        28 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.36
#   Stochastic:      45.56
#   Momentum (10):   -3.75
#   CCI (10):        -88.44
#   MACD:            -0.4913
#   MACD Signal:     -0.0368
#   MACD Histogram:  -0.4545
#   VWMACD:          0.1631
#   CMF (21):        0.5361
#   MFI (14):        43.97
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #83 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-10 04:30:00-04:00
#   Entry Price:     $1206.50
#   Open:            $1206.50
#   High:            $1209.87
#   Low:             $1199.50
#   Close:           $1207.86
#   Exit Time:       2025-06-10 10:00:00-04:00
#   Exit Price:      $1220.29
#   P&L:             +1.14%
#   Duration:        22 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.24
#   Stochastic:      23.43
#   Momentum (10):   -7.54
#   CCI (10):        -44.96
#   MACD:            -2.4394
#   MACD Signal:     -1.2201
#   MACD Histogram:  -1.2193
#   VWMACD:          -4.5185
#   CMF (21):        0.4248
#   MFI (14):        52.66
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #84 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-12 21:15:00-04:00
#   Entry Price:     $1280.55
#   Open:            $1280.55
#   High:            $1292.69
#   Low:             $1274.00
#   Close:           $1290.32
#   Exit Time:       2025-06-15 20:15:00-04:00
#   Exit Price:      $1236.22
#   P&L:             -3.46%
#   Duration:        88 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        51.92
#   Stochastic:      35.68
#   Momentum (10):   -0.31
#   CCI (10):        8.35
#   MACD:            0.1705
#   MACD Signal:     1.7851
#   MACD Histogram:  -1.6146
#   VWMACD:          -0.9567
#   CMF (21):        0.2123
#   MFI (14):        50.44
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #85 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-16 02:00:00-04:00
#   Entry Price:     $1235.08
#   Open:            $1235.08
#   High:            $1239.34
#   Low:             $1232.00
#   Close:           $1238.21
#   Exit Time:       2025-06-16 03:00:00-04:00
#   Exit Price:      $1238.56
#   P&L:             +0.28%
#   Duration:        4 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        56.72
#   Stochastic:      62.79
#   Momentum (10):   5.28
#   CCI (10):        134.91
#   MACD:            0.9982
#   MACD Signal:     0.8798
#   MACD Histogram:  0.1184
#   VWMACD:          1.5138
#   CMF (21):        0.3445
#   MFI (14):        72.39
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #86 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-17 18:45:00-04:00
#   Entry Price:     $1255.83
#   Open:            $1255.83
#   High:            $1260.50
#   Low:             $1253.47
#   Close:           $1254.86
#   Exit Time:       2025-06-17 23:15:00-04:00
#   Exit Price:      $1267.84
#   P&L:             +0.96%
#   Duration:        18 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.48
#   Stochastic:      35.25
#   Momentum (10):   -11.75
#   CCI (10):        -98.52
#   MACD:            -1.7036
#   MACD Signal:     -0.2011
#   MACD Histogram:  -1.5025
#   VWMACD:          -3.7980
#   CMF (21):        0.0192
#   MFI (14):        38.45
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #87 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-06-19 09:00:00-04:00
#   Entry Price:     $1276.28
#   Open:            $1276.28
#   High:            $1280.37
#   Low:             $1270.00
#   Close:           $1276.56
#   Exit Time:       2025-06-19 21:30:00-04:00
#   Exit Price:      $1303.16
#   P&L:             +2.11%
#   Duration:        36 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        27.14
#   Stochastic:      26.34
#   Momentum (10):   -23.11
#   CCI (10):        -85.04
#   MACD:            -9.9799
#   MACD Signal:     -9.2513
#   MACD Histogram:  -0.7287
#   VWMACD:          -10.2443
# ...
#   Entry Price:     $1564.90
#   Open:            $1564.90
#   High:            $1567.00
#   Low:             $1546.13
#   Close:           $1550.95
#   Exit Time:       2025-10-22 05:45:00-04:00
#   Exit Price:      $1545.40
#   P&L:             -1.25%
#   Duration:        77 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        29.48
#   Stochastic:      14.30
#   Momentum (10):   -36.16
#   CCI (10):        -127.49
#   MACD:            -11.4528
#   MACD Signal:     -9.8754
#   MACD Histogram:  -1.5774
#   VWMACD:          -6.7546
#   CMF (21):        -0.2421
#   MFI (14):        31.92
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #160 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-23 16:15:00-04:00
#   Entry Price:     $1627.43
#   Open:            $1627.43
#   High:            $1630.88
#   Low:             $1619.00
#   Close:           $1626.79
#   Exit Time:       2025-10-23 20:45:00-04:00
#   Exit Price:      $1651.32
#   P&L:             +1.47%
#   Duration:        14 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        41.68
#   Stochastic:      47.11
#   Momentum (10):   -7.52
#   CCI (10):        -85.91
#   MACD:            -1.8409
#   MACD Signal:     -1.6130
#   MACD Histogram:  -0.2280
#   VWMACD:          2.3144
#   CMF (21):        0.5220
#   MFI (14):        55.27
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #161 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-24 04:30:00-04:00
#   Entry Price:     $1605.21
#   Open:            $1605.21
#   High:            $1608.57
#   Low:             $1598.00
#   Close:           $1607.71
#   Exit Time:       2025-10-24 11:45:00-04:00
#   Exit Price:      $1618.03
#   P&L:             +0.80%
#   Duration:        29 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   1
#   Negative Divs:   0
#   Total Divs:      1
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        35.45
#   Stochastic:      33.46
#   Momentum (10):   -3.50
#   CCI (10):        -75.44
#   MACD:            -6.9728
#   MACD Signal:     -5.6141
#   MACD Histogram:  -1.3587
#   VWMACD:          -9.0267
#   CMF (21):        0.2170
#   MFI (14):        35.58
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   MFI            : Pos Regular (10 bars)
#
# ============================================================
# Trade #162 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-26 20:00:00-04:00
#   Entry Price:     $1601.54
#   Open:            $1601.54
#   High:            $1604.39
#   Low:             $1593.50
#   Close:           $1603.56
#   Exit Time:       2025-10-27 02:30:00-04:00
#   Exit Price:      $1620.96
#   P&L:             +1.21%
#   Duration:        26 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        46.06
#   Stochastic:      34.39
#   Momentum (10):   -5.62
#   CCI (10):        -32.17
#   MACD:            -1.7757
#   MACD Signal:     -0.9395
#   MACD Histogram:  -0.8362
#   VWMACD:          -3.0728
#   CMF (21):        0.3173
#   MFI (14):        36.67
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #163 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-27 05:15:00-04:00
#   Entry Price:     $1588.04
#   Open:            $1588.04
#   High:            $1590.33
#   Low:             $1580.50
#   Close:           $1588.21
#   Exit Time:       2025-10-27 09:15:00-04:00
#   Exit Price:      $1599.34
#   P&L:             +0.71%
#   Duration:        16 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        28.72
#   Stochastic:      13.25
#   Momentum (10):   -31.09
#   CCI (10):        -99.49
#   MACD:            -4.8228
#   MACD Signal:     -1.0017
#   MACD Histogram:  -3.8211
#   VWMACD:          -3.9425
#   CMF (21):        0.2525
#   MFI (14):        28.09
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #164 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-27 20:45:00-04:00
#   Entry Price:     $1572.45
#   Open:            $1572.45
#   High:            $1584.00
#   Low:             $1570.50
#   Close:           $1574.47
#   Exit Time:       2025-10-28 13:45:00-04:00
#   Exit Price:      $1594.58
#   P&L:             +1.41%
#   Duration:        68 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.29
#   Stochastic:      24.05
#   Momentum (10):   -12.41
#   CCI (10):        -63.29
#   MACD:            -4.2835
#   MACD Signal:     -2.8798
#   MACD Histogram:  -1.4037
#   VWMACD:          -9.2352
#   CMF (21):        -0.3757
#   MFI (14):        40.09
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #165 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-28 23:00:00-04:00
#   Entry Price:     $1578.42
#   Open:            $1578.42
#   High:            $1581.02
#   Low:             $1573.50
#   Close:           $1576.37
#   Exit Time:       2025-10-29 05:15:00-04:00
#   Exit Price:      $1611.06
#   P&L:             +2.07%
#   Duration:        25 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.75
#   Stochastic:      28.72
#   Momentum (10):   -22.16
#   CCI (10):        -99.92
#   MACD:            -1.3513
#   MACD Signal:     0.6290
#   MACD Histogram:  -1.9803
#   VWMACD:          1.6847
#   CMF (21):        -0.0362
#   MFI (14):        63.15
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #166 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-29 13:45:00-04:00
#   Entry Price:     $1592.64
#   Open:            $1592.64
#   High:            $1595.11
#   Low:             $1591.00
#   Close:           $1592.34
#   Exit Time:       2025-10-30 01:00:00-04:00
#   Exit Price:      $1605.39
#   P&L:             +0.80%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        39.73
#   Stochastic:      36.96
#   Momentum (10):   -6.00
#   CCI (10):        -84.79
#   MACD:            -2.6867
#   MACD Signal:     -1.5611
#   MACD Histogram:  -1.1255
#   VWMACD:          -7.1493
#   CMF (21):        0.0384
#   MFI (14):        51.35
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #167 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-10-31 13:45:00-04:00
#   Entry Price:     $1577.12
#   Open:            $1577.12
#   High:            $1578.67
#   Low:             $1572.50
#   Close:           $1574.81
#   Exit Time:       2025-11-05 03:30:00-05:00
#   Exit Price:      $1546.86
#   P&L:             -1.92%
#   Duration:        235 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        36.48
#   Stochastic:      30.49
#   Momentum (10):   -15.31
#   CCI (10):        -56.05
#   MACD:            -5.8834
#   MACD Signal:     -5.2380
#   MACD Histogram:  -0.6454
#   VWMACD:          -0.6766
#   CMF (21):        0.2307
#   MFI (14):        40.49
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #168 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-05 07:30:00-05:00
#   Entry Price:     $1533.29
#   Open:            $1533.29
#   High:            $1535.40
#   Low:             $1530.00
#   Close:           $1534.28
#   Exit Time:       2025-11-05 09:00:00-05:00
#   Exit Price:      $1554.45
#   P&L:             +1.38%
#   Duration:        6 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        44.49
#   Stochastic:      32.81
#   Momentum (10):   1.27
#   CCI (10):        -37.87
#   MACD:            -1.8486
#   MACD Signal:     -1.2179
#   MACD Histogram:  -0.6307
#   VWMACD:          -7.5337
#   CMF (21):        0.2583
#   MFI (14):        47.03
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #169 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-06 09:00:00-05:00
#   Entry Price:     $1560.28
#   Open:            $1560.28
#   High:            $1563.19
#   Low:             $1553.00
#   Close:           $1562.04
#   Exit Time:       2025-11-06 19:45:00-05:00
#   Exit Price:      $1543.46
#   P&L:             -1.08%
#   Duration:        39 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        47.39
#   Stochastic:      38.00
#   Momentum (10):   -3.98
#   CCI (10):        -29.38
#   MACD:            -1.0939
#   MACD Signal:     -0.4370
#   MACD Histogram:  -0.6568
#   VWMACD:          -4.3626
#   CMF (21):        0.2206
#   MFI (14):        52.59
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #170 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-07 10:00:00-05:00
#   Entry Price:     $1546.41
#   Open:            $1546.41
#   High:            $1550.75
#   Low:             $1537.50
#   Close:           $1541.96
#   Exit Time:       2025-11-07 12:00:00-05:00
#   Exit Price:      $1550.87
#   P&L:             +0.29%
#   Duration:        8 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        40.49
#   Stochastic:      38.37
#   Momentum (10):   -5.34
#   CCI (10):        -127.37
#   MACD:            -1.8021
#   MACD Signal:     -0.6351
#   MACD Histogram:  -1.1670
#   VWMACD:          -3.0646
#   CMF (21):        0.0973
#   MFI (14):        35.05
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #171 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-07 12:45:00-05:00
#   Entry Price:     $1537.35
#   Open:            $1537.35
#   High:            $1542.81
#   Low:             $1531.50
#   Close:           $1541.69
#   Exit Time:       2025-11-10 00:00:00-05:00
#   Exit Price:      $1569.02
#   P&L:             +2.06%
#   Duration:        41 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        45.33
#   Stochastic:      25.03
#   Momentum (10):   -0.67
#   CCI (10):        -32.39
#   MACD:            -2.4398
#   MACD Signal:     -1.6649
#   MACD Histogram:  -0.7749
#   VWMACD:          -2.0011
#   CMF (21):        0.2360
#   MFI (14):        46.46
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #172 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-10 06:00:00-05:00
#   Entry Price:     $1574.44
#   Open:            $1574.44
#   High:            $1577.21
#   Low:             $1568.50
#   Close:           $1572.41
#   Exit Time:       2025-11-10 07:45:00-05:00
#   Exit Price:      $1580.73
#   P&L:             +0.40%
#   Duration:        7 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        50.32
#   Stochastic:      36.66
#   Momentum (10):   -3.92
#   CCI (10):        -57.90
#   MACD:            1.5883
#   MACD Signal:     2.5232
#   MACD Histogram:  -0.9349
#   VWMACD:          0.5595
#   CMF (21):        -0.1173
#   MFI (14):        42.10
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #173 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-11 23:30:00-05:00
#   Entry Price:     $1583.33
#   Open:            $1583.33
#   High:            $1584.20
#   Low:             $1578.00
#   Close:           $1580.03
#   Exit Time:       2025-11-12 03:45:00-05:00
#   Exit Price:      $1593.21
#   P&L:             +0.62%
#   Duration:        17 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        38.61
#   Stochastic:      40.33
#   Momentum (10):   -12.99
#   CCI (10):        -149.98
#   MACD:            -1.3392
#   MACD Signal:     -0.6693
#   MACD Histogram:  -0.6698
#   VWMACD:          0.5851
#   CMF (21):        0.3272
#   MFI (14):        34.86
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #174 [CLOSED]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-13 03:00:00-05:00
#   Entry Price:     $1616.25
#   Open:            $1616.25
#   High:            $1624.00
#   Low:             $1613.50
#   Close:           $1618.86
#   Exit Time:       2025-11-13 04:15:00-05:00
#   Exit Price:      $1618.50
#   P&L:             +0.14%
#   Duration:        5 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        53.02
#   Stochastic:      54.57
#   Momentum (10):   0.24
#   CCI (10):        48.76
#   MACD:            0.5908
#   MACD Signal:     0.7987
#   MACD Histogram:  -0.2079
#   VWMACD:          -0.1361
#   CMF (21):        0.2447
#   MFI (14):        50.17
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================
# Trade #175 [OPEN]
# ============================================================
#
# 📊 PRICE INFORMATION:
#   Entry Time:      2025-11-13 09:00:00-05:00
#   Entry Price:     $1604.31
#   Open:            $1604.31
#   High:            $1604.42
#   Low:             $1582.00
#   Close:           $1598.36
#   Current Price:   $1541.40
#   P&L:             -3.92%
#   Duration:        123 bars
#
# 🔍 DIVERGENCE SIGNALS:
#   Positive Divs:   0
#   Negative Divs:   0
#   Total Divs:      0
#
# 📈 TECHNICAL INDICATORS AT ENTRY:
#   RSI (14):        37.71
#   Stochastic:      39.33
#   Momentum (10):   -15.45
#   CCI (10):        -100.38
#   MACD:            -4.5159
#   MACD Signal:     -2.4774
#   MACD Histogram:  -2.0384
#   VWMACD:          -8.2664
#   CMF (21):        0.4206
#   MFI (14):        28.57
#
# 🎯 SPECIFIC DIVERGENCES DETECTED:
#   No specific divergences recorded (signal from previous bar)
#
# ============================================================

# %%
#===============================================================================
# CELL 2: Auto "window + indicators + pivots" search (with drawdown stats)
#===============================================================================

# !pip install scikit-learn

from sklearn.model_selection import ParameterGrid

#-------------------------------------------
# 1) Parametric indicator calculator
#-------------------------------------------

def calculate_indicators_with_params(df, params):
    """
    نسخة من calculate_indicators لكن بالـ windows جاية من params
    ما بنلمسش Config ولا الاستراتيجية نفسها، بس بنغير إعدادات المؤشرات.
    """
    df = df.copy()

    # نقرأ الـ windows من params مع قيم default
    rsi_window      = params.get("rsi_window",      14)
    macd_fast       = params.get("macd_fast",       12)
    macd_slow       = params.get("macd_slow",       26)
    macd_signal     = params.get("macd_signal",      9)
    mom_window      = params.get("mom_window",      10)
    stoch_window    = params.get("stoch_window",    14)
    stoch_smooth    = params.get("stoch_smooth",     3)
    vwma_fast_win   = params.get("vwma_fast",       12)
    vwma_slow_win   = params.get("vwma_slow",       26)
    cmf_window      = params.get("cmf_window",      21)
    cci_window      = params.get("cci_window",      10)
    mfi_window      = params.get("mfi_window",      14)

    close  = df["close"]
    high   = df["high"]
    low    = df["low"]
    volume = df["volume"]

    # ----- RSI -----
    df["rsi"] = ta.momentum.RSIIndicator(
        close, window=rsi_window
    ).rsi()

    # ----- MACD -----
    macd_ind = ta.trend.MACD(
        close,
        window_slow=macd_slow,
        window_fast=macd_fast,
        window_sign=macd_signal,
    )
    df["macd"]        = macd_ind.macd()
    df["macd_signal"] = macd_ind.macd_signal()
    df["macd_hist"]   = macd_ind.macd_diff()

    # ----- Momentum -----
    df["momentum"] = close - close.shift(mom_window)

    # ----- Stochastic -----
    lowest_low   = low.rolling(window=stoch_window).min()
    highest_high = high.rolling(window=stoch_window).max()
    stoch_k = 100 * (close - lowest_low) / (highest_high - lowest_low)
    df["stoch"] = stoch_k.rolling(window=stoch_smooth).mean()

    # ----- VW-MACD (VWMA fast - VWMA slow) -----
    vwma_fast = (close * volume).rolling(vwma_fast_win).sum() / volume.rolling(vwma_fast_win).sum()
    vwma_slow = (close * volume).rolling(vwma_slow_win).sum() / volume.rolling(vwma_slow_win).sum()
    df["vwmacd"] = vwma_fast - vwma_slow

    # ----- CMF -----
    df["cmf"] = ta.volume.ChaikinMoneyFlowIndicator(
        high, low, close, volume, window=cmf_window
    ).chaikin_money_flow()

    # ----- CCI -----
    df["cci"] = ta.trend.CCIIndicator(
        high, low, close,
        window=cci_window, constant=0.015, fillna=False
    ).cci()

    # ----- MFI -----
    df["mfi"] = ta.volume.MFIIndicator(
        high, low, close, volume,
        window=mfi_window, fillna=False
    ).money_flow_index()

    # ----- OBV (نفس الكود القديم) -----
    obv_values = [0.0]
    for i in range(1, len(df)):
        if close.iloc[i] > close.iloc[i - 1]:
            obv_values.append(obv_values[-1] + volume.iloc[i])
        elif close.iloc[i] < close.iloc[i - 1]:
            obv_values.append(obv_values[-1] - volume.iloc[i])
        else:
            obv_values.append(obv_values[-1])
    df["obv"] = obv_values

    # Fill NaNs
    df = df.fillna(method="bfill").fillna(method="ffill")

    return df

#-------------------------------------------
# 2) Fast performance evaluator (بدون طباعة) + drawdown per trade
#-------------------------------------------

def quick_performance(df):
    """
    - يحسب P&L لكل صفقة
    - يحسب max drawdown% لكل صفقة (أكبر نزول عن سعر الدخول)
    - يرجّع ملخّص: total_trades, win_rate, avg_pnl, total_return,
                    max_dd, avg_dd, median_dd
    """
    entries = df[df["signal"] == 1].copy()
    exits   = df[df["signal"] == -1].copy()

    if len(entries) == 0:
        return {
            "total_trades": 0,
            "win_rate": 0.0,
            "avg_pnl": 0.0,
            "total_return": 0.0,
            "max_dd": 0.0,
            "avg_dd": 0.0,
            "median_dd": 0.0,
        }

    pnl_list = []
    dd_list  = []

    for i, entry_row in entries.iterrows():
        entry_idx   = df.index.get_loc(i)
        entry_price = entry_row["entry_price"]

        # نلاقي أول exit بعد entry
        exit_idx = None
        exit_price = None
        for j, exit_row in exits.iterrows():
            candidate_idx = df.index.get_loc(j)
            if candidate_idx > entry_idx:
                exit_idx   = candidate_idx
                exit_price = exit_row["exit_price"]
                break

        # لو مفيش exit -> نخرج عند آخر شمعة
        if exit_idx is None:
            exit_idx   = len(df) - 1
            exit_price = df["close"].iloc[-1]

        # --- P&L للصفقة ---
        pnl_pct = (exit_price - entry_price) / entry_price * 100.0
        pnl_list.append(pnl_pct)

        # --- Drawdown للصفقة ---
        # ناخد كل الشموع من الدخول لحد الخروج
        trade_slice = df.iloc[entry_idx:exit_idx + 1]
        # أسوأ نزول بالنسبة لسعر الدخول بناءً على الـ low
        dd_series = (trade_slice["low"] - entry_price) / entry_price * 100.0
        worst_dd = dd_series.min()  # ده رقم سالب غالباً
        dd_mag   = abs(worst_dd)    # نخليه موجب: 7% drawdown بدل -7%
        dd_list.append(dd_mag)

    trades = np.array(pnl_list)
    dds    = np.array(dd_list)

    total_trades = len(trades)
    wins   = (trades > 0).sum()
    win_rate = (wins / total_trades * 100.0) if total_trades > 0 else 0.0
    avg_pnl = trades.mean() if total_trades > 0 else 0.0
    total_return = trades.sum()

    max_dd     = dds.max()     if len(dds) > 0 else 0.0
    avg_dd     = dds.mean()    if len(dds) > 0 else 0.0
    median_dd  = np.median(dds) if len(dds) > 0 else 0.0

    return {
        "total_trades": int(total_trades),
        "win_rate": float(win_rate),
        "avg_pnl": float(avg_pnl),
        "total_return": float(total_return),
        "max_dd": float(max_dd),
        "avg_dd": float(avg_dd),
        "median_dd": float(median_dd),
    }

#-------------------------------------------
# 3) Pipeline for one parameter set
#    (مع لعب في indicators ON/OFF + pivot period)
#-------------------------------------------

def run_pipeline_with_params(csv_filepath, params):
    """
    - يحمّل الداتا
    - يحسب المؤشرات بالـ windows الجديدة
    - يظبط Config:
        * pivot period (prd)
        * أي indicators عايز تطفيها/تشغّلها
    - يطلع pivots + divergences
    - يشغّل الاستراتيجية
    - يرجع metrics + df الناتج
    """
    # نخزن الـ state الأصلي عشان نرجّعه بعدين
    orig_state = {
        "prd":       config.prd,
        "calcmacd":  config.calcmacd,
        "calcmacda": config.calcmacda,
        "calcrsi":   config.calcrsi,
        "calcstoc":  config.calcstoc,
        "calccci":   config.calccci,
        "calcmom":   config.calcmom,
        "calcobv":   config.calcobv,
        "calcvwmacd":config.calcvwmacd,
        "calccmf":   config.calccmf,
        "calcmfi":   config.calcmfi,
    }

    try:
        # 1) نغيّر الـ pivot period لو موجود في params
        pivot_prd = params.get("pivot_prd", config.prd)
        config.prd = int(pivot_prd)

        # 2) نطبّق ON/OFF للمؤشرات لو params فيها flags
        indicator_flags = {
            "use_macd":      "calcmacd",
            "use_macd_hist": "calcmacda",
            "use_rsi":       "calcrsi",
            "use_stoch":     "calcstoc",
            "use_mom":       "calcmom",
            "use_cci":       "calccci",
            "use_obv":       "calcobv",
            "use_vwmacd":    "calcvwmacd",
            "use_cmf":       "calccmf",
            "use_mfi":       "calcmfi",
        }
        for param_key, cfg_attr in indicator_flags.items():
            if param_key in params:
                setattr(config, cfg_attr, bool(params[param_key]))

        # 3) Pipeline عادي
        df = load_data_from_csv(csv_filepath)
        df = calculate_indicators_with_params(df, params)
        df = find_pivots(df, config.prd)
        df = scan_all_divergences(df)
        df = run_strategy(df)
        metrics = quick_performance(df)
    finally:
        # نرجّع Config زي ما كانت عشان التجربة اللي بعدها
        config.prd       = orig_state["prd"]
        config.calcmacd  = orig_state["calcmacd"]
        config.calcmacda = orig_state["calcmacda"]
        config.calcrsi   = orig_state["calcrsi"]
        config.calcstoc  = orig_state["calcstoc"]
        config.calccci   = orig_state["calccci"]
        config.calcmom   = orig_state["calcmom"]
        config.calcobv   = orig_state["calcobv"]
        config.calcvwmacd= orig_state["calcvwmacd"]
        config.calccmf   = orig_state["calccmf"]
        config.calcmfi   = orig_state["calcmfi"]

    return metrics, df

#-------------------------------------------
# 4) Grid search على windows + indicators + pivot period
#-------------------------------------------

# تقدر توسّع الـ grid براحتك لحد ~4000 combination زي ما انت قولت
param_grid = {
    # ---- indicator windows ----
    # كان [7, 14] بس → خلّيه [7, 10, 14, 21]  (4 قيم بدل 2)
    "rsi_window"   : [7, 10, 14, 21],

    # كان [9] بس → خلّيه [9, 14]  (2 قيم بدل 1)
    "stoch_window" : [9, 14],

    "stoch_smooth" : [3],
    "mom_window"   : [5, 10],
    "cci_window"   : [10],
    "mfi_window"   : [10, 20],
    "vwma_fast"    : [8, 12],
    "vwma_slow"    : [26],
    "cmf_window"   : [14, 21],

    # ---- pivot period ----
    "pivot_prd"    : [3, 5],

    # ---- indicator ON/OFF ----
    "use_vwmacd"   : [True, False],
    "use_cmf"      : [True, False],
    "use_mfi"      : [True, False],
}

grid = list(ParameterGrid(param_grid))
print(f"🔍 Number of combinations to test: {len(grid)}")

results = []

for idx, params in enumerate(grid, start=1):
    metrics, _ = run_pipeline_with_params(csv_filename, params)
    row = {**params, **metrics}
    results.append(row)

    # ✅ طباعة كاملة لكل combination
    print(f"\n[{idx}/{len(grid)}]")
    print(f"  params : {params}")
    print(
        "  metrics: "
        f"trades={metrics['total_trades']}, "
        f"win_rate={metrics['win_rate']:.2f}%, "
        f"avg_pnl={metrics['avg_pnl']:.2f}%, "
        f"total_return={metrics['total_return']:.2f}%, "
        f"max_dd={metrics['max_dd']:.2f}%, "
        f"avg_dd={metrics['avg_dd']:.2f}%, "
        f"median_dd={metrics['median_dd']:.2f}%"
    )

    # 💾 checkpoint كل 100 combo عشان الأمان
    if idx % 100 == 0 or idx == len(grid):
        tmp_df = pd.DataFrame(results)
        tmp_df.to_csv("divergence_param_grid_results_partial.csv", index=False)
        print("  💾 checkpoint saved: divergence_param_grid_results_partial.csv")


results_df = pd.DataFrame(results)

# نرتب حسب:
#   1) أعلى Total Return
#   2) أعلى Win Rate
#   3) أقل Max Drawdown
results_df = results_df.sort_values(
    by=["total_return", "win_rate", "max_dd"],
    ascending=[False, False, True]
).reset_index(drop=True)

print("\n===============================================")
print("🏆 TOP 10 PARAMETER SETS (by total_return, win_rate, low max_dd)")
print("===============================================")
print(results_df.head(10))
#-------------------------------------------
# 5) Export full grid-search results to CSV
#-------------------------------------------

csv_output_path = "divergence_param_grid_results.csv"
results_df.to_csv(csv_output_path, index=False)
print(f"\n📁 Full grid-search results saved to: {csv_output_path}")

best_params = results_df.iloc[0][list(param_grid.keys())].to_dict()
print("\n🔥 BEST PARAMS FOUND:")
for k, v in best_params.items():
    print(f"  {k}: {v}")

# شغّل الاستراتيجية تاني على أحسن params وشوف الشارت:
best_metrics, best_df = run_pipeline_with_params(csv_filename, best_params)
print("\nBest metrics on full sample:")
print(best_metrics)

# ترسم الشارت باستخدام best_df:
# plot_candlestick_with_signals(best_df)
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# 🔍 Number of combinations to test: 2048
# Loading data from PLD.csv...
# Loaded 20657 bars from 2025-01-01 18:15:00-05:00 to 2025-11-14 16:45:00-05:00
# Finding pivot points with period 3...
# Found 2127 pivot highs and 2142 pivot lows
# Scanning for divergences...
# Found 2361 bars with divergences
# Running strategy...
#
# [1/2048]
#   params : {'cci_window': 10, 'cmf_window': 14, 'mfi_window': 10, 'mom_window': 5, 'pivot_prd': 3, 'rsi_window': 7, 'stoch_smooth': 3, 'stoch_window': 9, 'use_cmf': True, 'use_mfi': True, 'use_vwmacd': True, 'vwma_fast': 8, 'vwma_slow': 26}
#   metrics: trades=266, win_rate=73.68%, avg_pnl=0.16%, total_return=43.67%, max_dd=7.98%, avg_dd=0.92%, median_dd=0.61%
# Loading data from PLD.csv...
# Loaded 20657 bars from 2025-01-01 18:15:00-05:00 to 2025-11-14 16:45:00-05:00
# Finding pivot points with period 3...
# Found 2127 pivot highs and 2142 pivot lows
# Scanning for divergences...
# Found 2410 bars with divergences
# Running strategy...
